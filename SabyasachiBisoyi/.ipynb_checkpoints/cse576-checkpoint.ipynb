# %%
import random

# %%
list_of_json_object = []

# %%
names = ["Liam", "Noah", "William", "James", "Oliver", "Benjamin", "Elijah", "Lucas", "Mason", "Logan", "Alexander", "Ethan", "Jacob", "Michael", "Daniel", "Henry", "Jackson", "Sebastian", "Aiden", "Matthew", "Samuel", "David", "Joseph", "Carter", "Owen", "Wyatt", "John", "Jack", "Luke", "Jayden", "Dylan", "Grayson", "Levi", "Isaac", "Gabriel", "Julian", "Mateo", "Anthony", "Jaxon", "Lincoln", "Joshua", "Christopher", "Andrew", "Theodore", "Caleb", "Ryan", "Asher", "Nathan", "Thomas", "Leo", "Isaiah", "Charles", "Josiah", "Hudson", "Christian", "Hunter", "Connor", "Eli", "Ezra", "Aaron", "Landon", "Adrian", "Jonathan", "Nolan", "Jeremiah", "Easton", "Elias", "Colton", "Cameron", "Carson", "Robert", "Angel", "Maverick", "Nicholas", "Dominic", "Jaxson", "Greyson", "Adam", "Ian", "Austin", "Santiago", "Jordan", "Cooper", "Brayden", "Roman", "Evan", "Ezekiel", "Xavier", "Jose", "Jace", "Jameson", "Leonardo", "Bryson", "Axel", "Everett", "Parker", "Kayden", "Miles", "Sawyer", "Jason", "Declan", "Weston", "Micah", "Ayden", "Wesley", "Luca", "Vincent", "Damian", "Zachary", "Silas", "Gavin", "Chase", "Kai", "Emmett", "Harrison", "Nathaniel", "Kingston", "Cole", "Tyler", "Bennett", "Bentley", "Ryker", "Tristan", "Brandon", "Kevin", "Luis", "George", "Ashton", "Rowan", "Braxton", "Ryder", "Gael", "Ivan", "Diego", "Maxwell", "Max", "Carlos", "Kaiden", "Juan", "Maddox", "Justin", "Waylon", "Calvin", "Giovanni", "Jonah", "Abel", "Jayce", "Jesus", "Amir", "King", "Beau", "Camden", "Alex", "Jasper", "Malachi", "Brody", "Jude", "Blake", "Emmanuel", "Eric", "Brooks", "Elliot", "Antonio", "Abraham", "Timothy", "Finn", "Rhett", "Elliott", "Edward", "August", "Xander", "Alan", "Dean", "Lorenzo", "Bryce", "Karter", "Victor", "Milo", "Miguel", "Hayden", "Graham", "Grant", "Zion", "Tucker", "Jesse", "Zayden", "Joel", "Richard", "Patrick", "Emiliano", "Avery", "Nicolas", "Brantley", "Dawson", "Myles", "Matteo", "River", "Steven", "Thiago", "Zane", "Matias", "Judah", "Messiah", "Jeremy", "Preston", "Oscar", "Kaleb", "Alejandro", "Marcus", "Mark", "Peter", "Maximus", "Barrett", "Jax", "Andres", "Holden", "Legend", "Charlie", "Knox", "Kaden", "Paxton", "Kyrie", "Kyle", "Griffin", "Josue", "Kenneth", "Beckett", "Enzo", "Adriel", "Arthur", "Felix", "Bryan", "Lukas", "Paul", "Brian", "Colt", "Caden", "Leon", "Archer", "Omar", "Israel", "Aidan", "Theo", "Javier", "Remington", "Jaden", "Bradley", "Emilio", "Colin", "Riley", "Cayden", "Phoenix", "Clayton", "Simon", "Ace", "Nash", "Derek", "Rafael", "Zander", "Brady", "Jorge", "Jake", "Louis", "Damien", "Karson", "Walker", "Maximiliano", "Amari", "Sean", "Chance", "Walter", "Martin", "Finley", "Andre", "Tobias", "Cash", "Corbin", "Arlo", "Iker", "Erick", "Emerson", "Gunner", "Cody", "Stephen", "Francisco", "Killian", "Dallas", "Reid", "Manuel", "Lane", "Atlas", "Rylan", "Jensen", "Ronan", "Beckham", "Daxton", "Anderson", "Kameron", "Raymond", "Orion", "Cristian", "Tanner", "Kyler", "Jett", "Cohen", "Ricardo", "Spencer", "Gideon", "Ali", "Fernando", "Jaiden", "Titus", "Travis", "Bodhi", "Eduardo", "Dante", "Ellis", "Prince", "Kane", "Luka", "Kash", "Hendrix", "Desmond", "Donovan", "Mario", "Atticus", "Cruz", "Garrett", "Hector", "Angelo", "Jeffrey", "Edwin", "Cesar", "Zayn", "Devin", "Conor", "Warren", "Odin", "Jayceon", "Romeo", "Julius", "Jaylen", "Hayes", "Kayson", "Muhammad", "Jaxton", "Joaquin", "Caiden", "Dakota", "Major", "Keegan", "Sergio", "Marshall", "Johnny", "Kade", "Edgar", "Leonel", "Ismael", "Marco", "Tyson", "Wade", "Collin", "Troy", "Nasir", "Conner", "Adonis", "Jared", "Rory", "Andy", "Jase", "Lennox", "Shane", "Malik", "Ari", "Reed", "Seth", "Clark", "Erik", "Lawson", "Trevor", "Gage", "Nico", "Malakai", "Quinn", "Cade", "Johnathan", "Sullivan", "Solomon", "Cyrus", "Fabian", "Pedro", "Frank", "Shawn", "Malcolm", "Khalil", "Nehemiah", "Dalton", "Mathias", "Jay", "Ibrahim", "Peyton", "Winston", "Kason", "Zayne", "Noel", "Princeton", "Matthias", "Gregory", "Sterling", "Dominick", "Elian", "Grady", "Russell", "Finnegan", "Ruben", "Gianni", "Porter", "Kendrick", "Leland", "Pablo", "Allen", "Hugo", "Raiden", "Kolton", "Remy", "Ezequiel", "Damon", "Emanuel", "Zaiden", "Otto", "Bowen", "Marcos", "Abram", "Kasen", "Franklin", "Royce", "Jonas", "Sage", "Philip", "Esteban", "Drake", "Kashton", "Roberto", "Harvey", "Alexis", "Kian", "Jamison", "Maximilian", "Adan", "Milan", "Phillip", "Albert", "Dax", "Mohamed", "Ronin", "Kamden", "Hank", "Memphis", "Oakley", "Augustus", "Drew", "Moises", "Armani", "Rhys", "Benson", "Jayson", "Kyson", "Braylen", "Corey", "Gunnar", "Omari", "Alonzo", "Landen", "Armando", "Derrick", "Dexter", "Enrique", "Bruce", "Nikolai", "Francis", "Rocco", "Kairo", "Royal", "Zachariah", "Arjun", "Deacon", "Skyler", "Eden", "Alijah", "Rowen", "Pierce", "Uriel", "Ronald", "Luciano", "Tate", "Frederick", "Kieran", "Lawrence", "Moses", "Rodrigo", "Brycen", "Leonidas", "Nixon", "Keith", "Chandler", "Case", "Davis", "Asa", "Darius", "Isaias", "Aden", "Jaime", "Landyn", "Raul", "Niko", "Trenton", "Apollo", "Cairo", "Izaiah", "Scott", "Dorian", "Julio", "Wilder", "Santino", "Dustin", "Donald", "Raphael", "Saul", "Taylor", "Ayaan", "Duke", "Ryland", "Tatum", "Ahmed", "Moshe", "Edison", "Emmitt", "Cannon", "Alec", "Danny", "Keaton", "Roy", "Conrad", "Roland", "Quentin", "Lewis", "Samson", "Brock", "Kylan", "Cason", "Ahmad", "Jalen", "Nikolas", "Braylon", "Kamari", "Dennis", "Callum", "Justice", "Soren", "Rayan", "Aarav", "Gerardo", "Ares", "Brendan", "Jamari", "Kaison", "Yusuf", "Issac", "Jasiah", "Callen", "Forrest", "Makai", "Crew", "Kobe", "Bo", "Julien", "Mathew", "Braden", "Johan", "Marvin", "Zaid", "Stetson", "Casey", "Ty", "Ariel", "Tony", "Zain", "Callan", "Cullen", "Sincere", "Uriah", "Dillon", "Kannon", "Colby", "Axton", "Cassius", "Quinton", "Mekhi", "Reece", "Alessandro", "Jerry", "Mauricio", "Sam", "Trey", "Mohammad", "Alberto", "Gustavo", "Arturo", "Fletcher", "Marcelo", "Abdiel", "Hamza", "Alfredo", "Chris", "Finnley", "Curtis", "Kellan", "Quincy", "Kase", "Harry", "Kyree", "Wilson", "Cayson", "Hezekiah", "Kohen", "Neil", "Mohammed", "Raylan", "Kaysen", "Lucca", "Sylas", "Mack", "Leonard", "Lionel", "Ford", "Roger", "Rex", "Alden", "Boston", "Colson", "Briggs", "Zeke", "Dariel", "Kingsley", "Valentino", "Jamir", "Salvador", "Vihaan", "Mitchell", "Lance", "Lucian", "Darren", "Jimmy", "Alvin", "Amos", "Tripp", "Zaire", "Layton", "Reese", "Casen", "Colten", "Brennan", "Korbin", "Sonny", "Bruno", "Orlando", "Devon", "Huxley", "Boone", "Maurice", "Nelson", "Douglas", "Randy", "Gary", "Lennon", "Titan", "Denver", "Jaziel", "Noe", "Jefferson", "Ricky", "Lochlan", "Rayden", "Bryant", "Langston", "Lachlan", "Clay", "Abdullah", "Lee", "Baylor", "Leandro", "Ben", "Kareem", "Layne", "Joe", "Crosby", "Deandre", "Demetrius", "Kellen", "Carl", "Jakob", "Ridge", "Bronson", "Jedidiah", "Rohan", "Larry", "Stanley", "Tomas", "Shiloh", "Thaddeus", "Watson", "Baker", "Vicente", "Koda", "Jagger", "Nathanael", "Carmelo", "Shepherd", "Graysen", "Melvin", "Ernesto", "Jamie", "Yosef", "Clyde", "Eddie", "Tristen", "Grey", "Ray", "Tommy", "Samir", "Ramon", "Santana", "Kristian", "Marcel", "Wells", "Zyaire", "Brecken", "Byron", "Otis", "Reyansh", "Axl", "Joey", "Trace", "Morgan", "Musa", "Harlan", "Enoch", "Henrik", "Kristopher", "Talon", "Rey", "Guillermo", "Houston", "Jon", "Vincenzo", "Dane", "Terry", "Azariah", "Castiel", "Kye", "Augustine", "Zechariah", "Joziah", "Kamryn", "Hassan", "Jamal", "Chaim", "Bodie", "Emery", "Branson", "Jaxtyn", "Kole", "Wayne", "Aryan", "Alonso", "Brixton", "Madden", "Allan", "Flynn", "Jaxen", "Harley", "Magnus", "Sutton", "Dash", "Anders", "Westley", "Brett", "Emory", "Felipe", "Yousef", "Jadiel", "Mordechai", "Dominik", "Junior", "Eliseo", "Fisher", "Harold", "Jaxxon", "Kamdyn", "Maximo", "Caspian", "Kelvin", "Damari", "Fox", "Trent", "Hugh", "Briar", "Franco", "Keanu", "Terrance", "Yahir", "Ameer", "Kaiser", "Thatcher", "Ishaan", "Koa", "Merrick", "Coen", "Rodney", "Brayan", "London", "Rudy", "Gordon", "Bobby", "Aron", "Marc", "Van", "Anakin", "Canaan", "Dario", "Reginald", "Westin", "Darian", "Ledger", "Leighton", "Maxton", "Tadeo", "Valentin", "Aldo", "Khalid", "Nickolas", "Toby", "Dayton", "Jacoby", "Billy", "Gatlin", "Elisha", "Jabari", "Jermaine", "Alvaro", "Marlon", "Mayson", "Blaze", "Jeffery", "Kace", "Braydon", "Achilles", "Brysen", "Saint", "Xzavier", "Aydin", "Eugene", "Adrien", "Cain", "Kylo", "Nova", "Onyx", "Arian", "Bjorn", "Jerome", "Miller", "Alfred", "Kenzo", "Kyng", "Leroy", "Maison", "Jordy", "Stefan", "Wallace", "Benicio", "Kendall", "Zayd", "Blaine", "Tristian", "Anson", "Gannon", "Jeremias", "Marley", "Ronnie", "Dangelo", "Kody", "Will", "Bentlee", "Gerald", "Salvatore", "Turner", "Chad", "Misael", "Mustafa", "Konnor", "Maxim", "Rogelio", "Zakai", "Cory", "Judson", "Brentley", "Darwin", "Louie", "Ulises", "Dakari", "Rocky", "Wesson", "Alfonso", "Payton", "Dwayne", "Juelz", "Duncan", "Keagan", "Deshawn", "Bode", "Bridger", "Skylar", "Brodie", "Landry", "Avi", "Keenan", "Reuben", "Jaxx", "Rene", "Yehuda", "Imran", "Yael", "Alexzander", "Willie", "Cristiano", "Heath", "Lyric", "Davion", "Elon", "Karsyn", "Krew", "Jairo", "Maddux", "Ephraim", "Ignacio", "Vivaan", "Aries", "Vance", "Boden", "Lyle", "Ralph", "Reign", "Camilo", "Draven", "Terrence", "Idris", "Ira", "Javion", "Jericho", "Khari", "Marcellus", "Creed", "Shepard", "Terrell", "Ahmir", "Camdyn", "Cedric", "Howard", "Jad", "Zahir", "Harper", "Justus", "Forest", "Gibson", "Zev", "Alaric", "Decker", "Ernest", "Jesiah", "Torin", "Benedict", "Bowie", "Deangelo", "Genesis", "Harlem", "Kalel", "Kylen", "Bishop", "Immanuel", "Lian", "Zavier", "Archie", "Davian", "Gus", "Kabir", "Korbyn", "Randall", "Benton", "Coleman", "Markus"]

# %%
def create_params_mapping(temp_variables):
    param_dict = {}
    for i in range(len(temp_variables)):
        key = "$"+str(i+1)
        param_dict[key] = temp_variables[i]
    return param_dict

# %%
def raplace_parameters(template,temp_variables):
    param_dict = create_params_mapping(temp_variables)
    for key in param_dict:
        template = template.replace(key,str(param_dict[key]))
    return template

# %%
def commonsense_carpet(list_of_json_object):
    template = "The size of my room is $1 * $2. Which carpet shoul I buy from $3?"
    ecommerce = ["amazon","flipkart","walmart","target"]
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        length = random.randint(30,60)
        breadth = random.randint(30,60)
        ecommerce_chooser = ecommerce[random.randint(0,3)]
        correct_answer = random.randint(0,4)
        temp_variables = [length,breadth,ecommerce_chooser]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        question_options = []
        for i in range(5):
            if i == correct_answer:
                ans_len = random.randint(int(length/2),length-1)
                ans_bre = random.randint(int(breadth/2),breadth-1)
                ans = str(ans_len)+"*"+str(ans_bre)
                template_obj["answer"] = ans
                question_options.append(ans)
            else:
                opt_len = random.randint(length+1,(length+1)*2)
                opt_bre = random.randint(breadth+1,(breadth+1)*2)
                opt = str(opt_len)+"*"+str(opt_bre)
                question_options.append(opt)
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
list_of_json_object.clear()
commonsense_carpet(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'The size of my room is 52 * 58. Which carpet shoul I buy from target?', 'answer': '48*52', 'options': ['48*52', '53*81', '88*75', '103*59', '60*60']}, {'question': 'The size of my room is 59 * 50. Which carpet shoul I buy from flipkart?', 'answer': '48*48', 'options': ['91*69', '64*67', '65*93', '48*48', '84*92']}, {'question': 'The size of my room is 47 * 42. Which carpet shoul I buy from amazon?', 'answer': '25*36', 'options': ['25*36', '49*80', '56*73', '59*62', '57*70']}, {'question': 'The size of my room is 53 * 59. Which carpet shoul I buy from target?', 'answer': '45*39', 'options': ['81*112', '62*79', '45*39', '89*90', '88*89']}, {'question': 'The size of my room is 58 * 41. Which carpet shoul I buy from flipkart?', 'answer': '44*28', 'options': ['76*44', '44*28', '107*52', '116*50', '83*43']}, {'question': 'The size of my room is 48 * 53. Which carpet shoul I buy from flipkart?', 'answer': '35*51', 'options': ['95*78', '56*85', '97*94', '35*51', '97*73']}, {'question': 'The size of my room is 58 * 48. Which carpet shoul I buy from walmart?', 'answer': '30*46', 'options': ['79*84', '62*83', '102*65', '95*87', '30*46']}, {'question': 'The size of my room is 43 * 46. Which carpet shoul I buy from flipkart?', 'answer': '23*40', 'options': ['63*54', '65*68', '81*76', '54*78', '23*40']}, {'question': 'The size of my room is 58 * 54. Which carpet shoul I buy from flipkart?', 'answer': '32*42', 'options': ['32*42', '78*87', '88*104', '108*76', '85*80']}, {'question': 'The size of my room is 38 * 47. Which carpet shoul I buy from walmart?', 'answer': '23*38', 'options': ['23*38', '52*89', '72*81', '59*74', '64*71']}, {'question': 'The size of my room is 45 * 39. Which carpet shoul I buy from walmart?', 'answer': '43*21', 'options': ['43*21', '62*59', '50*62', '60*46', '80*73']}, {'question': 'The size of my room is 30 * 56. Which carpet shoul I buy from walmart?', 'answer': '16*28', 'options': ['47*96', '32*69', '36*110', '16*28', '41*89']}, {'question': 'The size of my room is 39 * 55. Which carpet shoul I buy from flipkart?', 'answer': '24*44', 'options': ['53*83', '59*96', '61*57', '24*44', '80*60']}, {'question': 'The size of my room is 55 * 37. Which carpet shoul I buy from flipkart?', 'answer': '48*26', 'options': ['48*26', '111*42', '81*50', '77*74', '61*63']}, {'question': 'The size of my room is 47 * 32. Which carpet shoul I buy from flipkart?', 'answer': '40*28', 'options': ['55*55', '40*28', '56*34', '83*42', '60*49']}, {'question': 'The size of my room is 57 * 35. Which carpet shoul I buy from target?', 'answer': '47*20', 'options': ['88*52', '47*20', '61*63', '69*37', '107*66']}, {'question': 'The size of my room is 59 * 33. Which carpet shoul I buy from flipkart?', 'answer': '29*24', 'options': ['70*65', '29*24', '97*50', '119*59', '97*37']}, {'question': 'The size of my room is 46 * 41. Which carpet shoul I buy from target?', 'answer': '37*34', 'options': ['75*43', '89*68', '78*45', '37*34', '73*58']}, {'question': 'The size of my room is 52 * 42. Which carpet shoul I buy from target?', 'answer': '27*29', 'options': ['27*29', '70*74', '89*68', '76*81', '75*55']}, {'question': 'The size of my room is 56 * 53. Which carpet shoul I buy from amazon?', 'answer': '48*39', 'options': ['48*39', '82*99', '106*98', '91*71', '66*58']}, {'question': 'The size of my room is 51 * 53. Which carpet shoul I buy from target?', 'answer': '31*28', 'options': ['90*82', '31*28', '85*94', '68*86', '93*56']}, {'question': 'The size of my room is 53 * 50. Which carpet shoul I buy from target?', 'answer': '40*42', 'options': ['40*42', '107*82', '75*60', '88*72', '102*98']}, {'question': 'The size of my room is 59 * 34. Which carpet shoul I buy from walmart?', 'answer': '55*21', 'options': ['55*21', '85*38', '112*48', '69*51', '106*40']}, {'question': 'The size of my room is 32 * 49. Which carpet shoul I buy from walmart?', 'answer': '18*38', 'options': ['62*62', '59*68', '60*58', '18*38', '33*50']}, {'question': 'The size  ...

# %%
def time_distance(list_of_json_object):
    verbs = ["walks","drives","cycles","runs"]
    template = "$1 $5 at a speed of $2 km/hr. How much time will it take him/her to travel $3 's place which is $4 km away?"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        name_from = names[random.randint(0,500)]
        name_to = names[random.randint(501,999)]
        speed = random.randint(6,20)
        distance = random.randint(100,200)
        verb = verbs[random.randint(0,3)]
        correct_answer = random.randint(0,4)
        temp_variables = [name_from,speed,name_to,distance,verb]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        question_options = []
        for i in range(5):
            if i == correct_answer:
                ans = (distance/speed)
                ans = str("%.2f" % ans)
                template_obj["answer"] = ans
                question_options.append(ans)
            else:
                opt = ((distance/speed)*random.randint(2,5))
                opt = str("%.2f" % opt)
                question_options.append(opt)
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
list_of_json_object.clear()
time_distance(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': "Xavier walks at a speed of 13 km/hr. How much time will it take him/her to travel Korbyn 's place which is 129 km away?", 'answer': '9.92', 'options': ['29.77', '9.92', '19.85', '29.77', '49.62']}, {'question': "Leland walks at a speed of 12 km/hr. How much time will it take him/her to travel Tommy 's place which is 105 km away?", 'answer': '8.75', 'options': ['35.00', '17.50', '8.75', '26.25', '35.00']}, {'question': "Angel drives at a speed of 7 km/hr. How much time will it take him/her to travel Amos 's place which is 194 km away?", 'answer': '27.71', 'options': ['110.86', '83.14', '55.43', '83.14', '27.71']}, {'question': "Kaleb runs at a speed of 18 km/hr. How much time will it take him/her to travel Jimmy 's place which is 125 km away?", 'answer': '6.94', 'options': ['34.72', '20.83', '6.94', '13.89', '27.78']}, {'question': "Alejandro walks at a speed of 13 km/hr. How much time will it take him/her to travel Randy 's place which is 114 km away?", 'answer': '8.77', 'options': ['43.85', '35.08', '26.31', '26.31', '8.77']}, {'question': "Jude walks at a speed of 15 km/hr. How much time will it take him/her to travel Tomas 's place which is 136 km away?", 'answer': '9.07', 'options': ['45.33', '27.20', '18.13', '18.13', '9.07']}, {'question': "Archer cycles at a speed of 14 km/hr. How much time will it take him/her to travel Howard 's place which is 188 km away?", 'answer': '13.43', 'options': ['53.71', '26.86', '53.71', '53.71', '13.43']}, {'question': "Benjamin cycles at a speed of 15 km/hr. How much time will it take him/her to travel Jerry 's place which is 125 km away?", 'answer': '8.33', 'options': ['8.33', '41.67', '25.00', '33.33', '33.33']}, {'question': "Connor walks at a speed of 19 km/hr. How much time will it take him/her to travel Raul 's place which is 173 km away?", 'answer': '9.11', 'options': ['36.42', '18.21', '9.11', '18.21', '18.21']}, {'question': "Jack runs at a speed of 19 km/hr. How much time will it take him/her to travel Davis 's place which is 117 km away?", 'answer': '6.16', 'options': ['24.63', '6.16', '12.32', '12.32', '12.32']}, {'question': "Damian cycles at a speed of 6 km/hr. How much time will it take him/her to travel Bentlee 's place which is 128 km away?", 'answer': '21.33', 'options': ['64.00', '42.67', '21.33', '42.67', '42.67']}, {'question': "Eli drives at a speed of 17 km/hr. How much time will it take him/her to travel Landry 's place which is 103 km away?", 'answer': '6.06', 'options': ['18.18', '6.06', '12.12', '24.24', '18.18']}, {'question': "Marcos walks at a speed of 17 km/hr. How much time will it take him/her to travel Ahmad 's place which is 123 km away?", 'answer': '7.24', 'options': ['36.18', '28.94', '7.24', '21.71', '14.47']}, {'question': "Caden runs at a speed of 9 km/hr. How much time will it take him/her to travel Dustin 's place which is 179 km away?", 'answer': '19.89', 'options': ['59.67', '99.44', '99.44', '19.89', '79.56']}, {'question': "Allen runs at a speed of 10 km/hr. How much time will it take him/her to travel Alvaro 's place which is 193 km away?", 'answer': '19.30', 'options': ['38.60', '19.30', '77.20', '96.50', '38.60']}, {'question': "Clayton runs at a speed of 11 km/hr. How much time will it take him/her to travel Sonny 's place which is 134 km away?", 'answer': '12.18', 'options': ['12.18', '36.55', '24.36', '48.73', '48.73']}, {'question': "Rylan runs at a speed of 8 km/hr. How much time will it take him/her to travel Cayson 's place which is 118 km away?", 'answer': '14.75', 'options': ['59.00', '29.50', '14.75', '29.50', '59.00']}, {'question': "Jorge runs at a speed of 16 km/hr. How much time will it take him/her to travel Zaire 's place which is 146 km away?", 'answer': '9.12', 'options': ['36.50', '9.12', '18.25', '27.38', '45.62']}, {'question': "Eli cycles at a speed of 19 km/hr. How much time will it take him/her to travel Lewis 's place which is 113 km away?", 'answer': '5.95', 'options': ['5.95', '17.84', '23.79', '17. ...

# %%
def triangle(list_of_json_object):
    template = "The angles of an triangle are $1, $2, $3. What type of triangle is this one?"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        angle_1 = random.randint(30,100)
        angle_2 = random.randint(30,60)
        angle_3 = 180 - angle_1 - angle_2
        angles = [angle_1,angle_2,angle_3]
        template_question = raplace_parameters(template,angles)
        template_obj["question"] = template_question
        question_options = ["acute angle triangle,right angle triangle,obtuse angle triangle"]
        for i in range(5):
            if angle_1>90 or angle_2>90 or angle_3 > 90:
                template_obj["answer"] = "obtuse angle triangle"
            elif angle_1==90 or angle_2==90 or angle_3 == 90:
                template_obj["answer"] = "right angle triangle"
            else:
                template_obj["answer"] = "acute angle triangle"       
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
list_of_json_object.clear()
triangle(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'The angles of an triangle are 55, 34, 91. What type of triangle is this one?', 'answer': 'obtuse angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 58, 55, 67. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 69, 55, 56. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 57, 47, 76. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 54, 34, 92. What type of triangle is this one?', 'answer': 'obtuse angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 80, 46, 54. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 100, 36, 44. What type of triangle is this one?', 'answer': 'obtuse angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 72, 35, 73. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 78, 51, 51. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 37, 53, 90. What type of triangle is this one?', 'answer': 'right angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 75, 44, 61. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 95, 49, 36. What type of triangle is this one?', 'answer': 'obtuse angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 61, 51, 68. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 59, 35, 86. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 41, 43, 96. What type of triangle is this one?', 'answer': 'obtuse angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 32, 51, 97. What type of triangle is this one?', 'answer': 'obtuse angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 51, 57, 72. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 44, 50, 86. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle are 35, 56, 89. What type of triangle is this one?', 'answer': 'acute angle triangle', 'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}, {'question': 'The angles of an triangle  ...

# %%
def polygon(list_of_json_object):
    template = "There are $1 sides of a polygon. What type of polygon is this one?"
    duplicity = 10
    while duplicity > 0:
        template_obj = {}
        side = random.randint(3,8)
        sides = [side]
        template_question = raplace_parameters(template,sides)
        template_obj["question"] = template_question
        question_options = ["Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon"]
        for i in range(5):
            if side ==3:
                template_obj["answer"] = "Traingle"
            elif side == 4:
                template_obj["answer"] = "Rectangle"
            elif side == 5:
                template_obj["answer"] = "Pentagon"
            elif side == 6:
                template_obj["answer"] = "Hexagon"
            elif side == 7:
                template_obj["answer"] = "Heptagon"
            else:
                template_obj["answer"] = "Octagon"       
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
list_of_json_object.clear()
polygon(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'There are 6 sides of a polygon. What type of polygon is this one?', 'answer': 'Hexagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 7 sides of a polygon. What type of polygon is this one?', 'answer': 'Heptagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 4 sides of a polygon. What type of polygon is this one?', 'answer': 'Rectangle', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 3 sides of a polygon. What type of polygon is this one?', 'answer': 'Traingle', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 5 sides of a polygon. What type of polygon is this one?', 'answer': 'Pentagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 5 sides of a polygon. What type of polygon is this one?', 'answer': 'Pentagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 6 sides of a polygon. What type of polygon is this one?', 'answer': 'Hexagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 5 sides of a polygon. What type of polygon is this one?', 'answer': 'Pentagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 5 sides of a polygon. What type of polygon is this one?', 'answer': 'Pentagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}, {'question': 'There are 5 sides of a polygon. What type of polygon is this one?', 'answer': 'Pentagon', 'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}]

# %%
def general_physics(list_of_json_object):
    objects = {"water":"1496","wood":"3960","glass":"5640","aluminium":"6420","mercury":"1540","antimony":"3400","Beryllium":"12890","Bismut":"2180","Brass":"4700","Brick":"4200","cadmium":"2780","concrete":"3700","constantan":"5177","copper annealed":"4760","copper rolled":"5010","cork":"518","diamond":"12000","duralumin":"6320","glass silicate flint":"3980","glass light crown":"5100","glass pyrex":"5640","gold":"3240","granite":"5950","iridium":"4790","iron cast":"4994","iron electrolytic":"5950","ivory":"3010","lead annealed":"2160","lead rolled":"1960","lucite":"2680","magnesium annealed":"5770","manganese":"4660","marbel":"3810","molybdenum":"6250","monel":"5350","nickel":"6040","nylon":"2620","platinum":"3260","Polyethylene":"1250","Polystyrene":"2350","rubber butyl":"1830","rubber gum":"1550","rubber neoprene":"1600","silica fused":"5968","silver":"3650","slate":"4510","steel":"5940","stainless steel":"5790","tantalium":"3350","tin rolled":"3320","titanium":"6070","annealed tungsten":"5220","drawn tungsten":"5410","tungsten carbide":"6655","zinc rolled":"4210"}
    key_list = list(objects.keys()) 
    #print(len(key_list))
    val_list = list(objects.values())
    ref_air = {"air":"343"}
    template = "Sound travels faster in denser medium than air. What is the speed of sound in $1 ?"
    duplicity = 100
    while duplicity > 0:
        template_obj = {}
        medium = random.randint(0,54)
        template_question = raplace_parameters(template,[key_list[medium]])
        template_obj["question"] = template_question
        template_obj["answer"] = str(val_list[medium])
        question_options = []
        question_options.append(str(val_list[medium]))
        for i in range(4):
            question_options.append(str(random.randint(100,int(ref_air["air"])-1)))
        random.shuffle(question_options)
        template_obj["options"] = question_options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
list_of_json_object.clear()
general_physics(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polyethylene ?', 'answer': '1250', 'options': ['1250', '278', '289', '225', '290']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass pyrex ?', 'answer': '5640', 'options': ['184', '229', '5640', '173', '256']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in zinc rolled ?', 'answer': '4210', 'options': ['4210', '243', '289', '169', '335']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tungsten carbide ?', 'answer': '6655', 'options': ['276', '316', '6655', '197', '217']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in magnesium annealed ?', 'answer': '5770', 'options': ['5770', '136', '258', '141', '149']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nylon ?', 'answer': '2620', 'options': ['265', '300', '2620', '194', '262']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?', 'answer': '5640', 'options': ['265', '211', '260', '5640', '282']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in monel ?', 'answer': '5350', 'options': ['200', '5350', '311', '211', '312']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tin rolled ?', 'answer': '3320', 'options': ['164', '313', '219', '141', '3320']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in concrete ?', 'answer': '3700', 'options': ['3700', '126', '174', '106', '117']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead rolled ?', 'answer': '1960', 'options': ['117', '110', '271', '1960', '278']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber gum ?', 'answer': '1550', 'options': ['1550', '225', '187', '207', '242']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?', 'answer': '5010', 'options': ['141', '5010', '101', '202', '107']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?', 'answer': '4200', 'options': ['118', '173', '4200', '149', '176']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in ivory ?', 'answer': '3010', 'options': ['3010', '313', '116', '229', '314']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?', 'answer': '3810', 'options': ['278', '189', '312', '142', '3810']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in diamond ?', 'answer': '12000', 'options': ['100', '290', '316', '12000', '165']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass silicate flint ?', 'answer': '3980', 'options': ['118', '3980', '136', '295', '121']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in water ?', 'answer': '1496', 'options': ['296', '1496', '231', '280', '109']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in steel ?', 'answer': '5940', 'options': ['200', '116', '285', '5940', '210']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iridium ?', 'answer': '4790', 'options': ['202', '121', '4790', '212', '337']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iridium ?', 'answer': '4790', 'options': ['134', '4790', '151', '169', '180']}, {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?', 'answer': '6040', 'options': ['6040', '179', '316', '261', '17 ...

# %%
def age_problem(list_of_json_object):
    template = "$1 is younger than $2 by $3 years. $4 years ago $2 was $5 years old. What is $1 's age today?"
    yonger_age = random.randint(1,15)
    age_in_year = random.randint(11,75)
    actual_age = random.randint(25,35)
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        younger_name = names[random.randint(0,500)]
        older_name = names[random.randint(501,999)]
        yonger_age = random.randint(1,5)
        age_in_year = random.randint(5,15)
        actual_age = random.randint(25,35)
        temp_variables = [younger_name,older_name,yonger_age,age_in_year,actual_age]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        answer = actual_age + age_in_year - yonger_age
        template_obj["answer"] = answer
        options.append(str(answer))
        for i in range(4):
            opt = actual_age + age_in_year*random.randint(1,3) + random.randint(1,3)*yonger_age
            options.append(str(opt))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
list_of_json_object.clear()
age_problem(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': "Eduardo is younger than Donald by 4 years. 5 years ago Donald was 33 years old. What is Eduardo 's age today?", 'answer': 34, 'options': ['34', '42', '55', '55', '46']}, {'question': "Arjun is younger than Henrik by 3 years. 6 years ago Henrik was 29 years old. What is Arjun 's age today?", 'answer': 32, 'options': ['44', '56', '38', '32', '50']}, {'question': "Roman is younger than Izaiah by 1 years. 5 years ago Izaiah was 28 years old. What is Roman 's age today?", 'answer': 32, 'options': ['41', '36', '34', '39', '32']}, {'question': "Jeffrey is younger than Gatlin by 2 years. 12 years ago Gatlin was 28 years old. What is Jeffrey 's age today?", 'answer': 38, 'options': ['70', '56', '38', '44', '66']}, {'question': "Dexter is younger than Zahir by 3 years. 8 years ago Zahir was 27 years old. What is Dexter 's age today?", 'answer': 32, 'options': ['32', '44', '57', '52', '38']}, {'question': "Barrett is younger than Emmitt by 2 years. 11 years ago Emmitt was 27 years old. What is Barrett 's age today?", 'answer': 36, 'options': ['44', '55', '40', '55', '36']}, {'question': "Easton is younger than Dangelo by 1 years. 13 years ago Dangelo was 33 years old. What is Easton 's age today?", 'answer': 45, 'options': ['61', '47', '49', '45', '74']}, {'question': "Tyler is younger than Tatum by 3 years. 15 years ago Tatum was 35 years old. What is Tyler 's age today?", 'answer': 47, 'options': ['68', '71', '47', '89', '71']}, {'question': "Tyson is younger than Van by 2 years. 14 years ago Van was 34 years old. What is Tyson 's age today?", 'answer': 46, 'options': ['46', '78', '78', '78', '82']}, {'question': "River is younger than Marvin by 4 years. 13 years ago Marvin was 31 years old. What is River 's age today?", 'answer': 40, 'options': ['56', '56', '61', '56', '40']}, {'question': "Elliott is younger than Jasiah by 5 years. 5 years ago Jasiah was 34 years old. What is Elliott 's age today?", 'answer': 34, 'options': ['64', '59', '44', '54', '34']}, {'question': "Jake is younger than Harley by 4 years. 7 years ago Harley was 29 years old. What is Jake 's age today?", 'answer': 32, 'options': ['51', '48', '32', '51', '58']}, {'question': "Dean is younger than Raul by 5 years. 6 years ago Raul was 32 years old. What is Dean 's age today?", 'answer': 33, 'options': ['60', '55', '55', '43', '33']}, {'question': "Keegan is younger than Trace by 3 years. 7 years ago Trace was 28 years old. What is Keegan 's age today?", 'answer': 32, 'options': ['41', '32', '58', '48', '44']}, {'question': "Kevin is younger than Guillermo by 5 years. 10 years ago Guillermo was 25 years old. What is Kevin 's age today?", 'answer': 30, 'options': ['30', '45', '60', '65', '60']}, {'question': "Zayn is younger than Heath by 4 years. 12 years ago Heath was 25 years old. What is Zayn 's age today?", 'answer': 33, 'options': ['33', '69', '45', '61', '65']}, {'question': "Juan is younger than Juelz by 5 years. 13 years ago Juelz was 35 years old. What is Juan 's age today?", 'answer': 43, 'options': ['53', '71', '66', '58', '43']}, {'question': "Peyton is younger than Reyansh by 2 years. 11 years ago Reyansh was 27 years old. What is Peyton 's age today?", 'answer': 36, 'options': ['44', '62', '44', '36', '66']}, {'question': "Emerson is younger than Lance by 4 years. 12 years ago Lance was 27 years old. What is Emerson 's age today?", 'answer': 35, 'options': ['55', '35', '47', '47', '51']}, {'question': "Keegan is younger than Marlon by 5 years. 11 years ago Marlon was 28 years old. What is Keegan 's age today?", 'answer': 34, 'options': ['66', '60', '55', '49', '34']}, {'question': "Kaiden is younger than Toby by 5 years. 12 years ago Toby was 35 years old. What is Kaiden 's age today?", 'answer': 42, 'options': ['86', '42', '52', '62', '86']}, {'question': "Braxton is younger than Darian by 1 years. 6 years ago Darian was 33 years old. What is Braxton 's age today?", 'answer': 38, 'options': ['38', '48', '47', '41', '40']}, {'question': " ...

# %%
def perimeter(list_of_json_object):
    template = "The side of an square is $1 . What is the perimeter of the square?"
    duplicity = 50
    while(duplicity>0):
        template_obj = {}
        options = []
        side = random.randint(1,1000)
        template_question = raplace_parameters(template,[side])
        template_obj["question"] = template_question
        ans = side * 4
        template_obj["answer"] = ans
        options.append(str(ans))
        for i in range(4):
            options.append(side*random.randint(5,10))
        random.shuffle(options)
        template_obj["options"] = options
        duplicity-=1
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
list_of_json_object.clear()
perimeter(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'The side of an square is 180 . What is the perimeter of the square?', 'answer': 720, 'options': [1260, 900, 900, '720', 1800]}, {'question': 'The side of an square is 160 . What is the perimeter of the square?', 'answer': 640, 'options': ['640', 1120, 1120, 800, 1120]}, {'question': 'The side of an square is 258 . What is the perimeter of the square?', 'answer': 1032, 'options': [1806, 1806, 2064, 2322, '1032']}, {'question': 'The side of an square is 926 . What is the perimeter of the square?', 'answer': 3704, 'options': ['3704', 6482, 4630, 7408, 6482]}, {'question': 'The side of an square is 129 . What is the perimeter of the square?', 'answer': 516, 'options': [1161, 1161, 1290, 1161, '516']}, {'question': 'The side of an square is 159 . What is the perimeter of the square?', 'answer': 636, 'options': [1113, '636', 1272, 1431, 1113]}, {'question': 'The side of an square is 727 . What is the perimeter of the square?', 'answer': 2908, 'options': [5816, 7270, '2908', 7270, 4362]}, {'question': 'The side of an square is 694 . What is the perimeter of the square?', 'answer': 2776, 'options': ['2776', 3470, 6246, 6940, 5552]}, {'question': 'The side of an square is 125 . What is the perimeter of the square?', 'answer': 500, 'options': [625, 1125, '500', 1250, 875]}, {'question': 'The side of an square is 635 . What is the perimeter of the square?', 'answer': 2540, 'options': ['2540', 5080, 3810, 3175, 3175]}, {'question': 'The side of an square is 428 . What is the perimeter of the square?', 'answer': 1712, 'options': [4280, 2568, 2140, '1712', 3852]}, {'question': 'The side of an square is 600 . What is the perimeter of the square?', 'answer': 2400, 'options': [4200, 5400, 3600, '2400', 4800]}, {'question': 'The side of an square is 597 . What is the perimeter of the square?', 'answer': 2388, 'options': ['2388', 5373, 5970, 2985, 2985]}, {'question': 'The side of an square is 361 . What is the perimeter of the square?', 'answer': 1444, 'options': [2166, 2527, 3249, 2888, '1444']}, {'question': 'The side of an square is 959 . What is the perimeter of the square?', 'answer': 3836, 'options': ['3836', 9590, 7672, 8631, 8631]}, {'question': 'The side of an square is 474 . What is the perimeter of the square?', 'answer': 1896, 'options': [2844, 2370, 3318, 2844, '1896']}, {'question': 'The side of an square is 186 . What is the perimeter of the square?', 'answer': 744, 'options': [1116, 1860, 930, '744', 1674]}, {'question': 'The side of an square is 85 . What is the perimeter of the square?', 'answer': 340, 'options': [595, '340', 510, 425, 680]}, {'question': 'The side of an square is 109 . What is the perimeter of the square?', 'answer': 436, 'options': ['436', 981, 654, 1090, 763]}, {'question': 'The side of an square is 328 . What is the perimeter of the square?', 'answer': 1312, 'options': [2296, '1312', 2296, 1640, 3280]}, {'question': 'The side of an square is 884 . What is the perimeter of the square?', 'answer': 3536, 'options': ['3536', 8840, 7072, 7072, 7072]}, {'question': 'The side of an square is 49 . What is the perimeter of the square?', 'answer': 196, 'options': [392, 441, 441, 245, '196']}, {'question': 'The side of an square is 147 . What is the perimeter of the square?', 'answer': 588, 'options': [1176, '588', 882, 735, 1323]}, {'question': 'The side of an square is 646 . What is the perimeter of the square?', 'answer': 2584, 'options': [3230, 5168, '2584', 5814, 3876]}, {'question': 'The side of an square is 568 . What is the perimeter of the square?', 'answer': 2272, 'options': [3976, 5680, '2272', 5112, 4544]}, {'question': 'The side of an square is 284 . What is the perimeter of the square?', 'answer': 1136, 'options': [2556, 2840, 1704, '1136', 2840]}, {'question': 'The side of an square is 582 . What is the perimeter of the square?', 'answer': 2328, 'options': [4656, 4656, 4074, 4074, '2328']}, {'question': 'The side of an square is 787 . What is the perimeter of the square?', 'answer': 3148 ...

# %%
def age_problem_older(list_of_json_object):
    template = "$1 is older than $2 by $3 years. $4 years ago $2 was $5 years old. What is $1 's age today?"
    yonger_age = random.randint(1,15)
    age_in_year = random.randint(25,75)
    actual_age = random.randint(25,65)
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        younger_name = names[random.randint(0,5)]
        older_name = names[random.randint(0,5)]
        yonger_age = random.randint(1,5)
        age_in_year = random.randint(5,15)
        actual_age = random.randint(25,35)
        temp_variables = [younger_name,older_name,yonger_age,age_in_year,actual_age]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        answer = actual_age + age_in_year + yonger_age
        template_obj["answer"] = answer
        options.append(str(answer))
        for i in range(4):
            opt = actual_age + age_in_year*random.randint(1,3) - random.randint(1,3)*yonger_age
            options.append(str(opt))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
list_of_json_object.clear()
age_problem_older(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': "Oliver is older than Liam by 1 years. 13 years ago Liam was 31 years old. What is Oliver 's age today?", 'answer': 45, 'options': ['41', '67', '45', '68', '69']}, {'question': "Noah is older than Noah by 2 years. 11 years ago Noah was 35 years old. What is Noah 's age today?", 'answer': 48, 'options': ['62', '44', '62', '48', '55']}, {'question': "Oliver is older than Noah by 2 years. 6 years ago Noah was 35 years old. What is Oliver 's age today?", 'answer': 43, 'options': ['39', '51', '41', '43', '45']}, {'question': "Oliver is older than William by 1 years. 5 years ago William was 27 years old. What is Oliver 's age today?", 'answer': 33, 'options': ['36', '36', '33', '30', '31']}, {'question': "Benjamin is older than Liam by 1 years. 5 years ago Liam was 34 years old. What is Benjamin 's age today?", 'answer': 40, 'options': ['38', '40', '42', '36', '37']}, {'question': "William is older than Liam by 1 years. 12 years ago Liam was 34 years old. What is William 's age today?", 'answer': 47, 'options': ['69', '68', '69', '44', '47']}, {'question': "Oliver is older than James by 5 years. 7 years ago James was 34 years old. What is Oliver 's age today?", 'answer': 46, 'options': ['40', '36', '26', '43', '46']}, {'question': "William is older than Benjamin by 4 years. 9 years ago Benjamin was 29 years old. What is William 's age today?", 'answer': 42, 'options': ['30', '52', '34', '52', '42']}, {'question': "Liam is older than William by 1 years. 5 years ago William was 32 years old. What is Liam 's age today?", 'answer': 38, 'options': ['45', '35', '45', '44', '38']}, {'question': "Noah is older than Benjamin by 1 years. 15 years ago Benjamin was 33 years old. What is Noah 's age today?", 'answer': 49, 'options': ['76', '46', '49', '61', '75']}, {'question': "Liam is older than William by 1 years. 14 years ago William was 27 years old. What is Liam 's age today?", 'answer': 42, 'options': ['40', '53', '42', '67', '53']}, {'question': "Benjamin is older than William by 3 years. 10 years ago William was 32 years old. What is Benjamin 's age today?", 'answer': 45, 'options': ['39', '43', '56', '45', '43']}, {'question': "James is older than Liam by 1 years. 6 years ago Liam was 26 years old. What is James 's age today?", 'answer': 33, 'options': ['29', '33', '43', '30', '42']}, {'question': "Noah is older than Oliver by 4 years. 7 years ago Oliver was 26 years old. What is Noah 's age today?", 'answer': 37, 'options': ['21', '37', '21', '35', '25']}, {'question': "Noah is older than Liam by 3 years. 5 years ago Liam was 35 years old. What is Noah 's age today?", 'answer': 43, 'options': ['47', '47', '31', '44', '43']}, {'question': "William is older than Liam by 3 years. 12 years ago Liam was 35 years old. What is William 's age today?", 'answer': 50, 'options': ['44', '41', '68', '68', '50']}, {'question': "Oliver is older than Oliver by 3 years. 10 years ago Oliver was 28 years old. What is Oliver 's age today?", 'answer': 41, 'options': ['45', '32', '41', '55', '39']}, {'question': "Noah is older than Liam by 5 years. 5 years ago Liam was 32 years old. What is Noah 's age today?", 'answer': 42, 'options': ['42', '32', '32', '27', '32']}, {'question': "Oliver is older than Liam by 5 years. 9 years ago Liam was 34 years old. What is Oliver 's age today?", 'answer': 48, 'options': ['42', '56', '47', '48', '51']}, {'question': "Oliver is older than Noah by 4 years. 14 years ago Noah was 27 years old. What is Oliver 's age today?", 'answer': 45, 'options': ['29', '57', '51', '29', '45']}, {'question': "Noah is older than James by 4 years. 11 years ago James was 27 years old. What is Noah 's age today?", 'answer': 42, 'options': ['42', '56', '34', '26', '37']}, {'question': "James is older than James by 1 years. 9 years ago James was 28 years old. What is James 's age today?", 'answer': 38, 'options': ['43', '38', '53', '34', '45']}, {'question': "Noah is older than James by 5 years. 11 years ago James was 30 years ol ...

# %%
def mean(list_of_json_object):
    verbs = ["height","weight","length","area","size"]
    nouns = ["human","martians","tigers","elephants","kangaroos","cats","dogs"]
    template = "What is the mean $1 of the set of given $2 ? $3"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        verb = verbs[random.randint(0,4)]
        noun = nouns[random.randint(0,6)]
        set_of_obj = ""
        sum_ = 0
        length = random.randint(5,50)
        for i in range(length):
            obj  = random.randint(1,50)
            sum_ += obj
            set_of_obj+=(str(obj)+" ")
        temp_variables = [verb,noun,set_of_obj]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        ans = sum_ / length
        ans = str("%.2f" % ans)
        template_obj["answer"] = ans
        options.append(ans)
        for i in range(4):
            opt = float(ans) * random.randint(2,5)
            opt = str("%.2f" % opt)
            options.append(opt)
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
list_of_json_object.clear()
mean(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'What is the mean weight of the set of given tigers ? 22 2 19 33 42 50 40 3 9 1 ', 'answer': '22.10', 'options': ['22.10', '88.40', '88.40', '44.20', '66.30']}, {'question': 'What is the mean area of the set of given cats ? 20 47 15 11 42 1 32 23 19 50 36 37 25 33 14 ', 'answer': '27.00', 'options': ['135.00', '108.00', '27.00', '108.00', '54.00']}, {'question': 'What is the mean length of the set of given elephants ? 27 25 18 9 17 13 21 14 13 ', 'answer': '17.44', 'options': ['69.76', '69.76', '87.20', '69.76', '17.44']}, {'question': 'What is the mean weight of the set of given human ? 25 26 7 41 48 47 12 26 24 11 40 27 44 13 38 38 32 42 48 8 1 ', 'answer': '28.48', 'options': ['142.40', '28.48', '56.96', '56.96', '85.44']}, {'question': 'What is the mean height of the set of given martians ? 41 34 16 15 20 5 30 23 22 25 33 32 21 21 48 40 25 27 5 32 5 22 ', 'answer': '24.64', 'options': ['98.56', '98.56', '49.28', '49.28', '24.64']}, {'question': 'What is the mean weight of the set of given martians ? 50 39 38 21 34 22 17 5 36 24 19 28 19 37 45 18 26 50 2 5 48 16 31 11 12 19 35 46 41 33 17 34 46 5 8 22 1 44 40 28 21 47 39 23 44 11 ', 'answer': '27.33', 'options': ['54.66', '136.65', '27.33', '81.99', '109.32']}, {'question': 'What is the mean area of the set of given tigers ? 18 9 11 19 16 8 21 ', 'answer': '14.57', 'options': ['14.57', '58.28', '43.71', '29.14', '29.14']}, {'question': 'What is the mean area of the set of given cats ? 4 10 30 1 31 5 30 42 34 24 45 41 37 25 ', 'answer': '25.64', 'options': ['102.56', '128.20', '76.92', '51.28', '25.64']}, {'question': 'What is the mean length of the set of given kangaroos ? 42 30 46 29 15 11 39 11 27 2 40 4 10 40 44 29 19 7 34 18 31 29 11 13 45 19 7 6 23 28 9 46 25 43 31 36 43 ', 'answer': '25.46', 'options': ['25.46', '76.38', '101.84', '50.92', '76.38']}, {'question': 'What is the mean height of the set of given dogs ? 33 42 3 17 37 2 23 27 47 12 26 5 36 27 41 39 41 48 38 24 28 29 7 29 9 17 27 49 50 40 3 31 9 44 41 24 27 22 48 27 2 32 ', 'answer': '27.69', 'options': ['55.38', '138.45', '110.76', '27.69', '83.07']}, {'question': 'What is the mean length of the set of given cats ? 18 21 33 18 14 8 23 28 22 43 26 42 4 24 44 18 34 48 37 15 3 45 45 41 21 16 20 47 50 37 9 22 4 43 28 31 38 32 42 20 21 17 ', 'answer': '27.43', 'options': ['137.15', '82.29', '54.86', '27.43', '54.86']}, {'question': 'What is the mean length of the set of given elephants ? 8 8 28 48 40 22 10 2 14 3 10 30 37 3 29 10 49 26 24 44 49 36 22 2 21 10 41 33 12 2 46 16 15 45 39 31 8 16 4 23 18 3 7 20 6 10 9 ', 'answer': '21.04', 'options': ['42.08', '105.20', '63.12', '105.20', '21.04']}, {'question': 'What is the mean area of the set of given elephants ? 21 3 8 33 43 44 18 15 1 50 28 23 41 32 46 12 50 13 43 19 4 12 37 13 4 7 18 17 4 27 3 27 27 32 18 6 17 28 16 35 43 24 27 4 4 48 27 49 41 ', 'answer': '23.71', 'options': ['47.42', '47.42', '71.13', '118.55', '23.71']}, {'question': 'What is the mean length of the set of given cats ? 1 21 36 15 6 31 3 33 37 39 4 14 4 25 9 46 3 30 3 45 33 46 9 32 3 11 41 41 14 23 49 29 42 4 40 29 37 46 21 12 2 21 ', 'answer': '23.57', 'options': ['23.57', '70.71', '117.85', '47.14', '47.14']}, {'question': 'What is the mean size of the set of given cats ? 47 41 21 6 22 49 24 28 25 28 ', 'answer': '29.10', 'options': ['29.10', '145.50', '58.20', '116.40', '87.30']}, {'question': 'What is the mean length of the set of given dogs ? 1 32 48 10 36 39 17 25 35 21 45 33 1 3 27 33 33 1 24 11 38 12 43 37 28 6 45 43 27 5 41 21 50 20 49 47 25 40 18 47 30 38 48 46 24 1 ', 'answer': '28.35', 'options': ['85.05', '141.75', '141.75', '141.75', '28.35']}, {'question': 'What is the mean height of the set of given elephants ? 16 12 7 3 27 46 31 34 40 41 11 17 3 2 16 2 22 2 47 48 23 29 39 9 45 35 39 29 10 36 1 3 37 ', 'answer': '23.09', 'options': ['23.09', '69.27', '92.36', '115.45', '92.36']}, {'question': 'What is the mean size of the set of given human ? 2 27 43 4 37 5 47 33 4 ...

# %%
def median(list_of_json_object):
    verbs = ["height","weight","length","area","size"]
    nouns = ["human","martians","tigers","elephants","kangaroos","cats","dogs"]
    template = "What is the median $1 of the set of given $2 ? $3"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        verb = verbs[random.randint(0,4)]
        noun = nouns[random.randint(0,6)]
        median_set = []
        set_of_obj = ""
        length = random.randint(5,50)
        for i in range(length):
            obj  = random.randint(1,50)
            set_of_obj+=(str(obj)+" ")
            median_set.append(obj)
        temp_variables = [verb,noun,set_of_obj]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        median_set.sort()
        ans = 0
        if len(median_set)%2==0:
            ans = (median_set[int(len(median_set)/2)] + median_set[int(len(median_set)/2)-1])/2
        else:
            ans = (median_set[int(len(median_set)/2)])
        ans = str("%.2f" % ans)
        template_obj["answer"] = ans
        options.append(ans)
        for i in range(4):
            opt = float(median_set[random.randint(0,length-1)])
            opt = str("%.2f" % opt)
            options.append(opt)
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
list_of_json_object.clear()
median(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'What is the median height of the set of given elephants ? 6 50 50 11 15 46 26 48 25 19 50 18 18 29 33 31 42 24 35 22 46 16 23 49 26 29 6 8 20 40 5 20 ', 'answer': '25.50', 'options': ['25.50', '25.00', '19.00', '6.00', '46.00']}, {'question': 'What is the median area of the set of given elephants ? 42 28 35 39 27 15 29 38 14 9 32 29 29 41 44 21 10 7 21 49 4 46 5 15 22 37 45 7 14 47 42 28 35 2 5 47 46 5 ', 'answer': '28.50', 'options': ['22.00', '5.00', '15.00', '28.00', '28.50']}, {'question': 'What is the median length of the set of given kangaroos ? 48 39 12 45 5 40 26 2 23 36 1 38 18 5 10 30 41 4 13 1 32 31 16 37 44 9 21 13 5 25 44 2 46 35 22 27 37 1 5 14 15 26 22 45 49 44 43 28 ', 'answer': '25.50', 'options': ['2.00', '9.00', '25.50', '36.00', '37.00']}, {'question': 'What is the median height of the set of given human ? 22 19 36 35 29 13 16 46 49 8 41 43 36 30 6 27 50 37 50 6 5 29 6 22 16 3 41 22 38 5 29 10 10 33 35 22 37 ', 'answer': '29.00', 'options': ['36.00', '43.00', '29.00', '50.00', '43.00']}, {'question': 'What is the median height of the set of given tigers ? 23 26 17 6 50 50 48 48 31 37 50 1 23 3 19 29 9 12 8 40 40 30 20 27 26 8 24 3 30 14 40 40 25 ', 'answer': '26.00', 'options': ['14.00', '26.00', '31.00', '9.00', '30.00']}, {'question': 'What is the median length of the set of given human ? 36 21 9 43 34 10 17 1 10 10 16 34 20 30 45 25 15 38 9 29 29 7 25 7 35 47 50 34 46 7 45 23 33 31 44 48 34 8 21 1 32 32 4 2 2 17 14 32 33 ', 'answer': '25.00', 'options': ['36.00', '25.00', '43.00', '25.00', '7.00']}, {'question': 'What is the median weight of the set of given dogs ? 12 6 33 50 41 41 24 7 26 38 3 11 12 42 46 ', 'answer': '26.00', 'options': ['38.00', '26.00', '3.00', '41.00', '12.00']}, {'question': 'What is the median area of the set of given human ? 9 2 7 50 7 11 47 13 22 16 21 45 47 33 16 47 50 11 8 39 43 7 18 22 7 13 11 18 12 49 44 9 22 7 9 8 45 ', 'answer': '16.00', 'options': ['16.00', '47.00', '7.00', '7.00', '44.00']}, {'question': 'What is the median length of the set of given elephants ? 12 49 28 16 39 12 5 45 33 1 24 9 11 27 1 38 36 16 ', 'answer': '20.00', 'options': ['27.00', '16.00', '20.00', '49.00', '45.00']}, {'question': 'What is the median height of the set of given dogs ? 20 45 24 23 6 10 42 49 40 50 26 33 24 1 33 24 25 39 13 38 21 48 50 34 15 10 6 32 37 19 5 18 29 30 8 3 39 34 10 20 44 8 47 17 48 48 ', 'answer': '25.50', 'options': ['25.50', '33.00', '34.00', '21.00', '10.00']}, {'question': 'What is the median length of the set of given kangaroos ? 8 21 36 24 20 4 28 ', 'answer': '21.00', 'options': ['28.00', '21.00', '28.00', '36.00', '36.00']}, {'question': 'What is the median weight of the set of given martians ? 17 10 26 44 14 28 50 33 41 44 44 30 24 49 44 38 10 46 32 2 45 32 36 11 30 ', 'answer': '32.00', 'options': ['32.00', '10.00', '17.00', '11.00', '32.00']}, {'question': 'What is the median area of the set of given elephants ? 41 41 35 31 18 ', 'answer': '35.00', 'options': ['41.00', '18.00', '35.00', '18.00', '35.00']}, {'question': 'What is the median height of the set of given kangaroos ? 34 49 18 4 23 22 28 3 14 ', 'answer': '22.00', 'options': ['28.00', '22.00', '14.00', '49.00', '23.00']}, {'question': 'What is the median height of the set of given elephants ? 12 24 6 9 43 28 17 5 18 12 5 50 32 19 16 26 18 23 3 38 13 27 4 34 18 7 19 38 19 ', 'answer': '18.00', 'options': ['18.00', '23.00', '18.00', '6.00', '34.00']}, {'question': 'What is the median area of the set of given kangaroos ? 10 43 13 5 13 32 46 34 45 27 37 50 16 26 12 42 46 29 21 41 11 33 39 9 4 7 41 15 43 27 19 16 4 29 18 38 36 29 32 38 36 2 10 33 7 10 ', 'answer': '28.00', 'options': ['28.00', '26.00', '29.00', '33.00', '38.00']}, {'question': 'What is the median size of the set of given martians ? 45 6 1 40 14 9 29 14 8 45 16 12 15 21 24 48 6 16 14 15 15 45 28 17 19 49 44 32 27 11 49 34 17 24 34 31 50 15 20 11 ', 'answer': '19.50', 'options': ['49.00', '19.50', '24.00', '16.00', '15.00']},  ...

# %%
def general_physics_air(list_of_json_object):
    objects = {"water":"1496","wood":"3960","glass":"5640","aluminium":"6420","mercury":"1540","antimony":"3400","Beryllium":"12890","Bismut":"2180","Brass":"4700","Brick":"4200","cadmium":"2780","concrete":"3700","constantan":"5177","copper annealed":"4760","copper rolled":"5010","cork":"518","diamond":"12000","duralumin":"6320","glass silicate flint":"3980","glass light crown":"5100","glass pyrex":"5640","gold":"3240","granite":"5950","iridium":"4790","iron cast":"4994","iron electrolytic":"5950","ivory":"3010","lead annealed":"2160","lead rolled":"1960","lucite":"2680","magnesium annealed":"5770","manganese":"4660","marbel":"3810","molybdenum":"6250","monel":"5350","nickel":"6040","nylon":"2620","platinum":"3260","Polyethylene":"1250","Polystyrene":"2350","rubber butyl":"1830","rubber gum":"1550","rubber neoprene":"1600","silica fused":"5968","silver":"3650","slate":"4510","steel":"5940","stainless steel":"5790","tantalium":"3350","tin rolled":"3320","titanium":"6070","annealed tungsten":"5220","drawn tungsten":"5410","tungsten carbide":"6655","zinc rolled":"4210"}
    key_list = list(objects.keys()) 
    #print(len(key_list))
    val_list = list(objects.values())
    ref_air = {"air":"343"}
    template = "Sound travels slower in lighter medium than solids.The speed of sound in $1 is $2. What is the speed of sound in air?"
    duplicity = 100
    while duplicity > 0:
        template_obj = {}
        medium = random.randint(0,54)
        template_question = raplace_parameters(template,[key_list[medium],val_list[medium]])
        template_obj["question"] = template_question
        template_obj["answer"] = str(ref_air["air"])
        question_options = []
        question_options.append(str(ref_air["air"]))
        for i in range(4):
            question_options.append(str(random.randint(344,15000)))
        random.shuffle(question_options)
        template_obj["options"] = question_options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
list_of_json_object.clear()
general_physics_air(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'Sound travels slower in lighter medium than solids.The speed of sound in silica fused is 5968. What is the speed of sound in air?', 'answer': '343', 'options': ['4403', '9257', '343', '9232', '8739']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in wood is 3960. What is the speed of sound in air?', 'answer': '343', 'options': ['14827', '9961', '343', '11155', '11815']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in rubber butyl is 1830. What is the speed of sound in air?', 'answer': '343', 'options': ['5203', '6751', '12953', '343', '10574']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in ivory is 3010. What is the speed of sound in air?', 'answer': '343', 'options': ['10974', '13759', '343', '1102', '3731']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in concrete is 3700. What is the speed of sound in air?', 'answer': '343', 'options': ['343', '3620', '910', '10160', '8508']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in rubber neoprene is 1600. What is the speed of sound in air?', 'answer': '343', 'options': ['10282', '6609', '11033', '343', '5406']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in glass light crown is 5100. What is the speed of sound in air?', 'answer': '343', 'options': ['10304', '7058', '12010', '10688', '343']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in tin rolled is 3320. What is the speed of sound in air?', 'answer': '343', 'options': ['7617', '1597', '8621', '6024', '343']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in cork is 518. What is the speed of sound in air?', 'answer': '343', 'options': ['6151', '5012', '415', '8784', '343']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in water is 1496. What is the speed of sound in air?', 'answer': '343', 'options': ['13749', '1736', '8329', '343', '8812']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in silver is 3650. What is the speed of sound in air?', 'answer': '343', 'options': ['9788', '343', '7741', '581', '8948']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in iron electrolytic is 5950. What is the speed of sound in air?', 'answer': '343', 'options': ['1039', '10217', '7355', '695', '343']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in granite is 5950. What is the speed of sound in air?', 'answer': '343', 'options': ['463', '6714', '14808', '343', '14723']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in lead annealed is 2160. What is the speed of sound in air?', 'answer': '343', 'options': ['8419', '6165', '343', '13996', '8124']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in tantalium is 3350. What is the speed of sound in air?', 'answer': '343', 'options': ['8484', '2950', '7836', '343', '1614']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in Polyethylene is 1250. What is the speed of sound in air?', 'answer': '343', 'options': ['343', '11902', '3036', '777', '13544']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in Polyethylene is 1250. What is the speed of sound in air?', 'answer': '343', 'options': ['6800', '7283', '5879', '4581', '343']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in granite is 5950. What is the speed of sound in air?', 'answer': '343', 'options': ['343', '12862', '12397', '10482', '12266']}, {'question': 'Sound travels slower in lighter medium than solids.The speed of sound in cork is 518. What is the speed of sound in air?' ...

# %%
#calories stronger
def calories_high(list_of_json_object):
    template = "$1 consumes $2 calories per day. He/She is $3 years old. $4 is $5 years old. How much calories should $6 consume?"
    duplicity = 250
    while duplicity>0:
        template_obj = {}
        options = []
        younger_name = names[random.randint(0,500)]
        older_name = names[random.randint(501,999)]
        younger_food_calories = (random.randint(500,1000))
        younger_age = random.randint(1,15)
        older_age = random.randint(20,40)
        template_question = raplace_parameters(template,[younger_name,younger_food_calories,younger_age,older_name,older_age,older_name])
        template_obj["question"] = template_question
        answer = younger_food_calories*2
        template_obj["answer"] = answer
        options.append(answer)
        for i in range(1,5):
            options.append(int(younger_food_calories/(i+1))+random.randint(10,50))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
list_of_json_object.clear()
calories_high(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'Lucas consumes 911 calories per day. He/She is 15 years old. Mordechai is 29 years old. How much calories should Mordechai consume?', 'answer': 1822, 'options': [335, 1822, 480, 195, 248]}, {'question': 'Omari consumes 692 calories per day. He/She is 2 years old. Jerome is 40 years old. How much calories should Jerome consume?', 'answer': 1384, 'options': [241, 359, 189, 1384, 149]}, {'question': 'Rowan consumes 519 calories per day. He/She is 10 years old. Ernesto is 22 years old. How much calories should Ernesto consume?', 'answer': 1038, 'options': [290, 212, 141, 1038, 148]}, {'question': 'Lawrence consumes 936 calories per day. He/She is 9 years old. Reginald is 26 years old. How much calories should Reginald consume?', 'answer': 1872, 'options': [494, 248, 217, 1872, 342]}, {'question': 'Kane consumes 555 calories per day. He/She is 9 years old. Rayden is 23 years old. How much calories should Rayden consume?', 'answer': 1110, 'options': [155, 230, 180, 1110, 300]}, {'question': 'Gavin consumes 924 calories per day. He/She is 2 years old. Eliseo is 25 years old. How much calories should Eliseo consume?', 'answer': 1848, 'options': [487, 206, 340, 252, 1848]}, {'question': 'Waylon consumes 753 calories per day. He/She is 14 years old. Baker is 22 years old. How much calories should Baker consume?', 'answer': 1506, 'options': [1506, 270, 235, 387, 190]}, {'question': 'Myles consumes 807 calories per day. He/She is 4 years old. Nikolas is 20 years old. How much calories should Nikolas consume?', 'answer': 1614, 'options': [295, 224, 1614, 191, 422]}, {'question': 'Gunnar consumes 821 calories per day. He/She is 8 years old. Jagger is 38 years old. How much calories should Jagger consume?', 'answer': 1642, 'options': [1642, 420, 287, 175, 232]}, {'question': 'Cade consumes 772 calories per day. He/She is 14 years old. Talon is 29 years old. How much calories should Talon consume?', 'answer': 1544, 'options': [285, 405, 186, 227, 1544]}, {'question': 'Calvin consumes 760 calories per day. He/She is 13 years old. Ben is 28 years old. How much calories should Ben consume?', 'answer': 1520, 'options': [239, 290, 395, 1520, 201]}, {'question': 'Malachi consumes 688 calories per day. He/She is 13 years old. Neil is 35 years old. How much calories should Neil consume?', 'answer': 1376, 'options': [184, 388, 275, 1376, 185]}, {'question': 'Kason consumes 817 calories per day. He/She is 3 years old. Quentin is 24 years old. How much calories should Quentin consume?', 'answer': 1634, 'options': [458, 187, 311, 242, 1634]}, {'question': 'Kyler consumes 759 calories per day. He/She is 6 years old. Howard is 29 years old. How much calories should Howard consume?', 'answer': 1518, 'options': [1518, 403, 174, 290, 233]}, {'question': 'Gael consumes 649 calories per day. He/She is 2 years old. Wallace is 21 years old. How much calories should Wallace consume?', 'answer': 1298, 'options': [142, 340, 199, 1298, 240]}, {'question': 'Mason consumes 617 calories per day. He/She is 5 years old. Lucian is 35 years old. How much calories should Lucian consume?', 'answer': 1234, 'options': [172, 1234, 201, 226, 327]}, {'question': 'Tanner consumes 578 calories per day. He/She is 8 years old. Marlon is 27 years old. How much calories should Marlon consume?', 'answer': 1156, 'options': [1156, 148, 330, 161, 240]}, {'question': 'Tobias consumes 698 calories per day. He/She is 14 years old. Ishaan is 23 years old. How much calories should Ishaan consume?', 'answer': 1396, 'options': [393, 212, 1396, 172, 268]}, {'question': 'Arthur consumes 798 calories per day. He/She is 12 years old. Jaxx is 28 years old. How much calories should Jaxx consume?', 'answer': 1596, 'options': [430, 285, 231, 1596, 193]}, {'question': 'Pierce consumes 601 calories per day. He/She is 3 years old. Zev is 23 years old. How much calories should Zev consume?', 'answer': 1202, 'options': [177, 313, 1202, 158, 228]}, {'question': 'Archer consumes 807 calories per d ...

# %%
#calories age
def calories_tf(list_of_json_object):
    template = "Both $1 and $2 are of same age. Both do same physical activity. $3 consumes $4 calories per day whereas $5 consumes $6 calories per day. $7 is $8 than $9."
    duplicity = 250
    while duplicity > 0:
        template_obj = {}
        person_one = names[random.randint(0,500)]
        person_two = names[random.randint(500,999)]
        person_one_calories = random.randint(1500,3000)
        person_two_calories = random.randint(1500,3000)
        verb = ["bulkier","heavier","stronger","more weight"]
        question = raplace_parameters(template,[person_one,person_two,person_one,person_one_calories,person_two,person_two_calories,person_one,verb[random.randint(0,3)],person_two])
        template_obj["question"] = question
        options = ["True","False","Can't say"]
        random.shuffle(options)
        template_obj["options"] = options
        if person_one_calories==person_two_calories:
            template_obj["answer"] = "Can't say"
        else:
            template_obj["answer"] = True if person_one_calories > person_two_calories else False
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
list_of_json_object.clear()
calories_tf(list_of_json_object)
print(list_of_json_object)
# Out:
# [{'question': 'Both Zane and Keaton are of same age. Both do same physical activity. Zane consumes 2896 calories per day whereas Keaton consumes 2623 calories per day. Zane is more weight than Keaton.', 'options': ['false', "can't say", 'true'], 'answer': True}, {'question': 'Both Ezra and Dangelo are of same age. Both do same physical activity. Ezra consumes 2670 calories per day whereas Dangelo consumes 1613 calories per day. Ezra is heavier than Dangelo.', 'options': ["can't say", 'true', 'false'], 'answer': True}, {'question': 'Both Ari and Judson are of same age. Both do same physical activity. Ari consumes 2884 calories per day whereas Judson consumes 2506 calories per day. Ari is heavier than Judson.', 'options': ['true', 'false', "can't say"], 'answer': True}, {'question': 'Both Mathias and Briggs are of same age. Both do same physical activity. Mathias consumes 2279 calories per day whereas Briggs consumes 2527 calories per day. Mathias is more weight than Briggs.', 'options': ['false', "can't say", 'true'], 'answer': False}, {'question': 'Both Conner and Yael are of same age. Both do same physical activity. Conner consumes 1889 calories per day whereas Yael consumes 2332 calories per day. Conner is heavier than Yael.', 'options': ["can't say", 'true', 'false'], 'answer': False}, {'question': 'Both Jaxton and Mohammed are of same age. Both do same physical activity. Jaxton consumes 2827 calories per day whereas Mohammed consumes 2944 calories per day. Jaxton is stronger than Mohammed.', 'options': ["can't say", 'false', 'true'], 'answer': False}, {'question': 'Both Sawyer and Zaire are of same age. Both do same physical activity. Sawyer consumes 2728 calories per day whereas Zaire consumes 1876 calories per day. Sawyer is more weight than Zaire.', 'options': ["can't say", 'true', 'false'], 'answer': True}, {'question': 'Both Zayden and Braden are of same age. Both do same physical activity. Zayden consumes 2460 calories per day whereas Braden consumes 2327 calories per day. Zayden is stronger than Braden.', 'options': ['false', 'true', "can't say"], 'answer': True}, {'question': 'Both Brody and Avi are of same age. Both do same physical activity. Brody consumes 2037 calories per day whereas Avi consumes 2106 calories per day. Brody is stronger than Avi.', 'options': ['false', "can't say", 'true'], 'answer': False}, {'question': 'Both Ari and Kellan are of same age. Both do same physical activity. Ari consumes 2444 calories per day whereas Kellan consumes 1539 calories per day. Ari is stronger than Kellan.', 'options': ['false', 'true', "can't say"], 'answer': True}, {'question': 'Both Rowan and Case are of same age. Both do same physical activity. Rowan consumes 2995 calories per day whereas Case consumes 2768 calories per day. Rowan is bulkier than Case.', 'options': ['false', 'true', "can't say"], 'answer': True}, {'question': 'Both Colin and Ridge are of same age. Both do same physical activity. Colin consumes 1617 calories per day whereas Ridge consumes 1990 calories per day. Colin is heavier than Ridge.', 'options': ["can't say", 'true', 'false'], 'answer': False}, {'question': 'Both Kieran and Yehuda are of same age. Both do same physical activity. Kieran consumes 2905 calories per day whereas Yehuda consumes 1835 calories per day. Kieran is bulkier than Yehuda.', 'options': ["can't say", 'true', 'false'], 'answer': True}, {'question': 'Both Milo and Sylas are of same age. Both do same physical activity. Milo consumes 2073 calories per day whereas Sylas consumes 2497 calories per day. Milo is stronger than Sylas.', 'options': ['false', 'true', "can't say"], 'answer': False}, {'question': 'Both Malcolm and Samir are of same age. Both do same physical activity. Malcolm consumes 1826 calories per day whereas Samir consumes 1998 calories per day. Malcolm is stronger than Samir.', 'options': ['false', 'true', "can't say"], 'answer': False}, {'question': 'Both Austin and Lennon are of same age. Both do same physical a ...

# %%
#double

# %%
#snail
