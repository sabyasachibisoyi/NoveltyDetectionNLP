# %%
import random
import math

# %%
list_of_json_object = []

# %%
names = ["Liam", "Noah", "William", "James", "Oliver", "Benjamin", "Elijah", "Lucas", "Mason", "Logan", "Alexander", "Ethan", "Jacob", "Michael", "Daniel", "Henry", "Jackson", "Sebastian", "Aiden", "Matthew", "Samuel", "David", "Joseph", "Carter", "Owen", "Wyatt", "John", "Jack", "Luke", "Jayden", "Dylan", "Grayson", "Levi", "Isaac", "Gabriel", "Julian", "Mateo", "Anthony", "Jaxon", "Lincoln", "Joshua", "Christopher", "Andrew", "Theodore", "Caleb", "Ryan", "Asher", "Nathan", "Thomas", "Leo", "Isaiah", "Charles", "Josiah", "Hudson", "Christian", "Hunter", "Connor", "Eli", "Ezra", "Aaron", "Landon", "Adrian", "Jonathan", "Nolan", "Jeremiah", "Easton", "Elias", "Colton", "Cameron", "Carson", "Robert", "Angel", "Maverick", "Nicholas", "Dominic", "Jaxson", "Greyson", "Adam", "Ian", "Austin", "Santiago", "Jordan", "Cooper", "Brayden", "Roman", "Evan", "Ezekiel", "Xavier", "Jose", "Jace", "Jameson", "Leonardo", "Bryson", "Axel", "Everett", "Parker", "Kayden", "Miles", "Sawyer", "Jason", "Declan", "Weston", "Micah", "Ayden", "Wesley", "Luca", "Vincent", "Damian", "Zachary", "Silas", "Gavin", "Chase", "Kai", "Emmett", "Harrison", "Nathaniel", "Kingston", "Cole", "Tyler", "Bennett", "Bentley", "Ryker", "Tristan", "Brandon", "Kevin", "Luis", "George", "Ashton", "Rowan", "Braxton", "Ryder", "Gael", "Ivan", "Diego", "Maxwell", "Max", "Carlos", "Kaiden", "Juan", "Maddox", "Justin", "Waylon", "Calvin", "Giovanni", "Jonah", "Abel", "Jayce", "Jesus", "Amir", "King", "Beau", "Camden", "Alex", "Jasper", "Malachi", "Brody", "Jude", "Blake", "Emmanuel", "Eric", "Brooks", "Elliot", "Antonio", "Abraham", "Timothy", "Finn", "Rhett", "Elliott", "Edward", "August", "Xander", "Alan", "Dean", "Lorenzo", "Bryce", "Karter", "Victor", "Milo", "Miguel", "Hayden", "Graham", "Grant", "Zion", "Tucker", "Jesse", "Zayden", "Joel", "Richard", "Patrick", "Emiliano", "Avery", "Nicolas", "Brantley", "Dawson", "Myles", "Matteo", "River", "Steven", "Thiago", "Zane", "Matias", "Judah", "Messiah", "Jeremy", "Preston", "Oscar", "Kaleb", "Alejandro", "Marcus", "Mark", "Peter", "Maximus", "Barrett", "Jax", "Andres", "Holden", "Legend", "Charlie", "Knox", "Kaden", "Paxton", "Kyrie", "Kyle", "Griffin", "Josue", "Kenneth", "Beckett", "Enzo", "Adriel", "Arthur", "Felix", "Bryan", "Lukas", "Paul", "Brian", "Colt", "Caden", "Leon", "Archer", "Omar", "Israel", "Aidan", "Theo", "Javier", "Remington", "Jaden", "Bradley", "Emilio", "Colin", "Riley", "Cayden", "Phoenix", "Clayton", "Simon", "Ace", "Nash", "Derek", "Rafael", "Zander", "Brady", "Jorge", "Jake", "Louis", "Damien", "Karson", "Walker", "Maximiliano", "Amari", "Sean", "Chance", "Walter", "Martin", "Finley", "Andre", "Tobias", "Cash", "Corbin", "Arlo", "Iker", "Erick", "Emerson", "Gunner", "Cody", "Stephen", "Francisco", "Killian", "Dallas", "Reid", "Manuel", "Lane", "Atlas", "Rylan", "Jensen", "Ronan", "Beckham", "Daxton", "Anderson", "Kameron", "Raymond", "Orion", "Cristian", "Tanner", "Kyler", "Jett", "Cohen", "Ricardo", "Spencer", "Gideon", "Ali", "Fernando", "Jaiden", "Titus", "Travis", "Bodhi", "Eduardo", "Dante", "Ellis", "Prince", "Kane", "Luka", "Kash", "Hendrix", "Desmond", "Donovan", "Mario", "Atticus", "Cruz", "Garrett", "Hector", "Angelo", "Jeffrey", "Edwin", "Cesar", "Zayn", "Devin", "Conor", "Warren", "Odin", "Jayceon", "Romeo", "Julius", "Jaylen", "Hayes", "Kayson", "Muhammad", "Jaxton", "Joaquin", "Caiden", "Dakota", "Major", "Keegan", "Sergio", "Marshall", "Johnny", "Kade", "Edgar", "Leonel", "Ismael", "Marco", "Tyson", "Wade", "Collin", "Troy", "Nasir", "Conner", "Adonis", "Jared", "Rory", "Andy", "Jase", "Lennox", "Shane", "Malik", "Ari", "Reed", "Seth", "Clark", "Erik", "Lawson", "Trevor", "Gage", "Nico", "Malakai", "Quinn", "Cade", "Johnathan", "Sullivan", "Solomon", "Cyrus", "Fabian", "Pedro", "Frank", "Shawn", "Malcolm", "Khalil", "Nehemiah", "Dalton", "Mathias", "Jay", "Ibrahim", "Peyton", "Winston", "Kason", "Zayne", "Noel", "Princeton", "Matthias", "Gregory", "Sterling", "Dominick", "Elian", "Grady", "Russell", "Finnegan", "Ruben", "Gianni", "Porter", "Kendrick", "Leland", "Pablo", "Allen", "Hugo", "Raiden", "Kolton", "Remy", "Ezequiel", "Damon", "Emanuel", "Zaiden", "Otto", "Bowen", "Marcos", "Abram", "Kasen", "Franklin", "Royce", "Jonas", "Sage", "Philip", "Esteban", "Drake", "Kashton", "Roberto", "Harvey", "Alexis", "Kian", "Jamison", "Maximilian", "Adan", "Milan", "Phillip", "Albert", "Dax", "Mohamed", "Ronin", "Kamden", "Hank", "Memphis", "Oakley", "Augustus", "Drew", "Moises", "Armani", "Rhys", "Benson", "Jayson", "Kyson", "Braylen", "Corey", "Gunnar", "Omari", "Alonzo", "Landen", "Armando", "Derrick", "Dexter", "Enrique", "Bruce", "Nikolai", "Francis", "Rocco", "Kairo", "Royal", "Zachariah", "Arjun", "Deacon", "Skyler", "Eden", "Alijah", "Rowen", "Pierce", "Uriel", "Ronald", "Luciano", "Tate", "Frederick", "Kieran", "Lawrence", "Moses", "Rodrigo", "Brycen", "Leonidas", "Nixon", "Keith", "Chandler", "Case", "Davis", "Asa", "Darius", "Isaias", "Aden", "Jaime", "Landyn", "Raul", "Niko", "Trenton", "Apollo", "Cairo", "Izaiah", "Scott", "Dorian", "Julio", "Wilder", "Santino", "Dustin", "Donald", "Raphael", "Saul", "Taylor", "Ayaan", "Duke", "Ryland", "Tatum", "Ahmed", "Moshe", "Edison", "Emmitt", "Cannon", "Alec", "Danny", "Keaton", "Roy", "Conrad", "Roland", "Quentin", "Lewis", "Samson", "Brock", "Kylan", "Cason", "Ahmad", "Jalen", "Nikolas", "Braylon", "Kamari", "Dennis", "Callum", "Justice", "Soren", "Rayan", "Aarav", "Gerardo", "Ares", "Brendan", "Jamari", "Kaison", "Yusuf", "Issac", "Jasiah", "Callen", "Forrest", "Makai", "Crew", "Kobe", "Bo", "Julien", "Mathew", "Braden", "Johan", "Marvin", "Zaid", "Stetson", "Casey", "Ty", "Ariel", "Tony", "Zain", "Callan", "Cullen", "Sincere", "Uriah", "Dillon", "Kannon", "Colby", "Axton", "Cassius", "Quinton", "Mekhi", "Reece", "Alessandro", "Jerry", "Mauricio", "Sam", "Trey", "Mohammad", "Alberto", "Gustavo", "Arturo", "Fletcher", "Marcelo", "Abdiel", "Hamza", "Alfredo", "Chris", "Finnley", "Curtis", "Kellan", "Quincy", "Kase", "Harry", "Kyree", "Wilson", "Cayson", "Hezekiah", "Kohen", "Neil", "Mohammed", "Raylan", "Kaysen", "Lucca", "Sylas", "Mack", "Leonard", "Lionel", "Ford", "Roger", "Rex", "Alden", "Boston", "Colson", "Briggs", "Zeke", "Dariel", "Kingsley", "Valentino", "Jamir", "Salvador", "Vihaan", "Mitchell", "Lance", "Lucian", "Darren", "Jimmy", "Alvin", "Amos", "Tripp", "Zaire", "Layton", "Reese", "Casen", "Colten", "Brennan", "Korbin", "Sonny", "Bruno", "Orlando", "Devon", "Huxley", "Boone", "Maurice", "Nelson", "Douglas", "Randy", "Gary", "Lennon", "Titan", "Denver", "Jaziel", "Noe", "Jefferson", "Ricky", "Lochlan", "Rayden", "Bryant", "Langston", "Lachlan", "Clay", "Abdullah", "Lee", "Baylor", "Leandro", "Ben", "Kareem", "Layne", "Joe", "Crosby", "Deandre", "Demetrius", "Kellen", "Carl", "Jakob", "Ridge", "Bronson", "Jedidiah", "Rohan", "Larry", "Stanley", "Tomas", "Shiloh", "Thaddeus", "Watson", "Baker", "Vicente", "Koda", "Jagger", "Nathanael", "Carmelo", "Shepherd", "Graysen", "Melvin", "Ernesto", "Jamie", "Yosef", "Clyde", "Eddie", "Tristen", "Grey", "Ray", "Tommy", "Samir", "Ramon", "Santana", "Kristian", "Marcel", "Wells", "Zyaire", "Brecken", "Byron", "Otis", "Reyansh", "Axl", "Joey", "Trace", "Morgan", "Musa", "Harlan", "Enoch", "Henrik", "Kristopher", "Talon", "Rey", "Guillermo", "Houston", "Jon", "Vincenzo", "Dane", "Terry", "Azariah", "Castiel", "Kye", "Augustine", "Zechariah", "Joziah", "Kamryn", "Hassan", "Jamal", "Chaim", "Bodie", "Emery", "Branson", "Jaxtyn", "Kole", "Wayne", "Aryan", "Alonso", "Brixton", "Madden", "Allan", "Flynn", "Jaxen", "Harley", "Magnus", "Sutton", "Dash", "Anders", "Westley", "Brett", "Emory", "Felipe", "Yousef", "Jadiel", "Mordechai", "Dominik", "Junior", "Eliseo", "Fisher", "Harold", "Jaxxon", "Kamdyn", "Maximo", "Caspian", "Kelvin", "Damari", "Fox", "Trent", "Hugh", "Briar", "Franco", "Keanu", "Terrance", "Yahir", "Ameer", "Kaiser", "Thatcher", "Ishaan", "Koa", "Merrick", "Coen", "Rodney", "Brayan", "London", "Rudy", "Gordon", "Bobby", "Aron", "Marc", "Van", "Anakin", "Canaan", "Dario", "Reginald", "Westin", "Darian", "Ledger", "Leighton", "Maxton", "Tadeo", "Valentin", "Aldo", "Khalid", "Nickolas", "Toby", "Dayton", "Jacoby", "Billy", "Gatlin", "Elisha", "Jabari", "Jermaine", "Alvaro", "Marlon", "Mayson", "Blaze", "Jeffery", "Kace", "Braydon", "Achilles", "Brysen", "Saint", "Xzavier", "Aydin", "Eugene", "Adrien", "Cain", "Kylo", "Nova", "Onyx", "Arian", "Bjorn", "Jerome", "Miller", "Alfred", "Kenzo", "Kyng", "Leroy", "Maison", "Jordy", "Stefan", "Wallace", "Benicio", "Kendall", "Zayd", "Blaine", "Tristian", "Anson", "Gannon", "Jeremias", "Marley", "Ronnie", "Dangelo", "Kody", "Will", "Bentlee", "Gerald", "Salvatore", "Turner", "Chad", "Misael", "Mustafa", "Konnor", "Maxim", "Rogelio", "Zakai", "Cory", "Judson", "Brentley", "Darwin", "Louie", "Ulises", "Dakari", "Rocky", "Wesson", "Alfonso", "Payton", "Dwayne", "Juelz", "Duncan", "Keagan", "Deshawn", "Bode", "Bridger", "Skylar", "Brodie", "Landry", "Avi", "Keenan", "Reuben", "Jaxx", "Rene", "Yehuda", "Imran", "Yael", "Alexzander", "Willie", "Cristiano", "Heath", "Lyric", "Davion", "Elon", "Karsyn", "Krew", "Jairo", "Maddux", "Ephraim", "Ignacio", "Vivaan", "Aries", "Vance", "Boden", "Lyle", "Ralph", "Reign", "Camilo", "Draven", "Terrence", "Idris", "Ira", "Javion", "Jericho", "Khari", "Marcellus", "Creed", "Shepard", "Terrell", "Ahmir", "Camdyn", "Cedric", "Howard", "Jad", "Zahir", "Harper", "Justus", "Forest", "Gibson", "Zev", "Alaric", "Decker", "Ernest", "Jesiah", "Torin", "Benedict", "Bowie", "Deangelo", "Genesis", "Harlem", "Kalel", "Kylen", "Bishop", "Immanuel", "Lian", "Zavier", "Archie", "Davian", "Gus", "Kabir", "Korbyn", "Randall", "Benton", "Coleman", "Markus"]

# %%
def create_params_mapping(temp_variables):
    param_dict = {}
    for i in range(len(temp_variables)):
        key = "$"+str(i+1)
        param_dict[key] = temp_variables[i]
    return param_dict

# %%
def raplace_parameters(template,temp_variables):
    param_dict = create_params_mapping(temp_variables)
    for key in param_dict:
        template = template.replace(key,str(param_dict[key]))
    return template

# %%
def physics_temperature(list_of_json_object):
    template = "The current temperature of the living room is $1 . We turned on the cooler for $2 minutes. What is the temperature after $3 minutes?"
    duplicity = 250
    while duplicity > 0:
        template_obj = {}
        options = []
        curr_temp = random.randint(50,121)
        time = random.randint(5,120)
        ans = random.randint(curr_temp-random.randint(2,20),curr_temp)
        template_obj["question"] = raplace_parameters(template,[curr_temp,time,time])
        template_obj["answer"] = ans
        options.append(ans)
        for i in range(4):
            options.append(random.randint(curr_temp+1,curr_temp+random.randint(2,40)))
        random.shuffle(options)
        template_obj["options"] = options
        duplicity-=1
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
#list_of_json_object.clear()
physics_temperature(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 35 minutes. What is the temperature after 35 minutes?',
#   'answer': 105,
#   'options': [123, 120, 116, 122, 105]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 87,
#   'options': [113, 97, 117, 87, 132]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 59,
#   'options': [91, 65, 73, 59, 61]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 89,
#   'options': [94, 104, 121, 89, 106]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 118 minutes. What is the temperature after 118 minutes?',
#   'answer': 106,
#   'options': [109, 106, 108, 111, 111]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 33 minutes. What is the temperature after 33 minutes?',
#   'answer': 94,
#   'options': [126, 118, 113, 94, 109]},
#  {'question': 'The current temperature of the living room is 93 . We turned on the cooler for 57 minutes. What is the temperature after 57 minutes?',
#   'answer': 93,
#   'options': [114, 97, 93, 112, 114]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 97,
#   'options': [97, 105, 103, 125, 106]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 92,
#   'options': [122, 123, 92, 106, 103]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 45,
#   'options': [76, 45, 53, 68, 55]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 62,
#   'options': [62, 63, 72, 66, 65]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 73,
#   'options': [82, 84, 97, 104, 73]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 118 minutes. What is the temperature after 118 minutes?',
#   'answer': 92,
#   'options': [92, 105, 96, 122, 114]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 101,
#   'options': [114, 132, 127, 101, 113]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 59,
#   'options': [76, 59, 61, 92, 87]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 94,
#   'options': [117, 94, 101, 117, 103]}]

# %%
def physics_temperature_heater(list_of_json_object):
    template = "The current temperature of the living room is $1 . We turned on the heater for $2 minutes. What is the temperature after $3 minutes?"
    duplicity = 250
    while duplicity > 0:
        template_obj = {}
        options = []
        curr_temp = random.randint(0,70)
        time = random.randint(5,120)
        ans = random.randint(curr_temp+1,curr_temp+random.randint(2,20))
        template_obj["question"] = raplace_parameters(template,[curr_temp,time,time])
        template_obj["answer"] = ans
        options.append(ans)
        for i in range(4):
            options.append(random.randint(curr_temp-random.randint(2,40),curr_temp-1))
        random.shuffle(options)
        template_obj["options"] = options
        duplicity-=1
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
#list_of_json_object.clear()
physics_temperature_heater(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'options': [36, 21, 41, 32, 48]},
#  {'question': 'The current temperature of the living room is 55 . We turned on the heater for 75 minutes. What is the temperature after 75 minutes?',
#   'answer': 60,
#   'options': [44, 49, 30, 45, 60]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the heater for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 75,
#   'options': [62, 75, 47, 58, 47]},
#  {'question': 'The current temperature of the living room is 41 . We turned on the heater for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 47,
#   'options': [39, 47, 40, 31, 37]},
#  {'question': 'The current temperature of the living room is 9 . We turned on the heater for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 15,
#   'options': [15, 1, 5, -7, -29]},
#  {'question': 'The current temperature of the living room is 43 . We turned on the heater for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 48,
#   'options': [38, 48, 19, 40, 16]},
#  {'question': 'The current temperature of the living room is 49 . We turned on the heater for 83 minutes. What is the temperature after 83 minutes?',
#   'answer': 53,
#   'options': [46, 48, 42, 45, 53]},
#  {'question': 'The current temperature of the living room is 6 . We turned on the heater for 56 minutes. What is the temperature after 56 minutes?',
#   'answer': 8,
#   'options': [2, -10, 8, -8, -1]},
#  {'question': 'The current temperature of the living room is 28 . We turned on the heater for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 42,
#   'options': [18, 42, 25, 13, 24]},
#  {'question': 'The current temperature of the living room is 26 . We turned on the heater for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 35,
#   'options': [16, 24, 22, 9, 35]},
#  {'question': 'The current temperature of the living room is 38 . We turned on the heater for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [36, 16, 31, 20, 51]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the heater for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 69,
#   'options': [56, 69, 60, 60, 53]},
#  {'question': 'The current temperature of the living room is 19 . We turned on the heater for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 24,
#   'options': [11, 24, 15, 18, -15]},
#  {'question': 'The current temperature of the living room is 43 . We turned on the heater for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 46,
#   'options': [40, 46, 36, 15, 36]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the heater for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 54,
#   'options': [37, 49, 54, 38, 49]},
#  {'question': 'The current temperature of the living room is 17 . We turned on the heater for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 26,
#   'options': [-7, 3, 26, 0, 10]},
#  {'question': 'The current temperature of the living room is 2 . We turned on the heater for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 6,
#   'options': [-14, 6, -14, -14, -3]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the heater for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 67,
#   'options': [60, 67, 40, 52, 57]},
#  {'question': 'The current temperature of the living room is 31 . We turned on the heater for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 32,
#   'options': [29, 32, 28, -5, 11]},
#  {'question': 'The current temperature of the living room is 34 . We turned on the heater for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 37,
#   'options': [22, 32, 17, 37, 28]},
#  {'question': 'The current temperature of the living room is 23 . We turned on the heater for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 26,
#   'options': [21, 16, 26, 15, 0]},
#  {'question': 'The current temperature of the living room is 6 . We turned on the heater for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 8,
#   'options': [0, 2, 3, -14, 8]},
#  {'question': 'The current temperature of the living room is 16 . We turned on the heater for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 34,
#   'options': [14, -18, 34, 11, -5]},
#  {'question': 'The current temperature of the living room is 44 . We turned on the heater for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 46,
#   'options': [40, 43, 37, 46, 22]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the heater for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 72,
#   'options': [52, 68, 69, 65, 72]},
#  {'question': 'The current temperature of the living room is 45 . We turned on the heater for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 57,
#   'options': [37, 17, 42, 26, 57]},
#  {'question': 'The current temperature of the living room is 12 . We turned on the heater for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 22,
#   'options': [-11, 5, 22, 10, 1]},
#  {'question': 'The current temperature of the living room is 15 . We turned on the heater for 59 minutes. What is the temperature after 59 minutes?',
#   'answer': 20,
#   'options': [9, -9, 20, -5, 13]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the heater for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 65,
#   'options': [60, 52, 56, 65, 46]},
#  {'question': 'The current temperature of the living room is 13 . We turned on the heater for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 14,
#   'options': [12, 14, 9, 8, -1]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the heater for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 69,
#   'options': [52, 69, 50, 42, 60]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the heater for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 72,
#   'options': [59, 62, 59, 61, 72]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the heater for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 82,
#   'options': [65, 82, 56, 49, 59]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the heater for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 67,
#   'options': [60, 62, 67, 58, 63]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the heater for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [49, 68, 51, 53, 44]},
#  {'question': 'The current temperature of the living room is 48 . We turned on the heater for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 51,
#   'options': [44, 43, 44, 32, 51]},
#  {'question': 'The current temperature of the living room is 35 . We turned on the heater for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 51,
#   'options': [15, 3, 13, 34, 51]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the heater for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 65,
#   'options': [65, 46, 48, 44, 32]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the heater for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 75,
#   'options': [75, 62, 61, 47, 60]},
#  {'question': 'The current temperature of the living room is 36 . We turned on the heater for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 40,
#   'options': [31, 40, 32, 31, 34]},
#  {'question': 'The current temperature of the living room is 27 . We turned on the heater for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 45,
#   'options': [45, 16, 18, 20, 26]},
#  {'question': 'The current temperature of the living room is 46 . We turned on the heater for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 50,
#   'options': [38, 43, 50, 38, 38]},
#  {'question': 'The current temperature of the living room is 13 . We turned on the heater for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 19,
#   'options': [2, 19, 10, 6, -13]},
#  {'question': 'The current temperature of the living room is 39 . We turned on the heater for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 47,
#   'options': [12, 37, 34, 47, 29]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the heater for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 77,
#   'options': [52, 56, 47, 77, 50]},
#  {'question': 'The current temperature of the living room is 36 . We turned on the heater for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 45,
#   'options': [31, 45, 16, 30, 8]},
#  {'question': 'The current temperature of the living room is 34 . We turned on the heater for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 38,
#   'options': [23, 38, 22, 12, 23]},
#  {'question': 'The current temperature of the living room is 10 . We turned on the heater for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 18,
#   'options': [18, -4, -1, -17, -28]},
#  {'question': 'The current temperature of the living room is 32 . We turned on the heater for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 49,
#   'options': [5, 49, 30, 16, 29]},
#  {'question': 'The current temperature of the living room is 29 . We turned on the heater for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 44,
#   'options': [21, 16, 44, 27, 13]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the heater for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 60,
#   'options': [54, 60, 56, 49, 54]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the heater for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 63,
#   'options': [61, 58, 63, 57, 46]},
#  {'question': 'The current temperature of the living room is 12 . We turned on the heater for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 25,
#   'options': [0, 25, 4, 9, -10]},
#  {'question': 'The current temperature of the living room is 9 . We turned on the heater for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 13,
#   'options': [-7, 13, -29, 7, -3]},
#  {'question': 'The current temperature of the living room is 15 . We turned on the heater for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 27,
#   'options': [-4, 14, 13, 27, 12]},
#  {'question': 'The current temperature of the living room is 3 . We turned on the heater for 35 minutes. What is the temperature after 35 minutes?',
#   'answer': 4,
#   'options': [1, -25, 4, -7, -1]},
#  {'question': 'The current temperature of the living room is 1 . We turned on the heater for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 9,
#   'options': [-25, -18, 9, -16, 0]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the heater for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 72,
#   'options': [47, 39, 48, 72, 31]},
#  {'question': 'The current temperature of the living room is 2 . We turned on the heater for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 5,
#   'options': [-1, -16, 5, -18, -5]},
#  {'question': 'The current temperature of the living room is 49 . We turned on the heater for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 54,
#   'options': [44, 36, 48, 41, 54]},
#  {'question': 'The current temperature of the living room is 11 . We turned on the heater for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 21,
#   'options': [-2, 21, 10, -7, -25]},
#  {'question': 'The current temperature of the living room is 23 . We turned on the heater for 35 minutes. What is the temperature after 35 minutes?',
#   'answer': 26,
#   'options': [12, 26, 20, 8, 6]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the heater for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 62,
#   'options': [31, 62, 48, 51, 30]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the heater for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 53,
#   'options': [53, 36, 21, 23, 48]},
#  {'question': 'The current temperature of the living room is 12 . We turned on the heater for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 15,
#   'options': [1, 15, 6, 11, -9]},
#  {'question': 'The current temperature of the living room is 6 . We turned on the heater for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 17,
#   'options': [-11, -7, -1, 17, -3]},
#  {'question': 'The current temperature of the living room is 20 . We turned on the heater for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 21,
#   'options': [-16, 11, 1, 21, -6]},
#  {'question': 'The current temperature of the living room is 43 . We turned on the heater for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 61,
#   'options': [42, 41, 40, 61, 31]},
#  {'question': 'The current temperature of the living room is 43 . We turned on the heater for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 47,
#   'options': [34, 37, 28, 47, 37]},
#  {'question': 'The current temperature of the living room is 8 . We turned on the heater for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 14,
#   'options': [0, -9, 3, 14, -15]},
#  {'question': 'The current temperature of the living room is 44 . We turned on the heater for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 49,
#   'options': [36, 49, 26, 26, 11]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the heater for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 69,
#   'options': [61, 65, 52, 69, 54]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the heater for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 68,
#   'options': [68, 53, 57, 57, 42]},
#  {'question': 'The current temperature of the living room is 10 . We turned on the heater for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 11,
#   'options': [6, -12, 8, 11, -12]},
#  {'question': 'The current temperature of the living room is 23 . We turned on the heater for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 24,
#   'options': [21, 6, 11, -11, 24]},
#  {'question': 'The current temperature of the living room is 28 . We turned on the heater for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 30,
#   'options': [0, 30, 27, 24, 16]},
#  {'question': 'The current temperature of the living room is 19 . We turned on the heater for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 25,
#   'options': [7, 25, 17, -5, 14]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the heater for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 67,
#   'options': [35, 53, 56, 67, 58]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the heater for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 53,
#   'options': [53, 39, 36, 46, 39]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the heater for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 56,
#   'options': [41, 47, 32, 49, 56]}]

# %%
def planet_orbits(list_of_json_object):
    planets = {"mercury":[223700000,3],"venus":[67200000,7],"earth":[93000000,12],"mars":[141600000,23],"jupiter":[483600000,142],"saturn":[886500000,354],"uranus":[1783700000,1009],"neptune":[2795200000,1979],"pluto":[3670100000,2977]}
    planet = ["mercury","venus","earth","mars","jupiter","saturn","uranus","neptune","pluto"]
    template = "The orbit of $1 around sun is $2 miles.It takes $3 earth months to orbit once around sun. How many days will it take $4 whose orbit is $5 miles to rotate once around the sun?"
    duplicity = 100
    while duplicity > 0:
        template_obj = {}
        options = []
        planet_1 = planet[random.randint(0,8)]
        planet_1_orbit = planets[planet_1][0]
        planet_1_rotation_period = planets[planet_1][1]
        planet_2 = planet[random.randint(0,8)]
        planet_2_orbit = planets[planet_2][0]
        planet_2_rotation_period = planets[planet_2][1]
        template_obj["question"] = raplace_parameters(template,[planet_1,planet_1_orbit,planet_1_rotation_period,planet_2,planet_2_orbit])
        template_obj["answer"] = str(planet_2_rotation_period)
        options.append(planet_2_rotation_period)
        if planet_2_orbit < planet_1_orbit:
            for i in range(4):
                options.append(random.randint(planet_1_rotation_period,2*planet_1_rotation_period))
        else:
            for i in range(4):
                options.append(random.randint(1,planet_1_rotation_period-1))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
planet_orbits(list_of_json_object)
#print(list_of_json_object)

# %%
def commonsense_carpet(list_of_json_object):
    template = "The size of my room is $1 * $2. Which carpet shoul I buy from $3?"
    ecommerce = ["amazon","flipkart","walmart","target"]
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        length = random.randint(30,60)
        breadth = random.randint(30,60)
        ecommerce_chooser = ecommerce[random.randint(0,3)]
        correct_answer = random.randint(0,4)
        temp_variables = [length,breadth,ecommerce_chooser]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        question_options = []
        for i in range(5):
            if i == correct_answer:
                ans_len = random.randint(int(length/2),length-1)
                ans_bre = random.randint(int(breadth/2),breadth-1)
                ans = str(ans_len)+"*"+str(ans_bre)
                template_obj["answer"] = ans
                question_options.append(ans)
            else:
                opt_len = random.randint(length+1,(length+1)*2)
                opt_bre = random.randint(breadth+1,(breadth+1)*2)
                opt = str(opt_len)+"*"+str(opt_bre)
                question_options.append(opt)
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
#list_of_json_object.clear()
commonsense_carpet(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'answer': '3',
#   'options': [1983, 1901, 1926, 1746, 3]},
#  {'question': 'The orbit of pluto around sun is 3670100000 miles.It takes 2977 earth months to orbit once around sun. How many days will it take mercury whose orbit is 223700000 miles to rotate once around the sun?',
#   'answer': '3',
#   'options': [5731, 3, 5003, 3761, 2999]},
#  {'question': 'The orbit of mercury around sun is 223700000 miles.It takes 3 earth months to orbit once around sun. How many days will it take mars whose orbit is 141600000 miles to rotate once around the sun?',
#   'answer': '23',
#   'options': [6, 23, 3, 3, 6]},
#  {'question': 'The orbit of jupiter around sun is 483600000 miles.It takes 142 earth months to orbit once around sun. How many days will it take mercury whose orbit is 223700000 miles to rotate once around the sun?',
#   'answer': '3',
#   'options': [238, 3, 275, 263, 240]},
#  {'question': 'The orbit of jupiter around sun is 483600000 miles.It takes 142 earth months to orbit once around sun. How many days will it take saturn whose orbit is 886500000 miles to rotate once around the sun?',
#   'answer': '354',
#   'options': [354, 21, 81, 84, 77]},
#  {'question': 'The orbit of mars around sun is 141600000 miles.It takes 23 earth months to orbit once around sun. How many days will it take pluto whose orbit is 3670100000 miles to rotate once around the sun?',
#   'answer': '2977',
#   'options': [12, 2977, 8, 1, 3]},
#  {'question': 'The orbit of mercury around sun is 223700000 miles.It takes 3 earth months to orbit once around sun. How many days will it take jupiter whose orbit is 483600000 miles to rotate once around the sun?',
#   'answer': '142',
#   'options': [2, 1, 2, 142, 2]},
#  {'question': 'The orbit of pluto around sun is 3670100000 miles.It takes 2977 earth months to orbit once around sun. How many days will it take pluto whose orbit is 3670100000 miles to rotate once around the sun?',
#   'answer': '2977',
#   'options': [2931, 690, 1583, 2977, 114]},
#  {'question': 'The orbit of mars around sun is 141600000 miles.It takes 23 earth months to orbit once around sun. How many days will it take pluto whose orbit is 3670100000 miles to rotate once around the sun?',
#   'answer': '2977',
#   'options': [2977, 5, 22, 7, 10]},
#  {'question': 'The orbit of earth around sun is 93000000 miles.It takes 12 earth months to orbit once around sun. How many days will it take mars whose orbit is 141600000 miles to rotate once around the sun?',
#   'answer': '23',
#   'options': [1, 6, 23, 4, 5]},
#  {'question': 'The orbit of mars around sun is 141600000 miles.It takes 23 earth months to orbit once around sun. How many days will it take venus whose orbit is 67200000 miles to rotate once around the sun?',
#   'answer': '7',
#   'options': [7, 24, 44, 26, 45]},
#  {'question': 'The orbit of venus around sun is 67200000 miles.It takes 7 earth months to orbit once around sun. How many days will it take mars whose orbit is 141600000 miles to rotate once around the sun?',
#   'answer': '23',
#   'options': [2, 1, 2, 23, 6]},
#  {'question': 'The orbit of neptune around sun is 2795200000 miles.It takes 1979 earth months to orbit once around sun. How many days will it take earth whose orbit is 93000000 miles to rotate once around the sun?',
#   'answer': '12',
#   'options': [12, 3799, 2762, 3096, 2416]},
#  {'question': 'The orbit of neptune around sun is 2795200000 miles.It takes 1979 earth months to orbit once around sun. How many days will it take saturn whose orbit is 886500000 miles to rotate once around the sun?',
#   'answer': '354',
#   'options': [2282, 354, 2814, 3304, 2972]},
#  {'question': 'The orbit of pluto around sun is 3670100000 miles.It takes 2977 earth months to orbit once around sun. How many days will it take venus whose orbit is 67200000 miles to rotate once around the sun?',
#   'answer': '7',
#   'options': [5650, 7, 4014, 4320, 5477]},
#  {'question': 'The orbit of neptune around sun is 2795200000 miles.It takes 1979 earth months to orbit once around sun. How many days will it take mercury whose orbit is 223700000 miles to rotate once around the sun?',
#   'answer': '3',
#   'options': [2158, 3248, 3032, 3, 3043]},
#  {'question': 'The orbit of saturn around sun is 886500000 miles.It takes 354 earth months to orbit once around sun. How many days will it take saturn whose orbit is 886500000 miles to rotate once around the sun?',
#   'answer': '354',
#   'options': [249, 24, 354, 94, 89]},
#  {'question': 'The orbit of uranus around sun is 1783700000 miles.It takes 1009 earth months to orbit once around sun. How many days will it take neptune whose orbit is 2795200000 miles to rotate once around the sun?',
#   'answer': '1979',
#   'options': [915, 941, 1979, 63, 779]},
#  {'question': 'The orbit of venus around sun is 67200000 miles.It takes 7 earth months to orbit once around sun. How many days will it take mars whose orbit is 141600000 miles to rotate once around the sun?',
#   'answer': '23',
#   'options': [1, 1, 23, 2, 1]},
#  {'question': 'The orbit of mercury around sun is 223700000 miles.It takes 3 earth months to orbit once around sun. How many days will it take uranus whose orbit is 1783700000 miles to rotate once around the sun?',
#   'answer': '1009',
#   'options': [1, 1, 1009, 1, 1]},
#  {'question': 'The orbit of saturn around sun is 886500000 miles.It takes 354 earth months to orbit once around sun. How many days will it take neptune whose orbit is 2795200000 miles to rotate once around the sun?',
#   'answer': '1979',
#   'options': [1979, 1, 60, 1, 230]},
#  {'question': 'The orbit of uranus around sun is 1783700000 miles.It takes 1009 earth months to orbit once around sun. How many days will it take uranus whose orbit is 1783700000 miles to rotate once around the sun?',
#   'answer': '1009',
#   'options': [273, 221, 472, 1009, 586]},
#  {'question': 'The orbit of earth around sun is 93000000 miles.It takes 12 earth months to orbit once around sun. How many days will it take mercury whose orbit is 223700000 miles to rotate once around the sun?',
#   'answer': '3',
#   'options': [5, 1, 5, 3, 4]},
#  {'question': 'The orbit of jupiter around sun is 483600000 miles.It takes 142 earth months to orbit once around sun. How many days will it take saturn whose orbit is 886500000 miles to rotate once around the sun?',
#   'answer': '354',
#   'options': [51, 354, 42, 82, 56]},
#  {'question': 'The orbit of pluto around sun is 3670100000 miles.It takes 2977 earth months to orbit once around sun. How many days will it take neptune whose orbit is 2795200000 miles to rotate once around the sun?',
#   'answer': '1979',
#   'options': [3078, 1979, 3903, 3783, 4211]},
#  {'question': 'The orbit of uranus around sun is 1783700000 miles.It takes 1009 earth months to orbit once around sun. How many days will it take saturn whose orbit is 886500000 miles to rotate once around the sun?',
#   'answer': '354',
#   'options': [1280, 354, 1223, 1511, 1588]},
#  {'question': 'The orbit of saturn around sun is 886500000 miles.It takes 354 earth months to orbit once around sun. How many days will it take neptune whose orbit is 2795200000 miles to rotate once around the sun?',
#   'answer': '1979',
#   'options': [1979, 60, 206, 281, 25]},
#  {'question': 'The orbit of venus around sun is 67200000 miles.It takes 7 earth months to orbit once around sun. How many days will it take neptune whose orbit is 2795200000 miles to rotate once around the sun?',
#   'answer': '1979',
#   'options': [3, 4, 3, 3, 1979]},
#  {'question': 'The size of my room is 43 * 32. Which carpet shoul I buy from target?',
#   'answer': '31*31',
#   'options': ['69*44', '76*54', '75*35', '31*31', '60*53']},
#  {'question': 'The size of my room is 45 * 50. Which carpet shoul I buy from amazon?',
#   'answer': '43*31',
#   'options': ['62*79', '72*68', '68*79', '76*89', '43*31']},
#  {'question': 'The size of my room is 57 * 52. Which carpet shoul I buy from target?',
#   'answer': '42*38',
#   'options': ['42*38', '94*74', '103*105', '88*88', '104*69']},
#  {'question': 'The size of my room is 58 * 53. Which carpet shoul I buy from target?',
#   'answer': '39*38',
#   'options': ['39*38', '84*74', '67*59', '73*88', '99*98']},
#  {'question': 'The size of my room is 35 * 33. Which carpet shoul I buy from target?',
#   'answer': '33*30',
#   'options': ['44*49', '70*58', '49*62', '61*44', '33*30']},
#  {'question': 'The size of my room is 38 * 53. Which carpet shoul I buy from target?',
#   'answer': '31*37',
#   'options': ['40*100', '69*103', '31*37', '74*91', '53*91']},
#  {'question': 'The size of my room is 39 * 43. Which carpet shoul I buy from amazon?',
#   'answer': '31*37',
#   'options': ['55*59', '66*87', '31*37', '64*46', '47*73']},
#  {'question': 'The size of my room is 45 * 51. Which carpet shoul I buy from walmart?',
#   'answer': '30*37',
#   'options': ['82*78', '74*104', '60*88', '30*37', '91*97']},
#  {'question': 'The size of my room is 32 * 60. Which carpet shoul I buy from target?',
#   'answer': '29*40',
#   'options': ['50*119', '47*62', '55*109', '47*81', '29*40']},
#  {'question': 'The size of my room is 40 * 44. Which carpet shoul I buy from amazon?',
#   'answer': '39*23',
#   'options': ['62*72', '59*81', '39*23', '50*49', '67*47']},
#  {'question': 'The size of my room is 58 * 43. Which carpet shoul I buy from target?',
#   'answer': '33*41',
#   'options': ['33*41', '68*61', '101*74', '101*71', '64*54']},
#  {'question': 'The size of my room is 51 * 55. Which carpet shoul I buy from walmart?',
#   'answer': '30*29',
#   'options': ['94*111', '62*97', '84*78', '30*29', '66*99']},
#  {'question': 'The size of my room is 35 * 46. Which carpet shoul I buy from target?',
#   'answer': '34*36',
#   'options': ['34*36', '38*81', '55*68', '55*89', '40*83']},
#  {'question': 'The size of my room is 45 * 49. Which carpet shoul I buy from flipkart?',
#   'answer': '24*29',
#   'options': ['77*81', '55*91', '55*98', '92*54', '24*29']},
#  {'question': 'The size of my room is 38 * 59. Which carpet shoul I buy from target?',
#   'answer': '32*35',
#   'options': ['72*85', '71*81', '43*83', '32*35', '67*108']},
#  {'question': 'The size of my room is 58 * 38. Which carpet shoul I buy from target?',
#   'answer': '34*25',
#   'options': ['34*25', '61*45', '78*56', '115*74', '113*60']},
#  {'question': 'The size of my room is 38 * 57. Which carpet shoul I buy from flipkart?',
#   'answer': '28*29',
#   'options': ['66*107', '75*111', '42*108', '48*101', '28*29']},
#  {'question': 'The size of my room is 49 * 56. Which carpet shoul I buy from target?',
#   'answer': '32*52',
#   'options': ['32*52', '55*90', '65*75', '52*110', '92*82']},
#  {'question': 'The size of my room is 45 * 39. Which carpet shoul I buy from walmart?',
#   'answer': '26*37',
#   'options': ['87*52', '49*48', '26*37', '76*60', '83*74']},
#  {'question': 'The size of my room is 53 * 41. Which carpet shoul I buy from walmart?',
#   'answer': '49*21',
#   'options': ['80*44', '49*21', '63*58', '89*51', '91*56']},
#  {'question': 'The size of my room is 37 * 33. Which carpet shoul I buy from walmart?',
#   'answer': '24*21',
#   'options': ['49*52', '50*58', '40*59', '71*48', '24*21']},
#  {'question': 'The size of my room is 38 * 38. Which carpet shoul I buy from target?',
#   'answer': '29*20',
#   'options': ['65*57', '74*67', '29*20', '60*56', '52*47']},
#  {'question': 'The size of my room is 51 * 49. Which carpet shoul I buy from flipkart?',
#   'answer': '36*27',
#   'options': ['60*87', '36*27', '79*78', '63*52', '61*74']},
#  {'question': 'The size of my room is 43 * 57. Which carpet shoul I buy from walmart?',
#   'answer': '22*38',
#   'options': ['22*38', '65*92', '72*106', '68*88', '46*94']},
#  {'question': 'The size of my room is 44 * 59. Which carpet shoul I buy from flipkart?',
#   'answer': '36*58',
#   'options': ['36*58', '59*72', '73*102', '73*77', '62*99']},
#  {'question': 'The size of my room is 39 * 46. Which carpet shoul I buy from target?',
#   'answer': '20*34',
#   'options': ['43*55', '20*34', '67*78', '75*60', '72*68']},
#  {'question': 'The size of my room is 32 * 38. Which carpet shoul I buy from walmart?',
#   'answer': '27*23',
#   'options': ['55*64', '39*70', '48*63', '27*23', '59*73']},
#  {'question': 'The size of my room is 49 * 32. Which carpet shoul I buy from target?',
#   'answer': '34*20',
#   'options': ['89*54', '58*65', '34*20', '62*44', '69*59']},
#  {'question': 'The size of my room is 30 * 41. Which carpet shoul I buy from flipkart?',
#   'answer': '20*26',
#   'options': ['32*42', '44*63', '54*54', '49*81', '20*26']},
#  {'question': 'The size of my room is 52 * 43. Which carpet shoul I buy from amazon?',
#   'answer': '49*22',
#   'options': ['93*47', '62*75', '76*59', '53*45', '49*22']},
#  {'question': 'The size of my room is 43 * 48. Which carpet shoul I buy from flipkart?',
#   'answer': '35*45',
#   'options': ['66*83', '44*68', '67*51', '69*55', '35*45']},
#  {'question': 'The size of my room is 43 * 40. Which carpet shoul I buy from walmart?',
#   'answer': '42*34',
#   'options': ['55*61', '66*81', '81*77', '42*34', '71*78']},
#  {'question': 'The size of my room is 48 * 38. Which carpet shoul I buy from walmart?',
#   'answer': '27*25',
#   'options': ['60*46', '70*63', '27*25', '79*75', '50*62']},
#  {'question': 'The size of my room is 52 * 52. Which carpet shoul I buy from target?',
#   'answer': '43*51',
#   'options': ['43*51', '53*96', '77*92', '72*75', '85*59']},
#  {'question': 'The size of my room is 39 * 50. Which carpet shoul I buy from amazon?',
#   'answer': '21*49',
#   'options': ['44*62', '63*70', '21*49', '61*76', '66*70']},
#  {'question': 'The size of my room is 58 * 46. Which carpet shoul I buy from flipkart?',
#   'answer': '30*24',
#   'options': ['30*24', '69*73', '111*71', '96*76', '113*70']},
#  {'question': 'The size of my room is 37 * 50. Which carpet shoul I buy from target?',
#   'answer': '26*47',
#   'options': ['73*65', '41*69', '26*47', '38*66', '48*87']},
#  {'question': 'The size of my room is 56 * 40. Which carpet shoul I buy from flipkart?',
#   'answer': '51*20',
#   'options': ['103*60', '104*60', '98*61', '98*61', '51*20']},
#  {'question': 'The size of my room is 37 * 53. Which carpet shoul I buy from amazon?',
#   'answer': '31*31',
#   'options': ['62*88', '50*63', '68*94', '71*75', '31*31']},
#  {'question': 'The size of my room is 31 * 52. Which carpet shoul I buy from walmart?',
#   'answer': '21*45',
#   'options': ['55*95', '59*64', '63*87', '49*74', '21*45']},
#  {'question': 'The size of my room is 48 * 57. Which carpet shoul I buy from target?',
#   'answer': '44*39',
#   'options': ['67*76', '44*39', '52*63', '59*85', '77*67']},
#  {'question': 'The size of my room is 57 * 48. Which carpet shoul I buy from target?',
#   'answer': '37*31',
#   'options': ['68*60', '37*31', '80*49', '92*52', '102*82']},
#  {'question': 'The size of my room is 38 * 33. Which carpet shoul I buy from walmart?',
#   'answer': '19*23',
#   'options': ['55*50', '48*48', '60*57', '19*23', '48*41']},
#  {'question': 'The size of my room is 35 * 54. Which carpet shoul I buy from flipkart?',
#   'answer': '20*45',
#   'options': ['59*89', '20*45', '70*108', '54*84', '41*109']},
#  {'question': 'The size of my room is 50 * 57. Which carpet shoul I buy from walmart?',
#   'answer': '35*44',
#   'options': ['82*58', '35*44', '78*59', '66*107', '65*97']},
#  {'question': 'The size of my room is 58 * 34. Which carpet shoul I buy from amazon?',
#   'answer': '36*33',
#   'options': ['101*42', '74*36', '36*33', '73*52', '68*51']},
#  {'question': 'The size of my room is 42 * 53. Which carpet shoul I buy from flipkart?',
#   'answer': '36*36',
#   'options': ['36*36', '70*60', '62*83', '71*100', '43*86']},
#  {'question': 'The size of my room is 32 * 50. Which carpet shoul I buy from walmart?',
#   'answer': '17*36',
#   'options': ['56*94', '47*63', '17*36', '45*66', '58*63']},
#  {'question': 'The size of my room is 48 * 54. Which carpet shoul I buy from amazon?',
#   'answer': '37*35',
#   'options': ['61*68', '37*35', '80*64', '84*72', '69*88']},
#  {'question': 'The size of my room is 32 * 32. Which carpet shoul I buy from flipkart?',
#   'answer': '19*24',
#   'options': ['19*24', '36*48', '46*39', '48*35', '36*39']}]

# %%
def time_distance(list_of_json_object):
    verbs = ["walks","drives","cycles","runs"]
    template = "$1 $5 at a speed of $2 km/hr. How much time will it take him/her to travel $3 's place which is $4 km away?"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        name_from = names[random.randint(0,500)]
        name_to = names[random.randint(501,999)]
        speed = random.randint(6,20)
        distance = random.randint(100,200)
        verb = verbs[random.randint(0,3)]
        correct_answer = random.randint(0,4)
        temp_variables = [name_from,speed,name_to,distance,verb]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        question_options = []
        for i in range(5):
            if i == correct_answer:
                ans = (distance/speed)
                ans = str("%.2f" % ans)
                template_obj["answer"] = ans
                question_options.append(ans)
            else:
                opt = ((distance/speed)*random.randint(2,5))
                opt = str("%.2f" % opt)
                question_options.append(opt)
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
#list_of_json_object.clear()
time_distance(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'answer': '24*21',
#   'options': ['49*52', '50*58', '40*59', '71*48', '24*21']},
#  {'question': 'The size of my room is 38 * 38. Which carpet shoul I buy from target?',
#   'answer': '29*20',
#   'options': ['65*57', '74*67', '29*20', '60*56', '52*47']},
#  {'question': 'The size of my room is 51 * 49. Which carpet shoul I buy from flipkart?',
#   'answer': '36*27',
#   'options': ['60*87', '36*27', '79*78', '63*52', '61*74']},
#  {'question': 'The size of my room is 43 * 57. Which carpet shoul I buy from walmart?',
#   'answer': '22*38',
#   'options': ['22*38', '65*92', '72*106', '68*88', '46*94']},
#  {'question': 'The size of my room is 44 * 59. Which carpet shoul I buy from flipkart?',
#   'answer': '36*58',
#   'options': ['36*58', '59*72', '73*102', '73*77', '62*99']},
#  {'question': 'The size of my room is 39 * 46. Which carpet shoul I buy from target?',
#   'answer': '20*34',
#   'options': ['43*55', '20*34', '67*78', '75*60', '72*68']},
#  {'question': 'The size of my room is 32 * 38. Which carpet shoul I buy from walmart?',
#   'answer': '27*23',
#   'options': ['55*64', '39*70', '48*63', '27*23', '59*73']},
#  {'question': 'The size of my room is 49 * 32. Which carpet shoul I buy from target?',
#   'answer': '34*20',
#   'options': ['89*54', '58*65', '34*20', '62*44', '69*59']},
#  {'question': 'The size of my room is 30 * 41. Which carpet shoul I buy from flipkart?',
#   'answer': '20*26',
#   'options': ['32*42', '44*63', '54*54', '49*81', '20*26']},
#  {'question': 'The size of my room is 52 * 43. Which carpet shoul I buy from amazon?',
#   'answer': '49*22',
#   'options': ['93*47', '62*75', '76*59', '53*45', '49*22']},
#  {'question': 'The size of my room is 43 * 48. Which carpet shoul I buy from flipkart?',
#   'answer': '35*45',
#   'options': ['66*83', '44*68', '67*51', '69*55', '35*45']},
#  {'question': 'The size of my room is 43 * 40. Which carpet shoul I buy from walmart?',
#   'answer': '42*34',
#   'options': ['55*61', '66*81', '81*77', '42*34', '71*78']},
#  {'question': 'The size of my room is 48 * 38. Which carpet shoul I buy from walmart?',
#   'answer': '27*25',
#   'options': ['60*46', '70*63', '27*25', '79*75', '50*62']},
#  {'question': 'The size of my room is 52 * 52. Which carpet shoul I buy from target?',
#   'answer': '43*51',
#   'options': ['43*51', '53*96', '77*92', '72*75', '85*59']},
#  {'question': 'The size of my room is 39 * 50. Which carpet shoul I buy from amazon?',
#   'answer': '21*49',
#   'options': ['44*62', '63*70', '21*49', '61*76', '66*70']},
#  {'question': 'The size of my room is 58 * 46. Which carpet shoul I buy from flipkart?',
#   'answer': '30*24',
#   'options': ['30*24', '69*73', '111*71', '96*76', '113*70']},
#  {'question': 'The size of my room is 37 * 50. Which carpet shoul I buy from target?',
#   'answer': '26*47',
#   'options': ['73*65', '41*69', '26*47', '38*66', '48*87']},
#  {'question': 'The size of my room is 56 * 40. Which carpet shoul I buy from flipkart?',
#   'answer': '51*20',
#   'options': ['103*60', '104*60', '98*61', '98*61', '51*20']},
#  {'question': 'The size of my room is 37 * 53. Which carpet shoul I buy from amazon?',
#   'answer': '31*31',
#   'options': ['62*88', '50*63', '68*94', '71*75', '31*31']},
#  {'question': 'The size of my room is 31 * 52. Which carpet shoul I buy from walmart?',
#   'answer': '21*45',
#   'options': ['55*95', '59*64', '63*87', '49*74', '21*45']},
#  {'question': 'The size of my room is 48 * 57. Which carpet shoul I buy from target?',
#   'answer': '44*39',
#   'options': ['67*76', '44*39', '52*63', '59*85', '77*67']},
#  {'question': 'The size of my room is 57 * 48. Which carpet shoul I buy from target?',
#   'answer': '37*31',
#   'options': ['68*60', '37*31', '80*49', '92*52', '102*82']},
#  {'question': 'The size of my room is 38 * 33. Which carpet shoul I buy from walmart?',
#   'answer': '19*23',
#   'options': ['55*50', '48*48', '60*57', '19*23', '48*41']},
#  {'question': 'The size of my room is 35 * 54. Which carpet shoul I buy from flipkart?',
#   'answer': '20*45',
#   'options': ['59*89', '20*45', '70*108', '54*84', '41*109']},
#  {'question': 'The size of my room is 50 * 57. Which carpet shoul I buy from walmart?',
#   'answer': '35*44',
#   'options': ['82*58', '35*44', '78*59', '66*107', '65*97']},
#  {'question': 'The size of my room is 58 * 34. Which carpet shoul I buy from amazon?',
#   'answer': '36*33',
#   'options': ['101*42', '74*36', '36*33', '73*52', '68*51']},
#  {'question': 'The size of my room is 42 * 53. Which carpet shoul I buy from flipkart?',
#   'answer': '36*36',
#   'options': ['36*36', '70*60', '62*83', '71*100', '43*86']},
#  {'question': 'The size of my room is 32 * 50. Which carpet shoul I buy from walmart?',
#   'answer': '17*36',
#   'options': ['56*94', '47*63', '17*36', '45*66', '58*63']},
#  {'question': 'The size of my room is 48 * 54. Which carpet shoul I buy from amazon?',
#   'answer': '37*35',
#   'options': ['61*68', '37*35', '80*64', '84*72', '69*88']},
#  {'question': 'The size of my room is 32 * 32. Which carpet shoul I buy from flipkart?',
#   'answer': '19*24',
#   'options': ['19*24', '36*48', '46*39', '48*35', '36*39']},
#  {'question': "Harvey drives at a speed of 7 km/hr. How much time will it take him/her to travel Grey 's place which is 185 km away?",
#   'answer': '26.43',
#   'options': ['105.71', '52.86', '26.43', '132.14', '79.29']},
#  {'question': "Cade runs at a speed of 18 km/hr. How much time will it take him/her to travel Deandre 's place which is 151 km away?",
#   'answer': '8.39',
#   'options': ['25.17', '16.78', '25.17', '8.39', '16.78']},
#  {'question': "Anderson drives at a speed of 12 km/hr. How much time will it take him/her to travel Marc 's place which is 116 km away?",
#   'answer': '9.67',
#   'options': ['48.33', '38.67', '9.67', '38.67', '19.33']},
#  {'question': "Preston runs at a speed of 15 km/hr. How much time will it take him/her to travel Westin 's place which is 179 km away?",
#   'answer': '11.93',
#   'options': ['35.80', '11.93', '23.87', '23.87', '59.67']},
#  {'question': "Javier drives at a speed of 13 km/hr. How much time will it take him/her to travel Aden 's place which is 194 km away?",
#   'answer': '14.92',
#   'options': ['59.69', '59.69', '14.92', '44.77', '44.77']},
#  {'question': "Nash runs at a speed of 16 km/hr. How much time will it take him/her to travel Vivaan 's place which is 161 km away?",
#   'answer': '10.06',
#   'options': ['30.19', '20.12', '10.06', '20.12', '20.12']},
#  {'question': "Tobias runs at a speed of 15 km/hr. How much time will it take him/her to travel Alessandro 's place which is 169 km away?",
#   'answer': '11.27',
#   'options': ['33.80', '45.07', '56.33', '11.27', '56.33']},
#  {'question': "Ezra walks at a speed of 20 km/hr. How much time will it take him/her to travel Roland 's place which is 147 km away?",
#   'answer': '7.35',
#   'options': ['22.05', '7.35', '29.40', '22.05', '14.70']},
#  {'question': "Donovan drives at a speed of 17 km/hr. How much time will it take him/her to travel Gatlin 's place which is 167 km away?",
#   'answer': '9.82',
#   'options': ['19.65', '39.29', '9.82', '39.29', '39.29']},
#  {'question': "Maximiliano walks at a speed of 11 km/hr. How much time will it take him/her to travel Van 's place which is 142 km away?",
#   'answer': '12.91',
#   'options': ['64.55', '64.55', '64.55', '12.91', '51.64']},
#  {'question': "Derek cycles at a speed of 15 km/hr. How much time will it take him/her to travel Coleman 's place which is 179 km away?",
#   'answer': '11.93',
#   'options': ['35.80', '23.87', '59.67', '11.93', '47.73']},
#  {'question': "Ismael runs at a speed of 18 km/hr. How much time will it take him/her to travel Dillon 's place which is 177 km away?",
#   'answer': '9.83',
#   'options': ['29.50', '19.67', '39.33', '19.67', '9.83']},
#  {'question': "Oscar walks at a speed of 18 km/hr. How much time will it take him/her to travel Roger 's place which is 189 km away?",
#   'answer': '10.50',
#   'options': ['21.00', '10.50', '31.50', '52.50', '31.50']},
#  {'question': "Elliott runs at a speed of 11 km/hr. How much time will it take him/her to travel Blaze 's place which is 169 km away?",
#   'answer': '15.36',
#   'options': ['61.45', '76.82', '15.36', '61.45', '46.09']},
#  {'question': "Joshua runs at a speed of 7 km/hr. How much time will it take him/her to travel Casen 's place which is 112 km away?",
#   'answer': '16.00',
#   'options': ['80.00', '80.00', '48.00', '16.00', '80.00']},
#  {'question': "Josue runs at a speed of 12 km/hr. How much time will it take him/her to travel Julio 's place which is 183 km away?",
#   'answer': '15.25',
#   'options': ['30.50', '61.00', '61.00', '15.25', '76.25']},
#  {'question': "David cycles at a speed of 8 km/hr. How much time will it take him/her to travel Zaid 's place which is 168 km away?",
#   'answer': '21.00',
#   'options': ['63.00', '63.00', '105.00', '21.00', '84.00']},
#  {'question': "Milo drives at a speed of 16 km/hr. How much time will it take him/her to travel Arturo 's place which is 165 km away?",
#   'answer': '10.31',
#   'options': ['41.25', '20.62', '10.31', '30.94', '20.62']},
#  {'question': "Nicholas cycles at a speed of 7 km/hr. How much time will it take him/her to travel Alessandro 's place which is 196 km away?",
#   'answer': '28.00',
#   'options': ['84.00', '28.00', '140.00', '112.00', '112.00']},
#  {'question': "Joaquin walks at a speed of 10 km/hr. How much time will it take him/her to travel Crosby 's place which is 150 km away?",
#   'answer': '15.00',
#   'options': ['30.00', '30.00', '75.00', '75.00', '15.00']},
#  {'question': "Emerson runs at a speed of 20 km/hr. How much time will it take him/her to travel Dennis 's place which is 182 km away?",
#   'answer': '9.10',
#   'options': ['36.40', '18.20', '9.10', '27.30', '45.50']},
#  {'question': "Patrick walks at a speed of 7 km/hr. How much time will it take him/her to travel Jad 's place which is 108 km away?",
#   'answer': '15.43',
#   'options': ['30.86', '61.71', '61.71', '46.29', '15.43']},
#  {'question': "Hayden drives at a speed of 8 km/hr. How much time will it take him/her to travel Imran 's place which is 189 km away?",
#   'answer': '23.62',
#   'options': ['70.88', '23.62', '94.50', '47.25', '70.88']},
#  {'question': "Otto runs at a speed of 19 km/hr. How much time will it take him/her to travel Terry 's place which is 131 km away?",
#   'answer': '6.89',
#   'options': ['34.47', '34.47', '27.58', '6.89', '34.47']},
#  {'question': "Alexis drives at a speed of 17 km/hr. How much time will it take him/her to travel Kendall 's place which is 159 km away?",
#   'answer': '9.35',
#   'options': ['46.76', '28.06', '37.41', '9.35', '18.71']},
#  {'question': "Finnegan runs at a speed of 13 km/hr. How much time will it take him/her to travel Leonard 's place which is 196 km away?",
#   'answer': '15.08',
#   'options': ['60.31', '75.38', '30.15', '45.23', '15.08']},
#  {'question': "Aidan drives at a speed of 12 km/hr. How much time will it take him/her to travel Callum 's place which is 140 km away?",
#   'answer': '11.67',
#   'options': ['35.00', '58.33', '23.33', '58.33', '11.67']},
#  {'question': "Dawson cycles at a speed of 12 km/hr. How much time will it take him/her to travel Eddie 's place which is 184 km away?",
#   'answer': '15.33',
#   'options': ['15.33', '61.33', '76.67', '61.33', '61.33']},
#  {'question': "Liam cycles at a speed of 19 km/hr. How much time will it take him/her to travel Abdullah 's place which is 137 km away?",
#   'answer': '7.21',
#   'options': ['14.42', '28.84', '7.21', '28.84', '36.05']},
#  {'question': "Weston drives at a speed of 15 km/hr. How much time will it take him/her to travel Vihaan 's place which is 189 km away?",
#   'answer': '12.60',
#   'options': ['37.80', '37.80', '37.80', '12.60', '50.40']},
#  {'question': "Rylan walks at a speed of 6 km/hr. How much time will it take him/her to travel Scott 's place which is 144 km away?",
#   'answer': '24.00',
#   'options': ['96.00', '120.00', '24.00', '72.00', '96.00']},
#  {'question': "Jaxton walks at a speed of 12 km/hr. How much time will it take him/her to travel Jacoby 's place which is 164 km away?",
#   'answer': '13.67',
#   'options': ['27.33', '54.67', '41.00', '68.33', '13.67']},
#  {'question': "Jeremiah cycles at a speed of 10 km/hr. How much time will it take him/her to travel Duncan 's place which is 139 km away?",
#   'answer': '13.90',
#   'options': ['13.90', '41.70', '55.60', '55.60', '55.60']},
#  {'question': "Shawn walks at a speed of 14 km/hr. How much time will it take him/her to travel Dorian 's place which is 104 km away?",
#   'answer': '7.43',
#   'options': ['29.71', '22.29', '22.29', '29.71', '7.43']},
#  {'question': "Gavin cycles at a speed of 17 km/hr. How much time will it take him/her to travel Judson 's place which is 141 km away?",
#   'answer': '8.29',
#   'options': ['16.59', '16.59', '24.88', '16.59', '8.29']},
#  {'question': "Pedro cycles at a speed of 14 km/hr. How much time will it take him/her to travel Brendan 's place which is 154 km away?",
#   'answer': '11.00',
#   'options': ['22.00', '22.00', '33.00', '55.00', '11.00']},
#  {'question': "Killian runs at a speed of 6 km/hr. How much time will it take him/her to travel Vincenzo 's place which is 110 km away?",
#   'answer': '18.33',
#   'options': ['91.67', '18.33', '73.33', '73.33', '36.67']},
#  {'question': "Luca drives at a speed of 10 km/hr. How much time will it take him/her to travel Zakai 's place which is 199 km away?",
#   'answer': '19.90',
#   'options': ['39.80', '79.60', '19.90', '39.80', '39.80']},
#  {'question': "Jonathan drives at a speed of 8 km/hr. How much time will it take him/her to travel Westley 's place which is 192 km away?",
#   'answer': '24.00',
#   'options': ['96.00', '24.00', '72.00', '48.00', '96.00']},
#  {'question': "Fernando walks at a speed of 18 km/hr. How much time will it take him/her to travel Raylan 's place which is 110 km away?",
#   'answer': '6.11',
#   'options': ['6.11', '12.22', '30.56', '24.44', '30.56']},
#  {'question': "Atlas cycles at a speed of 13 km/hr. How much time will it take him/her to travel Casen 's place which is 152 km away?",
#   'answer': '11.69',
#   'options': ['23.38', '58.46', '35.08', '11.69', '46.77']},
#  {'question': "Kayden runs at a speed of 17 km/hr. How much time will it take him/her to travel Zev 's place which is 183 km away?",
#   'answer': '10.76',
#   'options': ['21.53', '53.82', '21.53', '43.06', '10.76']},
#  {'question': "Jensen cycles at a speed of 18 km/hr. How much time will it take him/her to travel Jordy 's place which is 105 km away?",
#   'answer': '5.83',
#   'options': ['11.67', '29.17', '17.50', '5.83', '17.50']},
#  {'question': "Jax cycles at a speed of 19 km/hr. How much time will it take him/her to travel Juelz 's place which is 197 km away?",
#   'answer': '10.37',
#   'options': ['10.37', '31.11', '20.74', '20.74', '31.11']},
#  {'question': "Cooper cycles at a speed of 9 km/hr. How much time will it take him/her to travel Nikolas 's place which is 179 km away?",
#   'answer': '19.89',
#   'options': ['19.89', '99.44', '79.56', '59.67', '99.44']},
#  {'question': "Erick cycles at a speed of 11 km/hr. How much time will it take him/her to travel Jericho 's place which is 154 km away?",
#   'answer': '14.00',
#   'options': ['70.00', '56.00', '14.00', '56.00', '42.00']},
#  {'question': "Mark runs at a speed of 17 km/hr. How much time will it take him/her to travel Bentlee 's place which is 118 km away?",
#   'answer': '6.94',
#   'options': ['20.82', '13.88', '6.94', '27.76', '34.71']},
#  {'question': "Ezra cycles at a speed of 18 km/hr. How much time will it take him/her to travel Jerry 's place which is 123 km away?",
#   'answer': '6.83',
#   'options': ['27.33', '20.50', '6.83', '34.17', '34.17']},
#  {'question': "Abraham runs at a speed of 7 km/hr. How much time will it take him/her to travel Zaire 's place which is 170 km away?",
#   'answer': '24.29',
#   'options': ['72.86', '24.29', '97.14', '72.86', '121.43']},
#  {'question': "Kameron walks at a speed of 12 km/hr. How much time will it take him/her to travel Valentino 's place which is 146 km away?",
#   'answer': '12.17',
#   'options': ['24.33', '12.17', '48.67', '36.50', '24.33']}]

# %%
def physics_charging(list_of_json_object):
    template = "A $1 watt charger charges a $2 in $3 minutes. How much time will it take for a $4 watt charger to charge the same $5 ?"
    objects = ["laptop","phone","powerbank","tablet","airpods"]
    duplicity = 100
    while duplicity > 0:
        template_obj = {}
        options = []
        charger_capacity = random.randint(2,30)
        object_1 = objects[random.randint(0,4)]
        time = random.randint(10,60)
        sec_charger_capacity = random.randint(2,30)
        object_2 = object_1
        template_question = raplace_parameters(template,[charger_capacity,object_1,time,sec_charger_capacity,object_2])
        template_obj["question"] = template_question
        answer = None
        if(charger_capacity==sec_charger_capacity):
            answer = time
            options.append(answer)
            for i in range(4):
                options.append(random.randint(1,70))
        elif(charger_capacity>sec_charger_capacity):
            answer = random.randint(time+1,70)
            options.append(answer)
            for i in range(4):
                options.append(random.randint(1,time-1))
        else:
            answer = random.randint(1,time-1)
            options.append(answer)
            for i in range(4):
                options.append(random.randint(time+1,100))
        random.shuffle(options)
        template_obj["answer"] = answer
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
physics_charging(list_of_json_object)
#print(list_of_json_object)

# %%
def triangle(list_of_json_object):
    template = "The angles of an triangle are $1, $2, $3. What type of triangle is this one?"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        angle_1 = random.randint(30,100)
        angle_2 = random.randint(30,60)
        angle_3 = 180 - angle_1 - angle_2
        angles = [angle_1,angle_2,angle_3]
        template_question = raplace_parameters(template,angles)
        template_obj["question"] = template_question
        question_options = ["acute angle triangle,right angle triangle,obtuse angle triangle"]
        for i in range(5):
            if angle_1>90 or angle_2>90 or angle_3 > 90:
                template_obj["answer"] = "obtuse angle triangle"
            elif angle_1==90 or angle_2==90 or angle_3 == 90:
                template_obj["answer"] = "right angle triangle"
            else:
                template_obj["answer"] = "acute angle triangle"       
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
#list_of_json_object.clear()
triangle(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'options': [11, 53, 13, 9, 13]},
#  {'question': 'A 18 watt charger charges a phone in 32 minutes. How much time will it take for a 23 watt charger to charge the same phone ?',
#   'answer': 6,
#   'options': [42, 78, 6, 80, 59]},
#  {'question': 'A 16 watt charger charges a airpods in 15 minutes. How much time will it take for a 16 watt charger to charge the same airpods ?',
#   'answer': 15,
#   'options': [70, 20, 37, 15, 33]},
#  {'question': 'A 13 watt charger charges a phone in 58 minutes. How much time will it take for a 14 watt charger to charge the same phone ?',
#   'answer': 30,
#   'options': [62, 91, 80, 71, 30]},
#  {'question': 'A 10 watt charger charges a phone in 48 minutes. How much time will it take for a 21 watt charger to charge the same phone ?',
#   'answer': 15,
#   'options': [60, 91, 62, 15, 78]},
#  {'question': 'A 24 watt charger charges a phone in 44 minutes. How much time will it take for a 17 watt charger to charge the same phone ?',
#   'answer': 62,
#   'options': [62, 36, 34, 22, 26]},
#  {'question': 'A 13 watt charger charges a airpods in 39 minutes. How much time will it take for a 7 watt charger to charge the same airpods ?',
#   'answer': 63,
#   'options': [63, 26, 4, 9, 36]},
#  {'question': 'A 20 watt charger charges a powerbank in 40 minutes. How much time will it take for a 11 watt charger to charge the same powerbank ?',
#   'answer': 46,
#   'options': [20, 14, 46, 18, 23]},
#  {'question': 'A 7 watt charger charges a laptop in 10 minutes. How much time will it take for a 11 watt charger to charge the same laptop ?',
#   'answer': 1,
#   'options': [1, 65, 38, 38, 93]},
#  {'question': 'A 24 watt charger charges a powerbank in 16 minutes. How much time will it take for a 4 watt charger to charge the same powerbank ?',
#   'answer': 47,
#   'options': [11, 47, 5, 9, 6]},
#  {'question': 'A 7 watt charger charges a powerbank in 41 minutes. How much time will it take for a 16 watt charger to charge the same powerbank ?',
#   'answer': 21,
#   'options': [21, 87, 91, 56, 68]},
#  {'question': 'A 3 watt charger charges a tablet in 56 minutes. How much time will it take for a 6 watt charger to charge the same tablet ?',
#   'answer': 53,
#   'options': [53, 76, 78, 95, 64]},
#  {'question': 'A 21 watt charger charges a laptop in 23 minutes. How much time will it take for a 20 watt charger to charge the same laptop ?',
#   'answer': 49,
#   'options': [7, 3, 3, 49, 14]},
#  {'question': 'A 23 watt charger charges a airpods in 36 minutes. How much time will it take for a 9 watt charger to charge the same airpods ?',
#   'answer': 47,
#   'options': [17, 26, 15, 10, 47]},
#  {'question': 'A 23 watt charger charges a laptop in 23 minutes. How much time will it take for a 7 watt charger to charge the same laptop ?',
#   'answer': 61,
#   'options': [3, 17, 15, 16, 61]},
#  {'question': 'A 12 watt charger charges a powerbank in 32 minutes. How much time will it take for a 22 watt charger to charge the same powerbank ?',
#   'answer': 31,
#   'options': [93, 51, 57, 31, 99]},
#  {'question': 'A 20 watt charger charges a laptop in 29 minutes. How much time will it take for a 9 watt charger to charge the same laptop ?',
#   'answer': 39,
#   'options': [27, 26, 39, 25, 3]},
#  {'question': 'A 12 watt charger charges a airpods in 33 minutes. How much time will it take for a 3 watt charger to charge the same airpods ?',
#   'answer': 62,
#   'options': [3, 15, 62, 1, 24]},
#  {'question': 'A 30 watt charger charges a tablet in 41 minutes. How much time will it take for a 10 watt charger to charge the same tablet ?',
#   'answer': 42,
#   'options': [19, 42, 26, 19, 5]},
#  {'question': 'A 13 watt charger charges a laptop in 24 minutes. How much time will it take for a 14 watt charger to charge the same laptop ?',
#   'answer': 20,
#   'options': [35, 63, 43, 20, 94]},
#  {'question': 'A 29 watt charger charges a laptop in 45 minutes. How much time will it take for a 18 watt charger to charge the same laptop ?',
#   'answer': 64,
#   'options': [28, 64, 44, 31, 20]},
#  {'question': 'A 25 watt charger charges a tablet in 11 minutes. How much time will it take for a 11 watt charger to charge the same tablet ?',
#   'answer': 67,
#   'options': [67, 6, 2, 10, 6]},
#  {'question': 'A 25 watt charger charges a phone in 15 minutes. How much time will it take for a 4 watt charger to charge the same phone ?',
#   'answer': 36,
#   'options': [36, 11, 2, 4, 3]},
#  {'question': 'A 4 watt charger charges a laptop in 42 minutes. How much time will it take for a 22 watt charger to charge the same laptop ?',
#   'answer': 26,
#   'options': [87, 71, 59, 26, 67]},
#  {'question': 'A 14 watt charger charges a powerbank in 46 minutes. How much time will it take for a 10 watt charger to charge the same powerbank ?',
#   'answer': 57,
#   'options': [57, 45, 31, 36, 8]},
#  {'question': 'A 7 watt charger charges a powerbank in 33 minutes. How much time will it take for a 5 watt charger to charge the same powerbank ?',
#   'answer': 45,
#   'options': [9, 7, 45, 14, 29]},
#  {'question': 'A 3 watt charger charges a phone in 52 minutes. How much time will it take for a 19 watt charger to charge the same phone ?',
#   'answer': 49,
#   'options': [99, 49, 93, 66, 72]},
#  {'question': 'A 24 watt charger charges a powerbank in 56 minutes. How much time will it take for a 20 watt charger to charge the same powerbank ?',
#   'answer': 62,
#   'options': [8, 62, 19, 21, 45]},
#  {'question': 'The angles of an triangle are 63, 38, 79. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 41, 32, 107. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 82, 43, 55. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 82, 58, 40. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 73, 57, 50. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 57, 42, 81. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 81, 48, 51. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 63, 43, 74. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 99, 48, 33. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 97, 42, 41. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 91, 53, 36. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 57, 34, 89. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 37, 44, 99. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 57, 55, 68. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 87, 60, 33. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 96, 38, 46. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 90, 49, 41. What type of triangle is this one?',
#   'answer': 'right angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 49, 47, 84. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 82, 42, 56. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 98, 57, 25. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 67, 50, 63. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 75, 41, 64. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 79, 40, 61. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 49, 52, 79. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 38, 34, 108. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 83, 46, 51. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 97, 52, 31. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 53, 46, 81. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 71, 41, 68. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 59, 30, 91. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 60, 36, 84. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 94, 51, 35. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 62, 48, 70. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 76, 57, 47. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 77, 50, 53. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 61, 43, 76. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 42, 56, 82. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 52, 37, 91. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 96, 32, 52. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 54, 34, 92. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 78, 50, 52. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 38, 31, 111. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 59, 44, 77. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 73, 30, 77. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 99, 32, 49. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 75, 41, 64. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 32, 35, 113. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 85, 40, 55. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 84, 32, 64. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 84, 47, 49. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']}]

# %%
def polygon(list_of_json_object):
    template = "There are $1 sides of a polygon. What type of polygon is this one?"
    duplicity = 10
    while duplicity > 0:
        template_obj = {}
        side = random.randint(3,8)
        sides = [side]
        template_question = raplace_parameters(template,sides)
        template_obj["question"] = template_question
        question_options = ["Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon"]
        for i in range(5):
            if side ==3:
                template_obj["answer"] = "Traingle"
            elif side == 4:
                template_obj["answer"] = "Rectangle"
            elif side == 5:
                template_obj["answer"] = "Pentagon"
            elif side == 6:
                template_obj["answer"] = "Hexagon"
            elif side == 7:
                template_obj["answer"] = "Heptagon"
            else:
                template_obj["answer"] = "Octagon"       
        duplicity-=1
        random.shuffle(question_options)
        template_obj["options"]=question_options
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
#list_of_json_object.clear()
polygon(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#  {'question': 'A 7 watt charger charges a powerbank in 41 minutes. How much time will it take for a 16 watt charger to charge the same powerbank ?',
#   'answer': 21,
#   'options': [21, 87, 91, 56, 68]},
#  {'question': 'A 3 watt charger charges a tablet in 56 minutes. How much time will it take for a 6 watt charger to charge the same tablet ?',
#   'answer': 53,
#   'options': [53, 76, 78, 95, 64]},
#  {'question': 'A 21 watt charger charges a laptop in 23 minutes. How much time will it take for a 20 watt charger to charge the same laptop ?',
#   'answer': 49,
#   'options': [7, 3, 3, 49, 14]},
#  {'question': 'A 23 watt charger charges a airpods in 36 minutes. How much time will it take for a 9 watt charger to charge the same airpods ?',
#   'answer': 47,
#   'options': [17, 26, 15, 10, 47]},
#  {'question': 'A 23 watt charger charges a laptop in 23 minutes. How much time will it take for a 7 watt charger to charge the same laptop ?',
#   'answer': 61,
#   'options': [3, 17, 15, 16, 61]},
#  {'question': 'A 12 watt charger charges a powerbank in 32 minutes. How much time will it take for a 22 watt charger to charge the same powerbank ?',
#   'answer': 31,
#   'options': [93, 51, 57, 31, 99]},
#  {'question': 'A 20 watt charger charges a laptop in 29 minutes. How much time will it take for a 9 watt charger to charge the same laptop ?',
#   'answer': 39,
#   'options': [27, 26, 39, 25, 3]},
#  {'question': 'A 12 watt charger charges a airpods in 33 minutes. How much time will it take for a 3 watt charger to charge the same airpods ?',
#   'answer': 62,
#   'options': [3, 15, 62, 1, 24]},
#  {'question': 'A 30 watt charger charges a tablet in 41 minutes. How much time will it take for a 10 watt charger to charge the same tablet ?',
#   'answer': 42,
#   'options': [19, 42, 26, 19, 5]},
#  {'question': 'A 13 watt charger charges a laptop in 24 minutes. How much time will it take for a 14 watt charger to charge the same laptop ?',
#   'answer': 20,
#   'options': [35, 63, 43, 20, 94]},
#  {'question': 'A 29 watt charger charges a laptop in 45 minutes. How much time will it take for a 18 watt charger to charge the same laptop ?',
#   'answer': 64,
#   'options': [28, 64, 44, 31, 20]},
#  {'question': 'A 25 watt charger charges a tablet in 11 minutes. How much time will it take for a 11 watt charger to charge the same tablet ?',
#   'answer': 67,
#   'options': [67, 6, 2, 10, 6]},
#  {'question': 'A 25 watt charger charges a phone in 15 minutes. How much time will it take for a 4 watt charger to charge the same phone ?',
#   'answer': 36,
#   'options': [36, 11, 2, 4, 3]},
#  {'question': 'A 4 watt charger charges a laptop in 42 minutes. How much time will it take for a 22 watt charger to charge the same laptop ?',
#   'answer': 26,
#   'options': [87, 71, 59, 26, 67]},
#  {'question': 'A 14 watt charger charges a powerbank in 46 minutes. How much time will it take for a 10 watt charger to charge the same powerbank ?',
#   'answer': 57,
#   'options': [57, 45, 31, 36, 8]},
#  {'question': 'A 7 watt charger charges a powerbank in 33 minutes. How much time will it take for a 5 watt charger to charge the same powerbank ?',
#   'answer': 45,
#   'options': [9, 7, 45, 14, 29]},
#  {'question': 'A 3 watt charger charges a phone in 52 minutes. How much time will it take for a 19 watt charger to charge the same phone ?',
#   'answer': 49,
#   'options': [99, 49, 93, 66, 72]},
#  {'question': 'A 24 watt charger charges a powerbank in 56 minutes. How much time will it take for a 20 watt charger to charge the same powerbank ?',
#   'answer': 62,
#   'options': [8, 62, 19, 21, 45]},
#  {'question': 'The angles of an triangle are 63, 38, 79. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 41, 32, 107. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 82, 43, 55. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 82, 58, 40. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 73, 57, 50. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 57, 42, 81. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 81, 48, 51. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 63, 43, 74. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 99, 48, 33. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 97, 42, 41. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 91, 53, 36. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 57, 34, 89. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 37, 44, 99. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 57, 55, 68. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 87, 60, 33. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 96, 38, 46. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 90, 49, 41. What type of triangle is this one?',
#   'answer': 'right angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 49, 47, 84. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 82, 42, 56. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 98, 57, 25. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 67, 50, 63. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 75, 41, 64. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 79, 40, 61. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 49, 52, 79. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 38, 34, 108. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 83, 46, 51. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 97, 52, 31. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 53, 46, 81. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 71, 41, 68. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 59, 30, 91. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 60, 36, 84. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 94, 51, 35. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 62, 48, 70. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 76, 57, 47. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 77, 50, 53. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 61, 43, 76. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 42, 56, 82. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 52, 37, 91. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 96, 32, 52. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 54, 34, 92. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 78, 50, 52. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 38, 31, 111. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 59, 44, 77. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 73, 30, 77. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 99, 32, 49. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 75, 41, 64. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 32, 35, 113. What type of triangle is this one?',
#   'answer': 'obtuse angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 85, 40, 55. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 84, 32, 64. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'The angles of an triangle are 84, 47, 49. What type of triangle is this one?',
#   'answer': 'acute angle triangle',
#   'options': ['acute angle triangle,right angle triangle,obtuse angle triangle']},
#  {'question': 'There are 6 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Hexagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 6 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Hexagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 8 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Octagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 6 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Hexagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 8 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Octagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 3 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Traingle',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 8 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Octagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 6 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Hexagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 5 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Pentagon',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']},
#  {'question': 'There are 4 sides of a polygon. What type of polygon is this one?',
#   'answer': 'Rectangle',
#   'options': ['Triangle,Rectangle,Pentagon,Hexagon,Heptagon,Octagon']}]

# %%
def general_physics(list_of_json_object):
    objects = {"water":"1496","wood":"3960","glass":"5640","aluminium":"6420","mercury":"1540","antimony":"3400","Beryllium":"12890","Bismut":"2180","Brass":"4700","Brick":"4200","cadmium":"2780","concrete":"3700","constantan":"5177","copper annealed":"4760","copper rolled":"5010","cork":"518","diamond":"12000","duralumin":"6320","glass silicate flint":"3980","glass light crown":"5100","glass pyrex":"5640","gold":"3240","granite":"5950","iridium":"4790","iron cast":"4994","iron electrolytic":"5950","ivory":"3010","lead annealed":"2160","lead rolled":"1960","lucite":"2680","magnesium annealed":"5770","manganese":"4660","marbel":"3810","molybdenum":"6250","monel":"5350","nickel":"6040","nylon":"2620","platinum":"3260","Polyethylene":"1250","Polystyrene":"2350","rubber butyl":"1830","rubber gum":"1550","rubber neoprene":"1600","silica fused":"5968","silver":"3650","slate":"4510","steel":"5940","stainless steel":"5790","tantalium":"3350","tin rolled":"3320","titanium":"6070","annealed tungsten":"5220","drawn tungsten":"5410","tungsten carbide":"6655","zinc rolled":"4210"}
    key_list = list(objects.keys()) 
    #print(len(key_list))
    val_list = list(objects.values())
    ref_air = {"air":"343"}
    template = "Sound travels faster in denser medium than air. What is the speed of sound in $1 ?"
    duplicity = 100
    while duplicity > 0:
        template_obj = {}
        medium = random.randint(0,54)
        template_question = raplace_parameters(template,[key_list[medium]])
        template_obj["question"] = template_question
        template_obj["answer"] = str(val_list[medium])
        question_options = []
        question_options.append(str(val_list[medium]))
        for i in range(4):
            question_options.append(str(random.randint(100,int(ref_air["air"])-1)))
        random.shuffle(question_options)
        template_obj["options"] = question_options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
general_physics(list_of_json_object)
#print(list_of_json_object)

# %%
def age_problem(list_of_json_object):
    template = "$1 is younger than $2 by $3 years. $4 years ago $2 was $5 years old. What is $1 's age today?"
    yonger_age = random.randint(1,15)
    age_in_year = random.randint(11,75)
    actual_age = random.randint(25,35)
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        younger_name = names[random.randint(0,500)]
        older_name = names[random.randint(501,999)]
        yonger_age = random.randint(1,5)
        age_in_year = random.randint(5,15)
        actual_age = random.randint(25,35)
        temp_variables = [younger_name,older_name,yonger_age,age_in_year,actual_age]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        answer = actual_age + age_in_year - yonger_age
        template_obj["answer"] = answer
        options.append(str(answer))
        for i in range(4):
            opt = actual_age + age_in_year*random.randint(1,3) + random.randint(1,3)*yonger_age
            options.append(str(opt))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
#list_of_json_object.clear()
age_problem(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'answer': '6250',
#   'options': ['6250', '323', '113', '102', '227']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in manganese ?',
#   'answer': '4660',
#   'options': ['183', '327', '290', '239', '4660']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in monel ?',
#   'answer': '5350',
#   'options': ['110', '5350', '282', '322', '302']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nylon ?',
#   'answer': '2620',
#   'options': ['130', '199', '248', '203', '2620']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['178', '255', '3810', '101', '268']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['164', '5010', '128', '307', '166']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['208', '209', '182', '5950', '142']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['101', '201', '207', '124', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in stainless steel ?',
#   'answer': '5790',
#   'options': ['154', '169', '257', '5790', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in silver ?',
#   'answer': '3650',
#   'options': ['3650', '212', '132', '196', '221']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['5100', '339', '256', '175', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['122', '242', '120', '5950', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iridium ?',
#   'answer': '4790',
#   'options': ['298', '196', '242', '4790', '109']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['5010', '212', '161', '282', '261']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['185', '3350', '318', '183', '299']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tungsten carbide ?',
#   'answer': '6655',
#   'options': ['200', '6655', '150', '290', '239']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in cadmium ?',
#   'answer': '2780',
#   'options': ['268', '173', '2780', '238', '295']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '298', '325', '205', '170']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber butyl ?',
#   'answer': '1830',
#   'options': ['327', '202', '142', '299', '1830']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron cast ?',
#   'answer': '4994',
#   'options': ['118', '4994', '246', '143', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['6040', '324', '141', '281', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['340', '4510', '194', '113', '277']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['301', '149', '322', '336', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polyethylene ?',
#   'answer': '1250',
#   'options': ['169', '192', '1250', '101', '228']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['241', '295', '135', '260', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['263', '220', '2680', '221', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '110', '224', '220', '327']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['289', '156', '309', '4510', '153']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['188', '4200', '130', '264', '325']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['197', '178', '275', '101', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['106', '190', '329', '5950', '211']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in drawn tungsten ?',
#   'answer': '5410',
#   'options': ['334', '217', '340', '5410', '317']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['149', '237', '165', '5950', '280']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['291', '283', '109', '5950', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['168', '332', '160', '191', '4200']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brass ?',
#   'answer': '4700',
#   'options': ['324', '179', '243', '287', '4700']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['207', '262', '143', '5640', '202']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in aluminium ?',
#   'answer': '6420',
#   'options': ['205', '265', '319', '236', '6420']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['100', '314', '3350', '298', '283']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['158', '200', '112', '5100', '287']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in diamond ?',
#   'answer': '12000',
#   'options': ['12000', '259', '299', '269', '161']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['175', '272', '2680', '246', '168']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['106', '267', '104', '145', '3350']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber gum ?',
#   'answer': '1550',
#   'options': ['170', '133', '263', '1550', '329']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['3810', '195', '185', '318', '240']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['302', '198', '175', '6040', '213']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tin rolled ?',
#   'answer': '3320',
#   'options': ['132', '310', '3320', '263', '102']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polystyrene ?',
#   'answer': '2350',
#   'options': ['190', '2350', '272', '174', '207']},
#  {'question': "Eduardo is younger than Harry by 4 years. 7 years ago Harry was 30 years old. What is Eduardo 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '56', '48', '52']},
#  {'question': "Pablo is younger than Crosby by 5 years. 10 years ago Crosby was 29 years old. What is Pablo 's age today?",
#   'answer': 34,
#   'options': ['49', '49', '64', '34', '54']},
#  {'question': "Kamden is younger than Morgan by 2 years. 7 years ago Morgan was 35 years old. What is Kamden 's age today?",
#   'answer': 40,
#   'options': ['51', '40', '53', '48', '62']},
#  {'question': "Luca is younger than Edison by 1 years. 15 years ago Edison was 31 years old. What is Luca 's age today?",
#   'answer': 45,
#   'options': ['49', '64', '45', '47', '62']},
#  {'question': "Ivan is younger than Roy by 3 years. 8 years ago Roy was 35 years old. What is Ivan 's age today?",
#   'answer': 40,
#   'options': ['62', '40', '68', '57', '49']},
#  {'question': "Tyson is younger than Gatlin by 2 years. 6 years ago Gatlin was 33 years old. What is Tyson 's age today?",
#   'answer': 37,
#   'options': ['51', '45', '37', '51', '47']},
#  {'question': "Nicholas is younger than Turner by 3 years. 14 years ago Turner was 27 years old. What is Nicholas 's age today?",
#   'answer': 38,
#   'options': ['75', '38', '47', '50', '50']},
#  {'question': "Princeton is younger than Toby by 5 years. 11 years ago Toby was 32 years old. What is Princeton 's age today?",
#   'answer': 38,
#   'options': ['59', '53', '64', '38', '75']},
#  {'question': "Luciano is younger than Davion by 5 years. 15 years ago Davion was 28 years old. What is Luciano 's age today?",
#   'answer': 38,
#   'options': ['83', '58', '73', '38', '58']},
#  {'question': "Joshua is younger than Wilder by 3 years. 14 years ago Wilder was 26 years old. What is Joshua 's age today?",
#   'answer': 37,
#   'options': ['57', '63', '43', '37', '49']},
#  {'question': "Emiliano is younger than Duke by 3 years. 7 years ago Duke was 28 years old. What is Emiliano 's age today?",
#   'answer': 32,
#   'options': ['52', '45', '51', '32', '45']},
#  {'question': "Alejandro is younger than Leighton by 2 years. 15 years ago Leighton was 33 years old. What is Alejandro 's age today?",
#   'answer': 46,
#   'options': ['46', '52', '54', '54', '54']},
#  {'question': "Justin is younger than Koa by 3 years. 15 years ago Koa was 27 years old. What is Justin 's age today?",
#   'answer': 39,
#   'options': ['48', '39', '48', '75', '63']},
#  {'question': "Fabian is younger than Gibson by 1 years. 8 years ago Gibson was 27 years old. What is Fabian 's age today?",
#   'answer': 34,
#   'options': ['54', '37', '52', '34', '38']},
#  {'question': "Henry is younger than Aryan by 3 years. 11 years ago Aryan was 29 years old. What is Henry 's age today?",
#   'answer': 37,
#   'options': ['68', '37', '49', '71', '68']},
#  {'question': "Jensen is younger than Izaiah by 3 years. 5 years ago Izaiah was 33 years old. What is Jensen 's age today?",
#   'answer': 35,
#   'options': ['52', '51', '46', '35', '51']},
#  {'question': "Nikolai is younger than Dash by 4 years. 7 years ago Dash was 30 years old. What is Nikolai 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '63', '52', '41']},
#  {'question': "Hank is younger than Leroy by 2 years. 12 years ago Leroy was 35 years old. What is Hank 's age today?",
#   'answer': 45,
#   'options': ['77', '65', '51', '61', '45']},
#  {'question': "Tyson is younger than Tadeo by 3 years. 10 years ago Tadeo was 28 years old. What is Tyson 's age today?",
#   'answer': 35,
#   'options': ['35', '57', '54', '47', '54']},
#  {'question': "Mark is younger than Azariah by 5 years. 7 years ago Azariah was 35 years old. What is Mark 's age today?",
#   'answer': 37,
#   'options': ['71', '59', '71', '37', '57']},
#  {'question': "Avery is younger than Westin by 1 years. 11 years ago Westin was 32 years old. What is Avery 's age today?",
#   'answer': 42,
#   'options': ['56', '55', '56', '42', '57']},
#  {'question': "Romeo is younger than Gustavo by 2 years. 12 years ago Gustavo was 30 years old. What is Romeo 's age today?",
#   'answer': 40,
#   'options': ['40', '46', '72', '44', '72']},
#  {'question': "Theo is younger than Nova by 2 years. 15 years ago Nova was 35 years old. What is Theo 's age today?",
#   'answer': 48,
#   'options': ['48', '71', '67', '86', '54']},
#  {'question': "Joaquin is younger than Ulises by 2 years. 7 years ago Ulises was 31 years old. What is Joaquin 's age today?",
#   'answer': 36,
#   'options': ['54', '49', '40', '36', '40']},
#  {'question': "Grayson is younger than Toby by 3 years. 15 years ago Toby was 30 years old. What is Grayson 's age today?",
#   'answer': 42,
#   'options': ['42', '69', '84', '78', '51']},
#  {'question': "Hayes is younger than Kendall by 5 years. 12 years ago Kendall was 29 years old. What is Hayes 's age today?",
#   'answer': 36,
#   'options': ['63', '80', '56', '36', '75']},
#  {'question': "August is younger than Konnor by 4 years. 10 years ago Konnor was 31 years old. What is August 's age today?",
#   'answer': 37,
#   'options': ['65', '69', '55', '37', '63']},
#  {'question': "Knox is younger than Franco by 3 years. 6 years ago Franco was 34 years old. What is Knox 's age today?",
#   'answer': 37,
#   'options': ['58', '37', '46', '52', '55']},
#  {'question': "Hank is younger than Lance by 2 years. 6 years ago Lance was 30 years old. What is Hank 's age today?",
#   'answer': 34,
#   'options': ['42', '54', '34', '38', '50']},
#  {'question': "Damian is younger than Elon by 1 years. 7 years ago Elon was 26 years old. What is Damian 's age today?",
#   'answer': 32,
#   'options': ['35', '34', '50', '32', '48']},
#  {'question': "Micah is younger than Heath by 2 years. 15 years ago Heath was 31 years old. What is Micah 's age today?",
#   'answer': 44,
#   'options': ['52', '44', '67', '78', '82']},
#  {'question': "Ayden is younger than Dakari by 2 years. 11 years ago Dakari was 33 years old. What is Ayden 's age today?",
#   'answer': 42,
#   'options': ['57', '59', '42', '61', '70']},
#  {'question': "Brian is younger than Layton by 5 years. 12 years ago Layton was 26 years old. What is Brian 's age today?",
#   'answer': 33,
#   'options': ['67', '48', '33', '67', '48']},
#  {'question': "Jordan is younger than Harley by 4 years. 15 years ago Harley was 34 years old. What is Jordan 's age today?",
#   'answer': 45,
#   'options': ['45', '68', '91', '91', '53']},
#  {'question': "Joel is younger than Ulises by 5 years. 8 years ago Ulises was 31 years old. What is Joel 's age today?",
#   'answer': 34,
#   'options': ['52', '70', '60', '70', '34']},
#  {'question': "Chase is younger than Caspian by 3 years. 8 years ago Caspian was 31 years old. What is Chase 's age today?",
#   'answer': 36,
#   'options': ['36', '61', '48', '61', '42']},
#  {'question': "Ricardo is younger than Reyansh by 3 years. 7 years ago Reyansh was 26 years old. What is Ricardo 's age today?",
#   'answer': 30,
#   'options': ['53', '46', '36', '30', '50']},
#  {'question': "Phillip is younger than Misael by 3 years. 11 years ago Misael was 33 years old. What is Phillip 's age today?",
#   'answer': 41,
#   'options': ['69', '58', '75', '41', '47']},
#  {'question': "Emanuel is younger than Mauricio by 2 years. 10 years ago Mauricio was 35 years old. What is Emanuel 's age today?",
#   'answer': 43,
#   'options': ['67', '71', '47', '43', '61']},
#  {'question': "Edward is younger than Maurice by 4 years. 9 years ago Maurice was 26 years old. What is Edward 's age today?",
#   'answer': 31,
#   'options': ['56', '56', '48', '47', '31']},
#  ...]

# %%
def perimeter(list_of_json_object):
    template = "The side of an square is $1 . What is the perimeter of the square?"
    duplicity = 50
    while(duplicity>0):
        template_obj = {}
        options = []
        side = random.randint(1,1000)
        template_question = raplace_parameters(template,[side])
        template_obj["question"] = template_question
        ans = side * 4
        template_obj["answer"] = ans
        options.append(str(ans))
        for i in range(4):
            options.append(side*random.randint(5,10))
        random.shuffle(options)
        template_obj["options"] = options
        duplicity-=1
        list_of_json_object.append(template_obj)
    return list_of_json_object

# %%
#list_of_json_object.clear()
perimeter(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'answer': '6250',
#   'options': ['6250', '323', '113', '102', '227']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in manganese ?',
#   'answer': '4660',
#   'options': ['183', '327', '290', '239', '4660']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in monel ?',
#   'answer': '5350',
#   'options': ['110', '5350', '282', '322', '302']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nylon ?',
#   'answer': '2620',
#   'options': ['130', '199', '248', '203', '2620']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['178', '255', '3810', '101', '268']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['164', '5010', '128', '307', '166']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['208', '209', '182', '5950', '142']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['101', '201', '207', '124', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in stainless steel ?',
#   'answer': '5790',
#   'options': ['154', '169', '257', '5790', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in silver ?',
#   'answer': '3650',
#   'options': ['3650', '212', '132', '196', '221']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['5100', '339', '256', '175', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['122', '242', '120', '5950', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iridium ?',
#   'answer': '4790',
#   'options': ['298', '196', '242', '4790', '109']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['5010', '212', '161', '282', '261']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['185', '3350', '318', '183', '299']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tungsten carbide ?',
#   'answer': '6655',
#   'options': ['200', '6655', '150', '290', '239']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in cadmium ?',
#   'answer': '2780',
#   'options': ['268', '173', '2780', '238', '295']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '298', '325', '205', '170']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber butyl ?',
#   'answer': '1830',
#   'options': ['327', '202', '142', '299', '1830']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron cast ?',
#   'answer': '4994',
#   'options': ['118', '4994', '246', '143', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['6040', '324', '141', '281', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['340', '4510', '194', '113', '277']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['301', '149', '322', '336', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polyethylene ?',
#   'answer': '1250',
#   'options': ['169', '192', '1250', '101', '228']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['241', '295', '135', '260', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['263', '220', '2680', '221', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '110', '224', '220', '327']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['289', '156', '309', '4510', '153']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['188', '4200', '130', '264', '325']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['197', '178', '275', '101', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['106', '190', '329', '5950', '211']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in drawn tungsten ?',
#   'answer': '5410',
#   'options': ['334', '217', '340', '5410', '317']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['149', '237', '165', '5950', '280']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['291', '283', '109', '5950', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['168', '332', '160', '191', '4200']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brass ?',
#   'answer': '4700',
#   'options': ['324', '179', '243', '287', '4700']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['207', '262', '143', '5640', '202']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in aluminium ?',
#   'answer': '6420',
#   'options': ['205', '265', '319', '236', '6420']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['100', '314', '3350', '298', '283']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['158', '200', '112', '5100', '287']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in diamond ?',
#   'answer': '12000',
#   'options': ['12000', '259', '299', '269', '161']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['175', '272', '2680', '246', '168']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['106', '267', '104', '145', '3350']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber gum ?',
#   'answer': '1550',
#   'options': ['170', '133', '263', '1550', '329']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['3810', '195', '185', '318', '240']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['302', '198', '175', '6040', '213']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tin rolled ?',
#   'answer': '3320',
#   'options': ['132', '310', '3320', '263', '102']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polystyrene ?',
#   'answer': '2350',
#   'options': ['190', '2350', '272', '174', '207']},
#  {'question': "Eduardo is younger than Harry by 4 years. 7 years ago Harry was 30 years old. What is Eduardo 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '56', '48', '52']},
#  {'question': "Pablo is younger than Crosby by 5 years. 10 years ago Crosby was 29 years old. What is Pablo 's age today?",
#   'answer': 34,
#   'options': ['49', '49', '64', '34', '54']},
#  {'question': "Kamden is younger than Morgan by 2 years. 7 years ago Morgan was 35 years old. What is Kamden 's age today?",
#   'answer': 40,
#   'options': ['51', '40', '53', '48', '62']},
#  {'question': "Luca is younger than Edison by 1 years. 15 years ago Edison was 31 years old. What is Luca 's age today?",
#   'answer': 45,
#   'options': ['49', '64', '45', '47', '62']},
#  {'question': "Ivan is younger than Roy by 3 years. 8 years ago Roy was 35 years old. What is Ivan 's age today?",
#   'answer': 40,
#   'options': ['62', '40', '68', '57', '49']},
#  {'question': "Tyson is younger than Gatlin by 2 years. 6 years ago Gatlin was 33 years old. What is Tyson 's age today?",
#   'answer': 37,
#   'options': ['51', '45', '37', '51', '47']},
#  {'question': "Nicholas is younger than Turner by 3 years. 14 years ago Turner was 27 years old. What is Nicholas 's age today?",
#   'answer': 38,
#   'options': ['75', '38', '47', '50', '50']},
#  {'question': "Princeton is younger than Toby by 5 years. 11 years ago Toby was 32 years old. What is Princeton 's age today?",
#   'answer': 38,
#   'options': ['59', '53', '64', '38', '75']},
#  {'question': "Luciano is younger than Davion by 5 years. 15 years ago Davion was 28 years old. What is Luciano 's age today?",
#   'answer': 38,
#   'options': ['83', '58', '73', '38', '58']},
#  {'question': "Joshua is younger than Wilder by 3 years. 14 years ago Wilder was 26 years old. What is Joshua 's age today?",
#   'answer': 37,
#   'options': ['57', '63', '43', '37', '49']},
#  {'question': "Emiliano is younger than Duke by 3 years. 7 years ago Duke was 28 years old. What is Emiliano 's age today?",
#   'answer': 32,
#   'options': ['52', '45', '51', '32', '45']},
#  {'question': "Alejandro is younger than Leighton by 2 years. 15 years ago Leighton was 33 years old. What is Alejandro 's age today?",
#   'answer': 46,
#   'options': ['46', '52', '54', '54', '54']},
#  {'question': "Justin is younger than Koa by 3 years. 15 years ago Koa was 27 years old. What is Justin 's age today?",
#   'answer': 39,
#   'options': ['48', '39', '48', '75', '63']},
#  {'question': "Fabian is younger than Gibson by 1 years. 8 years ago Gibson was 27 years old. What is Fabian 's age today?",
#   'answer': 34,
#   'options': ['54', '37', '52', '34', '38']},
#  {'question': "Henry is younger than Aryan by 3 years. 11 years ago Aryan was 29 years old. What is Henry 's age today?",
#   'answer': 37,
#   'options': ['68', '37', '49', '71', '68']},
#  {'question': "Jensen is younger than Izaiah by 3 years. 5 years ago Izaiah was 33 years old. What is Jensen 's age today?",
#   'answer': 35,
#   'options': ['52', '51', '46', '35', '51']},
#  {'question': "Nikolai is younger than Dash by 4 years. 7 years ago Dash was 30 years old. What is Nikolai 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '63', '52', '41']},
#  {'question': "Hank is younger than Leroy by 2 years. 12 years ago Leroy was 35 years old. What is Hank 's age today?",
#   'answer': 45,
#   'options': ['77', '65', '51', '61', '45']},
#  {'question': "Tyson is younger than Tadeo by 3 years. 10 years ago Tadeo was 28 years old. What is Tyson 's age today?",
#   'answer': 35,
#   'options': ['35', '57', '54', '47', '54']},
#  {'question': "Mark is younger than Azariah by 5 years. 7 years ago Azariah was 35 years old. What is Mark 's age today?",
#   'answer': 37,
#   'options': ['71', '59', '71', '37', '57']},
#  {'question': "Avery is younger than Westin by 1 years. 11 years ago Westin was 32 years old. What is Avery 's age today?",
#   'answer': 42,
#   'options': ['56', '55', '56', '42', '57']},
#  {'question': "Romeo is younger than Gustavo by 2 years. 12 years ago Gustavo was 30 years old. What is Romeo 's age today?",
#   'answer': 40,
#   'options': ['40', '46', '72', '44', '72']},
#  {'question': "Theo is younger than Nova by 2 years. 15 years ago Nova was 35 years old. What is Theo 's age today?",
#   'answer': 48,
#   'options': ['48', '71', '67', '86', '54']},
#  {'question': "Joaquin is younger than Ulises by 2 years. 7 years ago Ulises was 31 years old. What is Joaquin 's age today?",
#   'answer': 36,
#   'options': ['54', '49', '40', '36', '40']},
#  {'question': "Grayson is younger than Toby by 3 years. 15 years ago Toby was 30 years old. What is Grayson 's age today?",
#   'answer': 42,
#   'options': ['42', '69', '84', '78', '51']},
#  {'question': "Hayes is younger than Kendall by 5 years. 12 years ago Kendall was 29 years old. What is Hayes 's age today?",
#   'answer': 36,
#   'options': ['63', '80', '56', '36', '75']},
#  {'question': "August is younger than Konnor by 4 years. 10 years ago Konnor was 31 years old. What is August 's age today?",
#   'answer': 37,
#   'options': ['65', '69', '55', '37', '63']},
#  {'question': "Knox is younger than Franco by 3 years. 6 years ago Franco was 34 years old. What is Knox 's age today?",
#   'answer': 37,
#   'options': ['58', '37', '46', '52', '55']},
#  {'question': "Hank is younger than Lance by 2 years. 6 years ago Lance was 30 years old. What is Hank 's age today?",
#   'answer': 34,
#   'options': ['42', '54', '34', '38', '50']},
#  {'question': "Damian is younger than Elon by 1 years. 7 years ago Elon was 26 years old. What is Damian 's age today?",
#   'answer': 32,
#   'options': ['35', '34', '50', '32', '48']},
#  {'question': "Micah is younger than Heath by 2 years. 15 years ago Heath was 31 years old. What is Micah 's age today?",
#   'answer': 44,
#   'options': ['52', '44', '67', '78', '82']},
#  {'question': "Ayden is younger than Dakari by 2 years. 11 years ago Dakari was 33 years old. What is Ayden 's age today?",
#   'answer': 42,
#   'options': ['57', '59', '42', '61', '70']},
#  {'question': "Brian is younger than Layton by 5 years. 12 years ago Layton was 26 years old. What is Brian 's age today?",
#   'answer': 33,
#   'options': ['67', '48', '33', '67', '48']},
#  {'question': "Jordan is younger than Harley by 4 years. 15 years ago Harley was 34 years old. What is Jordan 's age today?",
#   'answer': 45,
#   'options': ['45', '68', '91', '91', '53']},
#  {'question': "Joel is younger than Ulises by 5 years. 8 years ago Ulises was 31 years old. What is Joel 's age today?",
#   'answer': 34,
#   'options': ['52', '70', '60', '70', '34']},
#  {'question': "Chase is younger than Caspian by 3 years. 8 years ago Caspian was 31 years old. What is Chase 's age today?",
#   'answer': 36,
#   'options': ['36', '61', '48', '61', '42']},
#  {'question': "Ricardo is younger than Reyansh by 3 years. 7 years ago Reyansh was 26 years old. What is Ricardo 's age today?",
#   'answer': 30,
#   'options': ['53', '46', '36', '30', '50']},
#  {'question': "Phillip is younger than Misael by 3 years. 11 years ago Misael was 33 years old. What is Phillip 's age today?",
#   'answer': 41,
#   'options': ['69', '58', '75', '41', '47']},
#  {'question': "Emanuel is younger than Mauricio by 2 years. 10 years ago Mauricio was 35 years old. What is Emanuel 's age today?",
#   'answer': 43,
#   'options': ['67', '71', '47', '43', '61']},
#  {'question': "Edward is younger than Maurice by 4 years. 9 years ago Maurice was 26 years old. What is Edward 's age today?",
#   'answer': 31,
#   'options': ['56', '56', '48', '47', '31']},
#  ...]

# %%
def age_problem_older(list_of_json_object):
    template = "$1 is older than $2 by $3 years. $4 years ago $2 was $5 years old. What is $1 's age today?"
    yonger_age = random.randint(1,15)
    age_in_year = random.randint(25,75)
    actual_age = random.randint(25,65)
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        younger_name = names[random.randint(0,5)]
        older_name = names[random.randint(0,5)]
        yonger_age = random.randint(1,5)
        age_in_year = random.randint(5,15)
        actual_age = random.randint(25,35)
        temp_variables = [younger_name,older_name,yonger_age,age_in_year,actual_age]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        answer = actual_age + age_in_year + yonger_age
        template_obj["answer"] = answer
        options.append(str(answer))
        for i in range(4):
            opt = actual_age + age_in_year*random.randint(1,3) - random.randint(1,3)*yonger_age
            options.append(str(opt))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
#list_of_json_object.clear()
age_problem_older(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'answer': '6250',
#   'options': ['6250', '323', '113', '102', '227']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in manganese ?',
#   'answer': '4660',
#   'options': ['183', '327', '290', '239', '4660']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in monel ?',
#   'answer': '5350',
#   'options': ['110', '5350', '282', '322', '302']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nylon ?',
#   'answer': '2620',
#   'options': ['130', '199', '248', '203', '2620']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['178', '255', '3810', '101', '268']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['164', '5010', '128', '307', '166']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['208', '209', '182', '5950', '142']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['101', '201', '207', '124', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in stainless steel ?',
#   'answer': '5790',
#   'options': ['154', '169', '257', '5790', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in silver ?',
#   'answer': '3650',
#   'options': ['3650', '212', '132', '196', '221']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['5100', '339', '256', '175', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['122', '242', '120', '5950', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iridium ?',
#   'answer': '4790',
#   'options': ['298', '196', '242', '4790', '109']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['5010', '212', '161', '282', '261']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['185', '3350', '318', '183', '299']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tungsten carbide ?',
#   'answer': '6655',
#   'options': ['200', '6655', '150', '290', '239']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in cadmium ?',
#   'answer': '2780',
#   'options': ['268', '173', '2780', '238', '295']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '298', '325', '205', '170']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber butyl ?',
#   'answer': '1830',
#   'options': ['327', '202', '142', '299', '1830']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron cast ?',
#   'answer': '4994',
#   'options': ['118', '4994', '246', '143', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['6040', '324', '141', '281', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['340', '4510', '194', '113', '277']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['301', '149', '322', '336', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polyethylene ?',
#   'answer': '1250',
#   'options': ['169', '192', '1250', '101', '228']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['241', '295', '135', '260', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['263', '220', '2680', '221', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '110', '224', '220', '327']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['289', '156', '309', '4510', '153']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['188', '4200', '130', '264', '325']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['197', '178', '275', '101', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['106', '190', '329', '5950', '211']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in drawn tungsten ?',
#   'answer': '5410',
#   'options': ['334', '217', '340', '5410', '317']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['149', '237', '165', '5950', '280']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['291', '283', '109', '5950', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['168', '332', '160', '191', '4200']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brass ?',
#   'answer': '4700',
#   'options': ['324', '179', '243', '287', '4700']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['207', '262', '143', '5640', '202']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in aluminium ?',
#   'answer': '6420',
#   'options': ['205', '265', '319', '236', '6420']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['100', '314', '3350', '298', '283']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['158', '200', '112', '5100', '287']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in diamond ?',
#   'answer': '12000',
#   'options': ['12000', '259', '299', '269', '161']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['175', '272', '2680', '246', '168']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['106', '267', '104', '145', '3350']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber gum ?',
#   'answer': '1550',
#   'options': ['170', '133', '263', '1550', '329']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['3810', '195', '185', '318', '240']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['302', '198', '175', '6040', '213']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tin rolled ?',
#   'answer': '3320',
#   'options': ['132', '310', '3320', '263', '102']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polystyrene ?',
#   'answer': '2350',
#   'options': ['190', '2350', '272', '174', '207']},
#  {'question': "Eduardo is younger than Harry by 4 years. 7 years ago Harry was 30 years old. What is Eduardo 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '56', '48', '52']},
#  {'question': "Pablo is younger than Crosby by 5 years. 10 years ago Crosby was 29 years old. What is Pablo 's age today?",
#   'answer': 34,
#   'options': ['49', '49', '64', '34', '54']},
#  {'question': "Kamden is younger than Morgan by 2 years. 7 years ago Morgan was 35 years old. What is Kamden 's age today?",
#   'answer': 40,
#   'options': ['51', '40', '53', '48', '62']},
#  {'question': "Luca is younger than Edison by 1 years. 15 years ago Edison was 31 years old. What is Luca 's age today?",
#   'answer': 45,
#   'options': ['49', '64', '45', '47', '62']},
#  {'question': "Ivan is younger than Roy by 3 years. 8 years ago Roy was 35 years old. What is Ivan 's age today?",
#   'answer': 40,
#   'options': ['62', '40', '68', '57', '49']},
#  {'question': "Tyson is younger than Gatlin by 2 years. 6 years ago Gatlin was 33 years old. What is Tyson 's age today?",
#   'answer': 37,
#   'options': ['51', '45', '37', '51', '47']},
#  {'question': "Nicholas is younger than Turner by 3 years. 14 years ago Turner was 27 years old. What is Nicholas 's age today?",
#   'answer': 38,
#   'options': ['75', '38', '47', '50', '50']},
#  {'question': "Princeton is younger than Toby by 5 years. 11 years ago Toby was 32 years old. What is Princeton 's age today?",
#   'answer': 38,
#   'options': ['59', '53', '64', '38', '75']},
#  {'question': "Luciano is younger than Davion by 5 years. 15 years ago Davion was 28 years old. What is Luciano 's age today?",
#   'answer': 38,
#   'options': ['83', '58', '73', '38', '58']},
#  {'question': "Joshua is younger than Wilder by 3 years. 14 years ago Wilder was 26 years old. What is Joshua 's age today?",
#   'answer': 37,
#   'options': ['57', '63', '43', '37', '49']},
#  {'question': "Emiliano is younger than Duke by 3 years. 7 years ago Duke was 28 years old. What is Emiliano 's age today?",
#   'answer': 32,
#   'options': ['52', '45', '51', '32', '45']},
#  {'question': "Alejandro is younger than Leighton by 2 years. 15 years ago Leighton was 33 years old. What is Alejandro 's age today?",
#   'answer': 46,
#   'options': ['46', '52', '54', '54', '54']},
#  {'question': "Justin is younger than Koa by 3 years. 15 years ago Koa was 27 years old. What is Justin 's age today?",
#   'answer': 39,
#   'options': ['48', '39', '48', '75', '63']},
#  {'question': "Fabian is younger than Gibson by 1 years. 8 years ago Gibson was 27 years old. What is Fabian 's age today?",
#   'answer': 34,
#   'options': ['54', '37', '52', '34', '38']},
#  {'question': "Henry is younger than Aryan by 3 years. 11 years ago Aryan was 29 years old. What is Henry 's age today?",
#   'answer': 37,
#   'options': ['68', '37', '49', '71', '68']},
#  {'question': "Jensen is younger than Izaiah by 3 years. 5 years ago Izaiah was 33 years old. What is Jensen 's age today?",
#   'answer': 35,
#   'options': ['52', '51', '46', '35', '51']},
#  {'question': "Nikolai is younger than Dash by 4 years. 7 years ago Dash was 30 years old. What is Nikolai 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '63', '52', '41']},
#  {'question': "Hank is younger than Leroy by 2 years. 12 years ago Leroy was 35 years old. What is Hank 's age today?",
#   'answer': 45,
#   'options': ['77', '65', '51', '61', '45']},
#  {'question': "Tyson is younger than Tadeo by 3 years. 10 years ago Tadeo was 28 years old. What is Tyson 's age today?",
#   'answer': 35,
#   'options': ['35', '57', '54', '47', '54']},
#  {'question': "Mark is younger than Azariah by 5 years. 7 years ago Azariah was 35 years old. What is Mark 's age today?",
#   'answer': 37,
#   'options': ['71', '59', '71', '37', '57']},
#  {'question': "Avery is younger than Westin by 1 years. 11 years ago Westin was 32 years old. What is Avery 's age today?",
#   'answer': 42,
#   'options': ['56', '55', '56', '42', '57']},
#  {'question': "Romeo is younger than Gustavo by 2 years. 12 years ago Gustavo was 30 years old. What is Romeo 's age today?",
#   'answer': 40,
#   'options': ['40', '46', '72', '44', '72']},
#  {'question': "Theo is younger than Nova by 2 years. 15 years ago Nova was 35 years old. What is Theo 's age today?",
#   'answer': 48,
#   'options': ['48', '71', '67', '86', '54']},
#  {'question': "Joaquin is younger than Ulises by 2 years. 7 years ago Ulises was 31 years old. What is Joaquin 's age today?",
#   'answer': 36,
#   'options': ['54', '49', '40', '36', '40']},
#  {'question': "Grayson is younger than Toby by 3 years. 15 years ago Toby was 30 years old. What is Grayson 's age today?",
#   'answer': 42,
#   'options': ['42', '69', '84', '78', '51']},
#  {'question': "Hayes is younger than Kendall by 5 years. 12 years ago Kendall was 29 years old. What is Hayes 's age today?",
#   'answer': 36,
#   'options': ['63', '80', '56', '36', '75']},
#  {'question': "August is younger than Konnor by 4 years. 10 years ago Konnor was 31 years old. What is August 's age today?",
#   'answer': 37,
#   'options': ['65', '69', '55', '37', '63']},
#  {'question': "Knox is younger than Franco by 3 years. 6 years ago Franco was 34 years old. What is Knox 's age today?",
#   'answer': 37,
#   'options': ['58', '37', '46', '52', '55']},
#  {'question': "Hank is younger than Lance by 2 years. 6 years ago Lance was 30 years old. What is Hank 's age today?",
#   'answer': 34,
#   'options': ['42', '54', '34', '38', '50']},
#  {'question': "Damian is younger than Elon by 1 years. 7 years ago Elon was 26 years old. What is Damian 's age today?",
#   'answer': 32,
#   'options': ['35', '34', '50', '32', '48']},
#  {'question': "Micah is younger than Heath by 2 years. 15 years ago Heath was 31 years old. What is Micah 's age today?",
#   'answer': 44,
#   'options': ['52', '44', '67', '78', '82']},
#  {'question': "Ayden is younger than Dakari by 2 years. 11 years ago Dakari was 33 years old. What is Ayden 's age today?",
#   'answer': 42,
#   'options': ['57', '59', '42', '61', '70']},
#  {'question': "Brian is younger than Layton by 5 years. 12 years ago Layton was 26 years old. What is Brian 's age today?",
#   'answer': 33,
#   'options': ['67', '48', '33', '67', '48']},
#  {'question': "Jordan is younger than Harley by 4 years. 15 years ago Harley was 34 years old. What is Jordan 's age today?",
#   'answer': 45,
#   'options': ['45', '68', '91', '91', '53']},
#  {'question': "Joel is younger than Ulises by 5 years. 8 years ago Ulises was 31 years old. What is Joel 's age today?",
#   'answer': 34,
#   'options': ['52', '70', '60', '70', '34']},
#  {'question': "Chase is younger than Caspian by 3 years. 8 years ago Caspian was 31 years old. What is Chase 's age today?",
#   'answer': 36,
#   'options': ['36', '61', '48', '61', '42']},
#  {'question': "Ricardo is younger than Reyansh by 3 years. 7 years ago Reyansh was 26 years old. What is Ricardo 's age today?",
#   'answer': 30,
#   'options': ['53', '46', '36', '30', '50']},
#  {'question': "Phillip is younger than Misael by 3 years. 11 years ago Misael was 33 years old. What is Phillip 's age today?",
#   'answer': 41,
#   'options': ['69', '58', '75', '41', '47']},
#  {'question': "Emanuel is younger than Mauricio by 2 years. 10 years ago Mauricio was 35 years old. What is Emanuel 's age today?",
#   'answer': 43,
#   'options': ['67', '71', '47', '43', '61']},
#  {'question': "Edward is younger than Maurice by 4 years. 9 years ago Maurice was 26 years old. What is Edward 's age today?",
#   'answer': 31,
#   'options': ['56', '56', '48', '47', '31']},
#  ...]

# %%
def mean(list_of_json_object):
    verbs = ["height","weight","length","area","size"]
    nouns = ["human","martians","tigers","elephants","kangaroos","cats","dogs"]
    template = "What is the mean $1 of the set of given $2 ? $3"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        verb = verbs[random.randint(0,4)]
        noun = nouns[random.randint(0,6)]
        set_of_obj = ""
        sum_ = 0
        length = random.randint(5,50)
        for i in range(length):
            obj  = random.randint(1,50)
            sum_ += obj
            set_of_obj+=(str(obj)+" ")
        temp_variables = [verb,noun,set_of_obj]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        ans = sum_ / length
        ans = str("%.2f" % ans)
        template_obj["answer"] = ans
        options.append(ans)
        for i in range(4):
            opt = float(ans) * random.randint(2,5)
            opt = str("%.2f" % opt)
            options.append(opt)
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
#list_of_json_object.clear()
mean(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'answer': '6250',
#   'options': ['6250', '323', '113', '102', '227']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in manganese ?',
#   'answer': '4660',
#   'options': ['183', '327', '290', '239', '4660']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in monel ?',
#   'answer': '5350',
#   'options': ['110', '5350', '282', '322', '302']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nylon ?',
#   'answer': '2620',
#   'options': ['130', '199', '248', '203', '2620']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['178', '255', '3810', '101', '268']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['164', '5010', '128', '307', '166']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['208', '209', '182', '5950', '142']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['101', '201', '207', '124', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in stainless steel ?',
#   'answer': '5790',
#   'options': ['154', '169', '257', '5790', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in silver ?',
#   'answer': '3650',
#   'options': ['3650', '212', '132', '196', '221']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['5100', '339', '256', '175', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['122', '242', '120', '5950', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iridium ?',
#   'answer': '4790',
#   'options': ['298', '196', '242', '4790', '109']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['5010', '212', '161', '282', '261']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['185', '3350', '318', '183', '299']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tungsten carbide ?',
#   'answer': '6655',
#   'options': ['200', '6655', '150', '290', '239']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in cadmium ?',
#   'answer': '2780',
#   'options': ['268', '173', '2780', '238', '295']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '298', '325', '205', '170']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber butyl ?',
#   'answer': '1830',
#   'options': ['327', '202', '142', '299', '1830']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron cast ?',
#   'answer': '4994',
#   'options': ['118', '4994', '246', '143', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['6040', '324', '141', '281', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['340', '4510', '194', '113', '277']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['301', '149', '322', '336', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polyethylene ?',
#   'answer': '1250',
#   'options': ['169', '192', '1250', '101', '228']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['241', '295', '135', '260', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['263', '220', '2680', '221', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '110', '224', '220', '327']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['289', '156', '309', '4510', '153']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['188', '4200', '130', '264', '325']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['197', '178', '275', '101', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['106', '190', '329', '5950', '211']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in drawn tungsten ?',
#   'answer': '5410',
#   'options': ['334', '217', '340', '5410', '317']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['149', '237', '165', '5950', '280']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['291', '283', '109', '5950', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['168', '332', '160', '191', '4200']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brass ?',
#   'answer': '4700',
#   'options': ['324', '179', '243', '287', '4700']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['207', '262', '143', '5640', '202']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in aluminium ?',
#   'answer': '6420',
#   'options': ['205', '265', '319', '236', '6420']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['100', '314', '3350', '298', '283']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['158', '200', '112', '5100', '287']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in diamond ?',
#   'answer': '12000',
#   'options': ['12000', '259', '299', '269', '161']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['175', '272', '2680', '246', '168']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['106', '267', '104', '145', '3350']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber gum ?',
#   'answer': '1550',
#   'options': ['170', '133', '263', '1550', '329']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['3810', '195', '185', '318', '240']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['302', '198', '175', '6040', '213']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tin rolled ?',
#   'answer': '3320',
#   'options': ['132', '310', '3320', '263', '102']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polystyrene ?',
#   'answer': '2350',
#   'options': ['190', '2350', '272', '174', '207']},
#  {'question': "Eduardo is younger than Harry by 4 years. 7 years ago Harry was 30 years old. What is Eduardo 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '56', '48', '52']},
#  {'question': "Pablo is younger than Crosby by 5 years. 10 years ago Crosby was 29 years old. What is Pablo 's age today?",
#   'answer': 34,
#   'options': ['49', '49', '64', '34', '54']},
#  {'question': "Kamden is younger than Morgan by 2 years. 7 years ago Morgan was 35 years old. What is Kamden 's age today?",
#   'answer': 40,
#   'options': ['51', '40', '53', '48', '62']},
#  {'question': "Luca is younger than Edison by 1 years. 15 years ago Edison was 31 years old. What is Luca 's age today?",
#   'answer': 45,
#   'options': ['49', '64', '45', '47', '62']},
#  {'question': "Ivan is younger than Roy by 3 years. 8 years ago Roy was 35 years old. What is Ivan 's age today?",
#   'answer': 40,
#   'options': ['62', '40', '68', '57', '49']},
#  {'question': "Tyson is younger than Gatlin by 2 years. 6 years ago Gatlin was 33 years old. What is Tyson 's age today?",
#   'answer': 37,
#   'options': ['51', '45', '37', '51', '47']},
#  {'question': "Nicholas is younger than Turner by 3 years. 14 years ago Turner was 27 years old. What is Nicholas 's age today?",
#   'answer': 38,
#   'options': ['75', '38', '47', '50', '50']},
#  {'question': "Princeton is younger than Toby by 5 years. 11 years ago Toby was 32 years old. What is Princeton 's age today?",
#   'answer': 38,
#   'options': ['59', '53', '64', '38', '75']},
#  {'question': "Luciano is younger than Davion by 5 years. 15 years ago Davion was 28 years old. What is Luciano 's age today?",
#   'answer': 38,
#   'options': ['83', '58', '73', '38', '58']},
#  {'question': "Joshua is younger than Wilder by 3 years. 14 years ago Wilder was 26 years old. What is Joshua 's age today?",
#   'answer': 37,
#   'options': ['57', '63', '43', '37', '49']},
#  {'question': "Emiliano is younger than Duke by 3 years. 7 years ago Duke was 28 years old. What is Emiliano 's age today?",
#   'answer': 32,
#   'options': ['52', '45', '51', '32', '45']},
#  {'question': "Alejandro is younger than Leighton by 2 years. 15 years ago Leighton was 33 years old. What is Alejandro 's age today?",
#   'answer': 46,
#   'options': ['46', '52', '54', '54', '54']},
#  {'question': "Justin is younger than Koa by 3 years. 15 years ago Koa was 27 years old. What is Justin 's age today?",
#   'answer': 39,
#   'options': ['48', '39', '48', '75', '63']},
#  {'question': "Fabian is younger than Gibson by 1 years. 8 years ago Gibson was 27 years old. What is Fabian 's age today?",
#   'answer': 34,
#   'options': ['54', '37', '52', '34', '38']},
#  {'question': "Henry is younger than Aryan by 3 years. 11 years ago Aryan was 29 years old. What is Henry 's age today?",
#   'answer': 37,
#   'options': ['68', '37', '49', '71', '68']},
#  {'question': "Jensen is younger than Izaiah by 3 years. 5 years ago Izaiah was 33 years old. What is Jensen 's age today?",
#   'answer': 35,
#   'options': ['52', '51', '46', '35', '51']},
#  {'question': "Nikolai is younger than Dash by 4 years. 7 years ago Dash was 30 years old. What is Nikolai 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '63', '52', '41']},
#  {'question': "Hank is younger than Leroy by 2 years. 12 years ago Leroy was 35 years old. What is Hank 's age today?",
#   'answer': 45,
#   'options': ['77', '65', '51', '61', '45']},
#  {'question': "Tyson is younger than Tadeo by 3 years. 10 years ago Tadeo was 28 years old. What is Tyson 's age today?",
#   'answer': 35,
#   'options': ['35', '57', '54', '47', '54']},
#  {'question': "Mark is younger than Azariah by 5 years. 7 years ago Azariah was 35 years old. What is Mark 's age today?",
#   'answer': 37,
#   'options': ['71', '59', '71', '37', '57']},
#  {'question': "Avery is younger than Westin by 1 years. 11 years ago Westin was 32 years old. What is Avery 's age today?",
#   'answer': 42,
#   'options': ['56', '55', '56', '42', '57']},
#  {'question': "Romeo is younger than Gustavo by 2 years. 12 years ago Gustavo was 30 years old. What is Romeo 's age today?",
#   'answer': 40,
#   'options': ['40', '46', '72', '44', '72']},
#  {'question': "Theo is younger than Nova by 2 years. 15 years ago Nova was 35 years old. What is Theo 's age today?",
#   'answer': 48,
#   'options': ['48', '71', '67', '86', '54']},
#  {'question': "Joaquin is younger than Ulises by 2 years. 7 years ago Ulises was 31 years old. What is Joaquin 's age today?",
#   'answer': 36,
#   'options': ['54', '49', '40', '36', '40']},
#  {'question': "Grayson is younger than Toby by 3 years. 15 years ago Toby was 30 years old. What is Grayson 's age today?",
#   'answer': 42,
#   'options': ['42', '69', '84', '78', '51']},
#  {'question': "Hayes is younger than Kendall by 5 years. 12 years ago Kendall was 29 years old. What is Hayes 's age today?",
#   'answer': 36,
#   'options': ['63', '80', '56', '36', '75']},
#  {'question': "August is younger than Konnor by 4 years. 10 years ago Konnor was 31 years old. What is August 's age today?",
#   'answer': 37,
#   'options': ['65', '69', '55', '37', '63']},
#  {'question': "Knox is younger than Franco by 3 years. 6 years ago Franco was 34 years old. What is Knox 's age today?",
#   'answer': 37,
#   'options': ['58', '37', '46', '52', '55']},
#  {'question': "Hank is younger than Lance by 2 years. 6 years ago Lance was 30 years old. What is Hank 's age today?",
#   'answer': 34,
#   'options': ['42', '54', '34', '38', '50']},
#  {'question': "Damian is younger than Elon by 1 years. 7 years ago Elon was 26 years old. What is Damian 's age today?",
#   'answer': 32,
#   'options': ['35', '34', '50', '32', '48']},
#  {'question': "Micah is younger than Heath by 2 years. 15 years ago Heath was 31 years old. What is Micah 's age today?",
#   'answer': 44,
#   'options': ['52', '44', '67', '78', '82']},
#  {'question': "Ayden is younger than Dakari by 2 years. 11 years ago Dakari was 33 years old. What is Ayden 's age today?",
#   'answer': 42,
#   'options': ['57', '59', '42', '61', '70']},
#  {'question': "Brian is younger than Layton by 5 years. 12 years ago Layton was 26 years old. What is Brian 's age today?",
#   'answer': 33,
#   'options': ['67', '48', '33', '67', '48']},
#  {'question': "Jordan is younger than Harley by 4 years. 15 years ago Harley was 34 years old. What is Jordan 's age today?",
#   'answer': 45,
#   'options': ['45', '68', '91', '91', '53']},
#  {'question': "Joel is younger than Ulises by 5 years. 8 years ago Ulises was 31 years old. What is Joel 's age today?",
#   'answer': 34,
#   'options': ['52', '70', '60', '70', '34']},
#  {'question': "Chase is younger than Caspian by 3 years. 8 years ago Caspian was 31 years old. What is Chase 's age today?",
#   'answer': 36,
#   'options': ['36', '61', '48', '61', '42']},
#  {'question': "Ricardo is younger than Reyansh by 3 years. 7 years ago Reyansh was 26 years old. What is Ricardo 's age today?",
#   'answer': 30,
#   'options': ['53', '46', '36', '30', '50']},
#  {'question': "Phillip is younger than Misael by 3 years. 11 years ago Misael was 33 years old. What is Phillip 's age today?",
#   'answer': 41,
#   'options': ['69', '58', '75', '41', '47']},
#  {'question': "Emanuel is younger than Mauricio by 2 years. 10 years ago Mauricio was 35 years old. What is Emanuel 's age today?",
#   'answer': 43,
#   'options': ['67', '71', '47', '43', '61']},
#  {'question': "Edward is younger than Maurice by 4 years. 9 years ago Maurice was 26 years old. What is Edward 's age today?",
#   'answer': 31,
#   'options': ['56', '56', '48', '47', '31']},
#  ...]

# %%
def median(list_of_json_object):
    verbs = ["height","weight","length","area","size"]
    nouns = ["human","martians","tigers","elephants","kangaroos","cats","dogs"]
    template = "What is the median $1 of the set of given $2 ? $3"
    duplicity = 50
    while duplicity > 0:
        template_obj = {}
        options = []
        verb = verbs[random.randint(0,4)]
        noun = nouns[random.randint(0,6)]
        median_set = []
        set_of_obj = ""
        length = random.randint(5,50)
        for i in range(length):
            obj  = random.randint(1,50)
            set_of_obj+=(str(obj)+" ")
            median_set.append(obj)
        temp_variables = [verb,noun,set_of_obj]
        template_question = raplace_parameters(template,temp_variables)
        template_obj["question"] = template_question
        median_set.sort()
        ans = 0
        if len(median_set)%2==0:
            ans = (median_set[int(len(median_set)/2)] + median_set[int(len(median_set)/2)-1])/2
        else:
            ans = (median_set[int(len(median_set)/2)])
        ans = str("%.2f" % ans)
        template_obj["answer"] = ans
        options.append(ans)
        for i in range(4):
            opt = float(median_set[random.randint(0,length-1)])
            opt = str("%.2f" % opt)
            options.append(opt)
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1
    return list_of_json_object

# %%
#list_of_json_object.clear()
median(list_of_json_object)
#print(list_of_json_object)
# Out:
# [{'question': 'The current temperature of the living room is 63 . We turned on the cooler for 52 minutes. What is the temperature after 52 minutes?',
#   'answer': 57,
#   'options': [57, 65, 69, 85, 82]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 57,
#   'options': [57, 63, 73, 62, 80]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [124, 118, 150, 123, 125]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 36 minutes. What is the temperature after 36 minutes?',
#   'answer': 66,
#   'options': [86, 66, 81, 101, 82]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 78,
#   'options': [78, 84, 108, 84, 81]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 107,
#   'options': [107, 109, 108, 108, 122]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 102,
#   'options': [130, 129, 111, 108, 102]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 109,
#   'options': [131, 118, 132, 119, 109]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 76,
#   'options': [93, 98, 95, 84, 76]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 72,
#   'options': [90, 72, 83, 122, 96]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 17 minutes. What is the temperature after 17 minutes?',
#   'answer': 98,
#   'options': [131, 102, 124, 98, 105]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 103,
#   'options': [110, 105, 118, 103, 138]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 66,
#   'options': [66, 74, 76, 99, 72]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 64,
#   'options': [67, 65, 78, 64, 68]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 86,
#   'options': [105, 100, 86, 92, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 99,
#   'options': [99, 120, 102, 105, 101]},
#  {'question': 'The current temperature of the living room is 82 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 73,
#   'options': [110, 103, 83, 73, 90]},
#  {'question': 'The current temperature of the living room is 52 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 47,
#   'options': [47, 58, 57, 83, 57]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 57,
#   'options': [73, 67, 57, 97, 73]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 30 minutes. What is the temperature after 30 minutes?',
#   'answer': 69,
#   'options': [69, 87, 75, 78, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 60,
#   'options': [92, 79, 79, 60, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 65 minutes. What is the temperature after 65 minutes?',
#   'answer': 43,
#   'options': [43, 56, 72, 59, 60]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 88 minutes. What is the temperature after 88 minutes?',
#   'answer': 107,
#   'options': [115, 107, 115, 115, 118]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [69, 65, 84, 81, 77]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 98,
#   'options': [98, 102, 103, 102, 115]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 71,
#   'options': [71, 103, 78, 103, 86]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 65,
#   'options': [82, 72, 65, 89, 75]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 63,
#   'options': [83, 68, 70, 63, 65]},
#  {'question': 'The current temperature of the living room is 61 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 50,
#   'options': [50, 77, 78, 88, 64]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 94,
#   'options': [108, 110, 120, 108, 94]},
#  {'question': 'The current temperature of the living room is 118 . We turned on the cooler for 78 minutes. What is the temperature after 78 minutes?',
#   'answer': 116,
#   'options': [123, 124, 122, 116, 135]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 74,
#   'options': [81, 83, 74, 102, 77]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 79 minutes. What is the temperature after 79 minutes?',
#   'answer': 75,
#   'options': [75, 97, 96, 99, 94]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 58,
#   'options': [77, 67, 58, 76, 77]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [40, 90, 59, 61, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 67,
#   'options': [96, 67, 79, 73, 79]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 53 minutes. What is the temperature after 53 minutes?',
#   'answer': 60,
#   'options': [60, 74, 66, 64, 82]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 113,
#   'options': [125, 127, 141, 113, 150]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 92,
#   'options': [105, 112, 101, 92, 107]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 55 minutes. What is the temperature after 55 minutes?',
#   'answer': 117,
#   'options': [121, 137, 117, 150, 122]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 61 minutes. What is the temperature after 61 minutes?',
#   'answer': 46,
#   'options': [60, 59, 66, 56, 46]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [110, 103, 107, 105, 111]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 47 minutes. What is the temperature after 47 minutes?',
#   'answer': 113,
#   'options': [143, 139, 125, 113, 152]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 50,
#   'options': [68, 94, 71, 64, 50]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 108,
#   'options': [118, 112, 114, 113, 108]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 115,
#   'options': [115, 148, 119, 120, 119]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 95,
#   'options': [95, 104, 116, 102, 119]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 77,
#   'options': [92, 91, 87, 80, 77]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 73,
#   'options': [89, 88, 93, 73, 77]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 66,
#   'options': [73, 81, 66, 70, 69]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 68,
#   'options': [86, 80, 68, 78, 80]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 120,
#   'options': [148, 125, 143, 120, 122]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 81,
#   'options': [100, 81, 92, 101, 111]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 79,
#   'options': [98, 86, 90, 106, 79]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 87,
#   'options': [90, 97, 87, 92, 97]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 87,
#   'options': [96, 91, 87, 100, 109]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 60,
#   'options': [86, 60, 70, 83, 80]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 105,
#   'options': [115, 123, 130, 105, 121]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 74 minutes. What is the temperature after 74 minutes?',
#   'answer': 65,
#   'options': [81, 65, 66, 68, 67]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 108 minutes. What is the temperature after 108 minutes?',
#   'answer': 68,
#   'options': [104, 85, 80, 68, 90]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 111,
#   'options': [125, 114, 111, 114, 132]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 65,
#   'options': [72, 69, 67, 65, 78]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 98,
#   'options': [116, 98, 110, 107, 115]},
#  {'question': 'The current temperature of the living room is 101 . We turned on the cooler for 97 minutes. What is the temperature after 97 minutes?',
#   'answer': 88,
#   'options': [88, 107, 114, 102, 103]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 54,
#   'options': [54, 66, 65, 67, 66]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 77,
#   'options': [77, 81, 81, 79, 80]},
#  {'question': 'The current temperature of the living room is 60 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 57,
#   'options': [79, 68, 67, 57, 67]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 21 minutes. What is the temperature after 21 minutes?',
#   'answer': 66,
#   'options': [75, 84, 73, 75, 66]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 105,
#   'options': [127, 105, 132, 135, 111]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 97,
#   'options': [129, 120, 114, 110, 97]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 96,
#   'options': [120, 96, 110, 127, 112]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 90 minutes. What is the temperature after 90 minutes?',
#   'answer': 88,
#   'options': [107, 104, 105, 88, 139]},
#  {'question': 'The current temperature of the living room is 102 . We turned on the cooler for 44 minutes. What is the temperature after 44 minutes?',
#   'answer': 98,
#   'options': [108, 110, 115, 98, 128]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 103,
#   'options': [139, 116, 147, 123, 103]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 82,
#   'options': [100, 86, 82, 105, 98]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 66,
#   'options': [78, 75, 66, 75, 74]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 97,
#   'options': [106, 106, 97, 137, 122]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 57,
#   'options': [70, 80, 57, 71, 79]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 68 minutes. What is the temperature after 68 minutes?',
#   'answer': 86,
#   'options': [90, 91, 91, 95, 86]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 70,
#   'options': [88, 76, 86, 70, 86]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 56,
#   'options': [81, 75, 77, 102, 56]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 38 minutes. What is the temperature after 38 minutes?',
#   'answer': 90,
#   'options': [124, 90, 128, 115, 111]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 84,
#   'options': [88, 89, 93, 105, 84]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 65,
#   'options': [65, 73, 94, 89, 68]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 77,
#   'options': [88, 77, 118, 105, 96]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 66,
#   'options': [98, 66, 78, 96, 78]},
#  {'question': 'The current temperature of the living room is 95 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 94,
#   'options': [94, 103, 100, 111, 100]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 48,
#   'options': [57, 48, 76, 71, 58]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 14 minutes. What is the temperature after 14 minutes?',
#   'answer': 118,
#   'options': [121, 123, 118, 123, 133]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 96 minutes. What is the temperature after 96 minutes?',
#   'answer': 108,
#   'options': [123, 108, 112, 119, 136]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 50,
#   'options': [50, 57, 64, 67, 64]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 45 minutes. What is the temperature after 45 minutes?',
#   'answer': 71,
#   'options': [85, 94, 71, 84, 77]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 89,
#   'options': [95, 107, 120, 89, 96]},
#  {'question': 'The current temperature of the living room is 63 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 58,
#   'options': [75, 64, 73, 58, 101]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 85,
#   'options': [116, 85, 106, 117, 103]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 48,
#   'options': [60, 48, 66, 59, 90]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 45,
#   'options': [57, 66, 45, 54, 76]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 76,
#   'options': [83, 79, 95, 76, 105]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 111,
#   'options': [120, 152, 121, 124, 111]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 92,
#   'options': [107, 115, 92, 111, 110]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 113 minutes. What is the temperature after 113 minutes?',
#   'answer': 112,
#   'options': [136, 121, 112, 133, 119]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 113,
#   'options': [119, 135, 125, 121, 113]},
#  {'question': 'The current temperature of the living room is 109 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 104,
#   'options': [142, 119, 104, 133, 117]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 96,
#   'options': [98, 96, 104, 118, 122]},
#  {'question': 'The current temperature of the living room is 54 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 53,
#   'options': [59, 70, 53, 63, 63]},
#  {'question': 'The current temperature of the living room is 87 . We turned on the cooler for 62 minutes. What is the temperature after 62 minutes?',
#   'answer': 86,
#   'options': [93, 103, 86, 90, 105]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 114 minutes. What is the temperature after 114 minutes?',
#   'answer': 54,
#   'options': [66, 84, 54, 94, 69]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 113,
#   'options': [124, 120, 115, 113, 118]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 41 minutes. What is the temperature after 41 minutes?',
#   'answer': 86,
#   'options': [86, 94, 95, 93, 106]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 103,
#   'options': [111, 117, 119, 118, 103]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 79,
#   'options': [92, 89, 82, 79, 81]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 53,
#   'options': [93, 74, 72, 53, 77]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 52,
#   'options': [75, 75, 84, 52, 86]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 71 minutes. What is the temperature after 71 minutes?',
#   'answer': 67,
#   'options': [67, 108, 88, 92, 87]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 85,
#   'options': [85, 88, 86, 87, 91]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 49,
#   'options': [73, 71, 70, 64, 49]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 73,
#   'options': [88, 84, 103, 73, 104]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 64,
#   'options': [78, 64, 67, 71, 97]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 87,
#   'options': [99, 87, 111, 93, 109]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 97,
#   'options': [97, 103, 100, 107, 101]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 100,
#   'options': [103, 108, 102, 100, 103]},
#  {'question': 'The current temperature of the living room is 71 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 60,
#   'options': [60, 73, 80, 96, 75]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 49,
#   'options': [83, 85, 69, 49, 65]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 88,
#   'options': [99, 112, 88, 101, 99]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 108,
#   'options': [108, 152, 138, 152, 120]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 66,
#   'options': [81, 66, 83, 74, 75]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 37 minutes. What is the temperature after 37 minutes?',
#   'answer': 103,
#   'options': [125, 118, 103, 124, 124]},
#  {'question': 'The current temperature of the living room is 64 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 58,
#   'options': [66, 67, 76, 58, 78]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 82,
#   'options': [101, 114, 82, 90, 91]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 99,
#   'options': [119, 118, 108, 111, 99]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 93,
#   'options': [102, 93, 122, 116, 105]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 5 minutes. What is the temperature after 5 minutes?',
#   'answer': 71,
#   'options': [82, 95, 71, 98, 86]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 101 minutes. What is the temperature after 101 minutes?',
#   'answer': 59,
#   'options': [67, 86, 99, 59, 66]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 78,
#   'options': [88, 114, 78, 85, 87]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 79,
#   'options': [85, 85, 79, 87, 99]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 50,
#   'options': [73, 69, 66, 50, 72]},
#  {'question': 'The current temperature of the living room is 90 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 90,
#   'options': [104, 94, 90, 98, 98]},
#  {'question': 'The current temperature of the living room is 120 . We turned on the cooler for 18 minutes. What is the temperature after 18 minutes?',
#   'answer': 118,
#   'options': [118, 139, 148, 128, 124]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 78,
#   'options': [89, 99, 111, 102, 78]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 27 minutes. What is the temperature after 27 minutes?',
#   'answer': 51,
#   'options': [80, 51, 70, 65, 58]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 104,
#   'options': [118, 104, 126, 106, 106]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 86,
#   'options': [98, 86, 95, 99, 102]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 49,
#   'options': [54, 49, 52, 53, 67]},
#  {'question': 'The current temperature of the living room is 57 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [43, 70, 93, 60, 58]},
#  {'question': 'The current temperature of the living room is 69 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 64,
#   'options': [75, 84, 71, 75, 64]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 114,
#   'options': [124, 118, 116, 114, 120]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 73 minutes. What is the temperature after 73 minutes?',
#   'answer': 76,
#   'options': [113, 102, 76, 80, 92]},
#  {'question': 'The current temperature of the living room is 62 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 58,
#   'options': [71, 68, 58, 88, 79]},
#  {'question': 'The current temperature of the living room is 70 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 65,
#   'options': [72, 88, 98, 65, 71]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 32 minutes. What is the temperature after 32 minutes?',
#   'answer': 96,
#   'options': [111, 96, 118, 112, 122]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 71,
#   'options': [115, 84, 71, 88, 85]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 67 minutes. What is the temperature after 67 minutes?',
#   'answer': 75,
#   'options': [93, 83, 75, 85, 107]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 95,
#   'options': [129, 119, 124, 131, 95]},
#  {'question': 'The current temperature of the living room is 51 . We turned on the cooler for 77 minutes. What is the temperature after 77 minutes?',
#   'answer': 51,
#   'options': [52, 59, 52, 55, 51]},
#  {'question': 'The current temperature of the living room is 50 . We turned on the cooler for 98 minutes. What is the temperature after 98 minutes?',
#   'answer': 42,
#   'options': [42, 52, 55, 53, 65]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 83,
#   'options': [87, 88, 85, 84, 83]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 117,
#   'options': [121, 117, 129, 140, 120]},
#  {'question': 'The current temperature of the living room is 59 . We turned on the cooler for 42 minutes. What is the temperature after 42 minutes?',
#   'answer': 55,
#   'options': [81, 61, 60, 55, 72]},
#  {'question': 'The current temperature of the living room is 89 . We turned on the cooler for 51 minutes. What is the temperature after 51 minutes?',
#   'answer': 88,
#   'options': [92, 88, 99, 90, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 54 minutes. What is the temperature after 54 minutes?',
#   'answer': 98,
#   'options': [106, 124, 98, 111, 104]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 102,
#   'options': [125, 134, 142, 102, 125]},
#  {'question': 'The current temperature of the living room is 91 . We turned on the cooler for 50 minutes. What is the temperature after 50 minutes?',
#   'answer': 85,
#   'options': [104, 96, 85, 94, 103]},
#  {'question': 'The current temperature of the living room is 67 . We turned on the cooler for 72 minutes. What is the temperature after 72 minutes?',
#   'answer': 55,
#   'options': [55, 94, 79, 80, 84]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 51,
#   'options': [67, 76, 51, 56, 58]},
#  {'question': 'The current temperature of the living room is 85 . We turned on the cooler for 86 minutes. What is the temperature after 86 minutes?',
#   'answer': 84,
#   'options': [105, 92, 120, 84, 87]},
#  {'question': 'The current temperature of the living room is 83 . We turned on the cooler for 111 minutes. What is the temperature after 111 minutes?',
#   'answer': 78,
#   'options': [104, 101, 78, 91, 97]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 61,
#   'options': [97, 61, 69, 79, 96]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 120,
#   'options': [126, 122, 120, 124, 130]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 15 minutes. What is the temperature after 15 minutes?',
#   'answer': 105,
#   'options': [121, 122, 117, 108, 105]},
#  {'question': 'The current temperature of the living room is 116 . We turned on the cooler for 76 minutes. What is the temperature after 76 minutes?',
#   'answer': 113,
#   'options': [119, 128, 124, 113, 131]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 19 minutes. What is the temperature after 19 minutes?',
#   'answer': 94,
#   'options': [109, 110, 94, 109, 108]},
#  {'question': 'The current temperature of the living room is 117 . We turned on the cooler for 9 minutes. What is the temperature after 9 minutes?',
#   'answer': 106,
#   'options': [120, 136, 150, 121, 106]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 31 minutes. What is the temperature after 31 minutes?',
#   'answer': 66,
#   'options': [108, 75, 78, 66, 88]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 106,
#   'options': [119, 106, 136, 130, 120]},
#  {'question': 'The current temperature of the living room is 107 . We turned on the cooler for 117 minutes. What is the temperature after 117 minutes?',
#   'answer': 106,
#   'options': [106, 108, 123, 112, 108]},
#  {'question': 'The current temperature of the living room is 66 . We turned on the cooler for 95 minutes. What is the temperature after 95 minutes?',
#   'answer': 62,
#   'options': [90, 62, 76, 69, 91]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 103,
#   'options': [103, 112, 107, 107, 133]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 104,
#   'options': [134, 115, 115, 104, 126]},
#  {'question': 'The current temperature of the living room is 106 . We turned on the cooler for 104 minutes. What is the temperature after 104 minutes?',
#   'answer': 103,
#   'options': [108, 126, 103, 125, 109]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 93,
#   'options': [93, 112, 95, 98, 99]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 93 minutes. What is the temperature after 93 minutes?',
#   'answer': 88,
#   'options': [122, 88, 102, 118, 100]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 84 minutes. What is the temperature after 84 minutes?',
#   'answer': 72,
#   'options': [97, 101, 107, 86, 72]},
#  {'question': 'The current temperature of the living room is 98 . We turned on the cooler for 43 minutes. What is the temperature after 43 minutes?',
#   'answer': 96,
#   'options': [105, 96, 112, 105, 119]},
#  {'question': 'The current temperature of the living room is 110 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 103,
#   'options': [144, 115, 125, 119, 103]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 28 minutes. What is the temperature after 28 minutes?',
#   'answer': 46,
#   'options': [70, 63, 67, 46, 63]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 101,
#   'options': [116, 101, 110, 110, 112]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 99 minutes. What is the temperature after 99 minutes?',
#   'answer': 80,
#   'options': [83, 83, 98, 80, 89]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 7 minutes. What is the temperature after 7 minutes?',
#   'answer': 76,
#   'options': [82, 81, 87, 95, 76]},
#  {'question': 'The current temperature of the living room is 81 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 75,
#   'options': [84, 89, 82, 85, 75]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 46 minutes. What is the temperature after 46 minutes?',
#   'answer': 76,
#   'options': [76, 92, 98, 102, 85]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 116 minutes. What is the temperature after 116 minutes?',
#   'answer': 91,
#   'options': [130, 104, 91, 123, 109]},
#  {'question': 'The current temperature of the living room is 104 . We turned on the cooler for 26 minutes. What is the temperature after 26 minutes?',
#   'answer': 104,
#   'options': [111, 122, 106, 111, 104]},
#  {'question': 'The current temperature of the living room is 96 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 95,
#   'options': [99, 117, 95, 104, 99]},
#  {'question': 'The current temperature of the living room is 73 . We turned on the cooler for 23 minutes. What is the temperature after 23 minutes?',
#   'answer': 71,
#   'options': [71, 75, 84, 106, 82]},
#  {'question': 'The current temperature of the living room is 72 . We turned on the cooler for 110 minutes. What is the temperature after 110 minutes?',
#   'answer': 72,
#   'options': [100, 76, 72, 93, 73]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 62,
#   'options': [97, 75, 76, 62, 75]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 11 minutes. What is the temperature after 11 minutes?',
#   'answer': 96,
#   'options': [121, 106, 105, 103, 96]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 8 minutes. What is the temperature after 8 minutes?',
#   'answer': 62,
#   'options': [79, 85, 91, 62, 86]},
#  {'question': 'The current temperature of the living room is 97 . We turned on the cooler for 115 minutes. What is the temperature after 115 minutes?',
#   'answer': 86,
#   'options': [113, 121, 103, 100, 86]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 20 minutes. What is the temperature after 20 minutes?',
#   'answer': 105,
#   'options': [105, 129, 118, 118, 130]},
#  {'question': 'The current temperature of the living room is 94 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 82,
#   'options': [107, 82, 130, 112, 99]},
#  {'question': 'The current temperature of the living room is 113 . We turned on the cooler for 82 minutes. What is the temperature after 82 minutes?',
#   'answer': 108,
#   'options': [128, 108, 117, 128, 117]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 10 minutes. What is the temperature after 10 minutes?',
#   'answer': 111,
#   'options': [111, 117, 118, 119, 133]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 109 minutes. What is the temperature after 109 minutes?',
#   'answer': 43,
#   'options': [68, 60, 82, 70, 43]},
#  {'question': 'The current temperature of the living room is 86 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 81,
#   'options': [102, 91, 81, 97, 90]},
#  {'question': 'The current temperature of the living room is 121 . We turned on the cooler for 29 minutes. What is the temperature after 29 minutes?',
#   'answer': 120,
#   'options': [141, 134, 125, 131, 120]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 63,
#   'options': [66, 67, 63, 89, 96]},
#  {'question': 'The current temperature of the living room is 103 . We turned on the cooler for 13 minutes. What is the temperature after 13 minutes?',
#   'answer': 97,
#   'options': [97, 104, 104, 108, 107]},
#  {'question': 'The current temperature of the living room is 99 . We turned on the cooler for 105 minutes. What is the temperature after 105 minutes?',
#   'answer': 99,
#   'options': [104, 101, 121, 99, 118]},
#  {'question': 'The current temperature of the living room is 111 . We turned on the cooler for 58 minutes. What is the temperature after 58 minutes?',
#   'answer': 111,
#   'options': [111, 113, 115, 134, 112]},
#  {'question': 'The current temperature of the living room is 68 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 63,
#   'options': [95, 77, 98, 77, 63]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 107 minutes. What is the temperature after 107 minutes?',
#   'answer': 70,
#   'options': [80, 91, 89, 70, 99]},
#  {'question': 'The current temperature of the living room is 105 . We turned on the cooler for 85 minutes. What is the temperature after 85 minutes?',
#   'answer': 95,
#   'options': [110, 114, 95, 113, 114]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 64 minutes. What is the temperature after 64 minutes?',
#   'answer': 106,
#   'options': [110, 106, 139, 109, 144]},
#  {'question': 'The current temperature of the living room is 112 . We turned on the cooler for 106 minutes. What is the temperature after 106 minutes?',
#   'answer': 102,
#   'options': [113, 124, 128, 113, 102]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 6 minutes. What is the temperature after 6 minutes?',
#   'answer': 98,
#   'options': [117, 116, 116, 98, 140]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 81 minutes. What is the temperature after 81 minutes?',
#   'answer': 52,
#   'options': [68, 54, 65, 73, 52]},
#  {'question': 'The current temperature of the living room is 114 . We turned on the cooler for 66 minutes. What is the temperature after 66 minutes?',
#   'answer': 105,
#   'options': [153, 105, 128, 116, 136]},
#  {'question': 'The current temperature of the living room is 80 . We turned on the cooler for 34 minutes. What is the temperature after 34 minutes?',
#   'answer': 77,
#   'options': [82, 95, 77, 90, 81]},
#  {'question': 'The current temperature of the living room is 58 . We turned on the cooler for 120 minutes. What is the temperature after 120 minutes?',
#   'answer': 39,
#   'options': [89, 39, 62, 75, 59]},
#  {'question': 'The current temperature of the living room is 65 . We turned on the cooler for 16 minutes. What is the temperature after 16 minutes?',
#   'answer': 56,
#   'options': [56, 81, 67, 94, 101]},
#  {'question': 'The current temperature of the living room is 78 . We turned on the cooler for 24 minutes. What is the temperature after 24 minutes?',
#   'answer': 74,
#   'options': [93, 94, 82, 82, 74]},
#  {'question': 'The current temperature of the living room is 88 . We turned on the cooler for 100 minutes. What is the temperature after 100 minutes?',
#   'answer': 85,
#   'options': [90, 92, 98, 91, 85]},
#  {'question': 'The current temperature of the living room is 119 . We turned on the cooler for 119 minutes. What is the temperature after 119 minutes?',
#   'answer': 104,
#   'options': [127, 122, 144, 142, 104]},
#  {'question': 'The current temperature of the living room is 53 . We turned on the cooler for 60 minutes. What is the temperature after 60 minutes?',
#   'answer': 51,
#   'options': [56, 51, 64, 56, 72]},
#  {'question': 'The current temperature of the living room is 77 . We turned on the cooler for 25 minutes. What is the temperature after 25 minutes?',
#   'answer': 74,
#   'options': [101, 78, 84, 74, 90]},
#  {'question': 'The current temperature of the living room is 84 . We turned on the cooler for 91 minutes. What is the temperature after 91 minutes?',
#   'answer': 79,
#   'options': [113, 86, 79, 89, 108]},
#  {'question': 'The current temperature of the living room is 74 . We turned on the cooler for 80 minutes. What is the temperature after 80 minutes?',
#   'answer': 68,
#   'options': [76, 79, 87, 68, 78]},
#  {'question': 'The current temperature of the living room is 56 . We turned on the cooler for 103 minutes. What is the temperature after 103 minutes?',
#   'answer': 40,
#   'options': [58, 40, 65, 60, 61]},
#  {'question': 'The current temperature of the living room is 75 . We turned on the cooler for 48 minutes. What is the temperature after 48 minutes?',
#   'answer': 73,
#   'options': [73, 80, 98, 82, 86]},
#  {'question': 'The current temperature of the living room is 76 . We turned on the cooler for 112 minutes. What is the temperature after 112 minutes?',
#   'answer': 76,
#   'options': [82, 76, 87, 80, 89]},
#  {'question': 'The current temperature of the living room is 100 . We turned on the cooler for 94 minutes. What is the temperature after 94 minutes?',
#   'answer': 100,
#   'options': [106, 103, 106, 100, 111]},
#  {'question': 'The current temperature of the living room is 108 . We turned on the cooler for 22 minutes. What is the temperature after 22 minutes?',
#   'answer': 105,
#   'options': [109, 122, 128, 105, 118]},
#  {'question': 'The current temperature of the living room is 115 . We turned on the cooler for 12 minutes. What is the temperature after 12 minutes?',
#   'answer': 113,
#   'options': [116, 123, 125, 125, 113]},
# ...
#   'answer': '6250',
#   'options': ['6250', '323', '113', '102', '227']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in manganese ?',
#   'answer': '4660',
#   'options': ['183', '327', '290', '239', '4660']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in monel ?',
#   'answer': '5350',
#   'options': ['110', '5350', '282', '322', '302']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nylon ?',
#   'answer': '2620',
#   'options': ['130', '199', '248', '203', '2620']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['178', '255', '3810', '101', '268']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['164', '5010', '128', '307', '166']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['208', '209', '182', '5950', '142']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['101', '201', '207', '124', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in stainless steel ?',
#   'answer': '5790',
#   'options': ['154', '169', '257', '5790', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in silver ?',
#   'answer': '3650',
#   'options': ['3650', '212', '132', '196', '221']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['5100', '339', '256', '175', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['122', '242', '120', '5950', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iridium ?',
#   'answer': '4790',
#   'options': ['298', '196', '242', '4790', '109']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in copper rolled ?',
#   'answer': '5010',
#   'options': ['5010', '212', '161', '282', '261']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['185', '3350', '318', '183', '299']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tungsten carbide ?',
#   'answer': '6655',
#   'options': ['200', '6655', '150', '290', '239']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in cadmium ?',
#   'answer': '2780',
#   'options': ['268', '173', '2780', '238', '295']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '298', '325', '205', '170']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber butyl ?',
#   'answer': '1830',
#   'options': ['327', '202', '142', '299', '1830']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron cast ?',
#   'answer': '4994',
#   'options': ['118', '4994', '246', '143', '108']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['6040', '324', '141', '281', '180']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['340', '4510', '194', '113', '277']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['301', '149', '322', '336', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polyethylene ?',
#   'answer': '1250',
#   'options': ['169', '192', '1250', '101', '228']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lead annealed ?',
#   'answer': '2160',
#   'options': ['241', '295', '135', '260', '2160']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['263', '220', '2680', '221', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['5640', '110', '224', '220', '327']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in slate ?',
#   'answer': '4510',
#   'options': ['289', '156', '309', '4510', '153']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['188', '4200', '130', '264', '325']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Beryllium ?',
#   'answer': '12890',
#   'options': ['197', '178', '275', '101', '12890']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in granite ?',
#   'answer': '5950',
#   'options': ['106', '190', '329', '5950', '211']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in drawn tungsten ?',
#   'answer': '5410',
#   'options': ['334', '217', '340', '5410', '317']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['149', '237', '165', '5950', '280']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in iron electrolytic ?',
#   'answer': '5950',
#   'options': ['291', '283', '109', '5950', '156']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brick ?',
#   'answer': '4200',
#   'options': ['168', '332', '160', '191', '4200']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Brass ?',
#   'answer': '4700',
#   'options': ['324', '179', '243', '287', '4700']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass ?',
#   'answer': '5640',
#   'options': ['207', '262', '143', '5640', '202']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in aluminium ?',
#   'answer': '6420',
#   'options': ['205', '265', '319', '236', '6420']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['100', '314', '3350', '298', '283']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in glass light crown ?',
#   'answer': '5100',
#   'options': ['158', '200', '112', '5100', '287']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in diamond ?',
#   'answer': '12000',
#   'options': ['12000', '259', '299', '269', '161']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in lucite ?',
#   'answer': '2680',
#   'options': ['175', '272', '2680', '246', '168']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tantalium ?',
#   'answer': '3350',
#   'options': ['106', '267', '104', '145', '3350']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in rubber gum ?',
#   'answer': '1550',
#   'options': ['170', '133', '263', '1550', '329']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in marbel ?',
#   'answer': '3810',
#   'options': ['3810', '195', '185', '318', '240']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in nickel ?',
#   'answer': '6040',
#   'options': ['302', '198', '175', '6040', '213']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in tin rolled ?',
#   'answer': '3320',
#   'options': ['132', '310', '3320', '263', '102']},
#  {'question': 'Sound travels faster in denser medium than air. What is the speed of sound in Polystyrene ?',
#   'answer': '2350',
#   'options': ['190', '2350', '272', '174', '207']},
#  {'question': "Eduardo is younger than Harry by 4 years. 7 years ago Harry was 30 years old. What is Eduardo 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '56', '48', '52']},
#  {'question': "Pablo is younger than Crosby by 5 years. 10 years ago Crosby was 29 years old. What is Pablo 's age today?",
#   'answer': 34,
#   'options': ['49', '49', '64', '34', '54']},
#  {'question': "Kamden is younger than Morgan by 2 years. 7 years ago Morgan was 35 years old. What is Kamden 's age today?",
#   'answer': 40,
#   'options': ['51', '40', '53', '48', '62']},
#  {'question': "Luca is younger than Edison by 1 years. 15 years ago Edison was 31 years old. What is Luca 's age today?",
#   'answer': 45,
#   'options': ['49', '64', '45', '47', '62']},
#  {'question': "Ivan is younger than Roy by 3 years. 8 years ago Roy was 35 years old. What is Ivan 's age today?",
#   'answer': 40,
#   'options': ['62', '40', '68', '57', '49']},
#  {'question': "Tyson is younger than Gatlin by 2 years. 6 years ago Gatlin was 33 years old. What is Tyson 's age today?",
#   'answer': 37,
#   'options': ['51', '45', '37', '51', '47']},
#  {'question': "Nicholas is younger than Turner by 3 years. 14 years ago Turner was 27 years old. What is Nicholas 's age today?",
#   'answer': 38,
#   'options': ['75', '38', '47', '50', '50']},
#  {'question': "Princeton is younger than Toby by 5 years. 11 years ago Toby was 32 years old. What is Princeton 's age today?",
#   'answer': 38,
#   'options': ['59', '53', '64', '38', '75']},
#  {'question': "Luciano is younger than Davion by 5 years. 15 years ago Davion was 28 years old. What is Luciano 's age today?",
#   'answer': 38,
#   'options': ['83', '58', '73', '38', '58']},
#  {'question': "Joshua is younger than Wilder by 3 years. 14 years ago Wilder was 26 years old. What is Joshua 's age today?",
#   'answer': 37,
#   'options': ['57', '63', '43', '37', '49']},
#  {'question': "Emiliano is younger than Duke by 3 years. 7 years ago Duke was 28 years old. What is Emiliano 's age today?",
#   'answer': 32,
#   'options': ['52', '45', '51', '32', '45']},
#  {'question': "Alejandro is younger than Leighton by 2 years. 15 years ago Leighton was 33 years old. What is Alejandro 's age today?",
#   'answer': 46,
#   'options': ['46', '52', '54', '54', '54']},
#  {'question': "Justin is younger than Koa by 3 years. 15 years ago Koa was 27 years old. What is Justin 's age today?",
#   'answer': 39,
#   'options': ['48', '39', '48', '75', '63']},
#  {'question': "Fabian is younger than Gibson by 1 years. 8 years ago Gibson was 27 years old. What is Fabian 's age today?",
#   'answer': 34,
#   'options': ['54', '37', '52', '34', '38']},
#  {'question': "Henry is younger than Aryan by 3 years. 11 years ago Aryan was 29 years old. What is Henry 's age today?",
#   'answer': 37,
#   'options': ['68', '37', '49', '71', '68']},
#  {'question': "Jensen is younger than Izaiah by 3 years. 5 years ago Izaiah was 33 years old. What is Jensen 's age today?",
#   'answer': 35,
#   'options': ['52', '51', '46', '35', '51']},
#  {'question': "Nikolai is younger than Dash by 4 years. 7 years ago Dash was 30 years old. What is Nikolai 's age today?",
#   'answer': 33,
#   'options': ['55', '33', '63', '52', '41']},
#  {'question': "Hank is younger than Leroy by 2 years. 12 years ago Leroy was 35 years old. What is Hank 's age today?",
#   'answer': 45,
#   'options': ['77', '65', '51', '61', '45']},
#  {'question': "Tyson is younger than Tadeo by 3 years. 10 years ago Tadeo was 28 years old. What is Tyson 's age today?",
#   'answer': 35,
#   'options': ['35', '57', '54', '47', '54']},
#  {'question': "Mark is younger than Azariah by 5 years. 7 years ago Azariah was 35 years old. What is Mark 's age today?",
#   'answer': 37,
#   'options': ['71', '59', '71', '37', '57']},
#  {'question': "Avery is younger than Westin by 1 years. 11 years ago Westin was 32 years old. What is Avery 's age today?",
#   'answer': 42,
#   'options': ['56', '55', '56', '42', '57']},
#  {'question': "Romeo is younger than Gustavo by 2 years. 12 years ago Gustavo was 30 years old. What is Romeo 's age today?",
#   'answer': 40,
#   'options': ['40', '46', '72', '44', '72']},
#  {'question': "Theo is younger than Nova by 2 years. 15 years ago Nova was 35 years old. What is Theo 's age today?",
#   'answer': 48,
#   'options': ['48', '71', '67', '86', '54']},
#  {'question': "Joaquin is younger than Ulises by 2 years. 7 years ago Ulises was 31 years old. What is Joaquin 's age today?",
#   'answer': 36,
#   'options': ['54', '49', '40', '36', '40']},
#  {'question': "Grayson is younger than Toby by 3 years. 15 years ago Toby was 30 years old. What is Grayson 's age today?",
#   'answer': 42,
#   'options': ['42', '69', '84', '78', '51']},
#  {'question': "Hayes is younger than Kendall by 5 years. 12 years ago Kendall was 29 years old. What is Hayes 's age today?",
#   'answer': 36,
#   'options': ['63', '80', '56', '36', '75']},
#  {'question': "August is younger than Konnor by 4 years. 10 years ago Konnor was 31 years old. What is August 's age today?",
#   'answer': 37,
#   'options': ['65', '69', '55', '37', '63']},
#  {'question': "Knox is younger than Franco by 3 years. 6 years ago Franco was 34 years old. What is Knox 's age today?",
#   'answer': 37,
#   'options': ['58', '37', '46', '52', '55']},
#  {'question': "Hank is younger than Lance by 2 years. 6 years ago Lance was 30 years old. What is Hank 's age today?",
#   'answer': 34,
#   'options': ['42', '54', '34', '38', '50']},
#  {'question': "Damian is younger than Elon by 1 years. 7 years ago Elon was 26 years old. What is Damian 's age today?",
#   'answer': 32,
#   'options': ['35', '34', '50', '32', '48']},
#  {'question': "Micah is younger than Heath by 2 years. 15 years ago Heath was 31 years old. What is Micah 's age today?",
#   'answer': 44,
#   'options': ['52', '44', '67', '78', '82']},
#  {'question': "Ayden is younger than Dakari by 2 years. 11 years ago Dakari was 33 years old. What is Ayden 's age today?",
#   'answer': 42,
#   'options': ['57', '59', '42', '61', '70']},
#  {'question': "Brian is younger than Layton by 5 years. 12 years ago Layton was 26 years old. What is Brian 's age today?",
#   'answer': 33,
#   'options': ['67', '48', '33', '67', '48']},
#  {'question': "Jordan is younger than Harley by 4 years. 15 years ago Harley was 34 years old. What is Jordan 's age today?",
#   'answer': 45,
#   'options': ['45', '68', '91', '91', '53']},
#  {'question': "Joel is younger than Ulises by 5 years. 8 years ago Ulises was 31 years old. What is Joel 's age today?",
#   'answer': 34,
#   'options': ['52', '70', '60', '70', '34']},
#  {'question': "Chase is younger than Caspian by 3 years. 8 years ago Caspian was 31 years old. What is Chase 's age today?",
#   'answer': 36,
#   'options': ['36', '61', '48', '61', '42']},
#  {'question': "Ricardo is younger than Reyansh by 3 years. 7 years ago Reyansh was 26 years old. What is Ricardo 's age today?",
#   'answer': 30,
#   'options': ['53', '46', '36', '30', '50']},
#  {'question': "Phillip is younger than Misael by 3 years. 11 years ago Misael was 33 years old. What is Phillip 's age today?",
#   'answer': 41,
#   'options': ['69', '58', '75', '41', '47']},
#  {'question': "Emanuel is younger than Mauricio by 2 years. 10 years ago Mauricio was 35 years old. What is Emanuel 's age today?",
#   'answer': 43,
#   'options': ['67', '71', '47', '43', '61']},
#  {'question': "Edward is younger than Maurice by 4 years. 9 years ago Maurice was 26 years old. What is Edward 's age today?",
#   'answer': 31,
#   'options': ['56', '56', '48', '47', '31']},
#  ...]

# %%
def general_physics_air(list_of_json_object):
    objects = {"water":"1496","wood":"3960","glass":"5640","aluminium":"6420","mercury":"1540","antimony":"3400","Beryllium":"12890","Bismut":"2180","Brass":"4700","Brick":"4200","cadmium":"2780","concrete":"3700","constantan":"5177","copper annealed":"4760","copper rolled":"5010","cork":"518","diamond":"12000","duralumin":"6320","glass silicate flint":"3980","glass light crown":"5100","glass pyrex":"5640","gold":"3240","granite":"5950","iridium":"4790","iron cast":"4994","iron electrolytic":"5950","ivory":"3010","lead annealed":"2160","lead rolled":"1960","lucite":"2680","magnesium annealed":"5770","manganese":"4660","marbel":"3810","molybdenum":"6250","monel":"5350","nickel":"6040","nylon":"2620","platinum":"3260","Polyethylene":"1250","Polystyrene":"2350","rubber butyl":"1830","rubber gum":"1550","rubber neoprene":"1600","silica fused":"5968","silver":"3650","slate":"4510","steel":"5940","stainless steel":"5790","tantalium":"3350","tin rolled":"3320","titanium":"6070","annealed tungsten":"5220","drawn tungsten":"5410","tungsten carbide":"6655","zinc rolled":"4210"}
    key_list = list(objects.keys()) 
    #print(len(key_list))
    val_list = list(objects.values())
    ref_air = {"air":"343"}
    template = "Sound travels slower in lighter medium than solids.The speed of sound in $1 is $2. What is the speed of sound in air?"
    duplicity = 100
    while duplicity > 0:
        template_obj = {}
        medium = random.randint(0,54)
        template_question = raplace_parameters(template,[key_list[medium],val_list[medium]])
        template_obj["question"] = template_question
        template_obj["answer"] = str(ref_air["air"])
        question_options = []
        question_options.append(str(ref_air["air"]))
        for i in range(4):
            question_options.append(str(random.randint(344,15000)))
        random.shuffle(question_options)
        template_obj["options"] = question_options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
general_physics_air(list_of_json_object)
#print(list_of_json_object)

# %%
#calories stronger
def calories_high(list_of_json_object):
    template = "$1 consumes $2 calories per day. He/She is $3 years old. $4 is $5 years old. How much calories should $6 consume?"
    duplicity = 250
    while duplicity>0:
        template_obj = {}
        options = []
        younger_name = names[random.randint(0,500)]
        older_name = names[random.randint(501,999)]
        younger_food_calories = (random.randint(500,1000))
        younger_age = random.randint(1,15)
        older_age = random.randint(20,40)
        template_question = raplace_parameters(template,[younger_name,younger_food_calories,younger_age,older_name,older_age,older_name])
        template_obj["question"] = template_question
        answer = younger_food_calories*2
        template_obj["answer"] = answer
        options.append(answer)
        for i in range(1,5):
            options.append(int(younger_food_calories/(i+1))+random.randint(10,50))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
calories_high(list_of_json_object)
#print(list_of_json_object)

# %%
#calories age
def calories_tf(list_of_json_object):
    template = "Both $1 and $2 are of same age. Both do same physical activity. $3 consumes $4 calories per day whereas $5 consumes $6 calories per day. $7 is $8 than $9."
    duplicity = 250
    while duplicity > 0:
        template_obj = {}
        person_one = names[random.randint(0,500)]
        person_two = names[random.randint(500,999)]
        person_one_calories = random.randint(1500,3000)
        person_two_calories = random.randint(1500,3000)
        verb = ["bulkier","heavier","stronger","more weight"]
        question = raplace_parameters(template,[person_one,person_two,person_one,person_one_calories,person_two,person_two_calories,person_one,verb[random.randint(0,3)],person_two])
        template_obj["question"] = question
        options = ["True","False","Can't say"]
        random.shuffle(options)
        template_obj["options"] = options
        if person_one_calories==person_two_calories:
            template_obj["answer"] = "Can't say"
        else:
            template_obj["answer"] = True if person_one_calories > person_two_calories else False
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
calories_tf(list_of_json_object)
#print(list_of_json_object)

# %%
#double
def double_radius(list_of_json_object):
    template = "The radius of lotus doubles everyday. It took $1 days to cover the whole pond. How many days would have it taken to cover (1/ $2 )th of the pond?"
    duplicity = 250
    while duplicity>0:
        template_obj = {}
        options = []
        total_days = random.randint(10,350)
        exp_radius = random.randint(1,11)
        part_of_pond = 2**exp_radius
        question = raplace_parameters(template,[total_days,part_of_pond])
        template_obj["question"] = question
        answer = total_days - exp_radius
        template_obj["answer"] = answer
        options.append(answer)
        for i in range(4):
            val = 2*answer
            options.append(random.randint(1,val))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
double_radius(list_of_json_object)
#print(list_of_json_object)

# %%
#calories age
def calories_weaker_tf(list_of_json_object):
    template = "Both $1 and $2 are of same age. Both do same physical activity. $3 consumes $4 calories per day whereas $5 consumes $6 calories per day. $7 is $8 than $9."
    duplicity = 250
    while duplicity > 0:
        template_obj = {}
        person_one = names[random.randint(0,500)]
        person_two = names[random.randint(500,999)]
        person_one_calories = random.randint(1500,3000)
        person_two_calories = random.randint(1500,3000)
        verb = ["lighter","weaker","less weight"]
        question = raplace_parameters(template,[person_one,person_two,person_one,person_one_calories,person_two,person_two_calories,person_one,verb[random.randint(0,2)],person_two])
        template_obj["question"] = question
        options = ["True","False","Can't say"]
        random.shuffle(options)
        template_obj["options"] = options
        if person_one_calories==person_two_calories:
            template_obj["answer"] = "Can't say"
        else:
            template_obj["answer"] = True if person_one_calories < person_two_calories else False
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
#list_of_json_object.clear()
calories_weaker_tf(list_of_json_object)
#print(list_of_json_object)

# %%
#snail
def snail(list_of_json_object):
    climibing_objs = ["snail","bee","mosquito","fly","man","girl","monkey","squirrel","snake","caterpillar"]
    template = "A $1 is climbing a $2 meter pole. It climbs $3 meter in one sec and in the next second it comes $4 meter down. How much time will it take to climb the poll? "
    duplicity = 500
    while duplicity > 0:
        template_obj = {}
        options = []
        climbingObj = climibing_objs[random.randint(0,9)]
        poll_height = random.randint(100,500)
        up = random.randint(1,50)
        down = random.randint(1,50)
        question = raplace_parameters(template,[climbingObj,poll_height,up,down])
        template_obj["question"] = question
        ans = None
        if up <= down:
            ans = "Not possible"
        else:
            two_sec_height = up - down
            total_height_to_climb_with_down = poll_height - up
            time = int(math.ceil((total_height_to_climb_with_down/two_sec_height)))*2 + 1
            ans = str(time)
        template_obj["answer"] = ans
        options.append(ans)
        options.append("Not possible")
        for i in range(4):
            options.append(random.randint(1,100))
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
snail(list_of_json_object)
#print(list_of_json_object)

# %%
def percentage_sell(list_of_json_object):
    template = "$1 sold a book to $2 at a price of $3 after giving $4 pecent discount. What is the original price of the book?"
    duplicity = 200
    while duplicity>0:
        template_obj = {}
        options = []
        person_1 = names[random.randint(0,500)]
        person_2 = names[random.randint(501,999)]
        selling_price = random.randint(100,1000)
        discount = random.randint(1,80)
        question = raplace_parameters(template,[person_1,person_2,selling_price,discount])
        template_obj["question"] = question
        buying_price = float(selling_price / (1-(discount/100)))
        buying_price = str("%.2f" % buying_price)
        template_obj["answer"] = buying_price
        options.append(buying_price)
        options_1 = float(selling_price / (1+(discount/100)))
        options_1 = str("%.2f" % options_1)
        options.append(options_1)
        options_2 = float(selling_price / (1+0.8*(discount/100)))
        options_2 = str("%.2f" % options_2)
        options.append(options_2)
        options_3 = float(selling_price / (1+0.75*(discount/100)))
        options_3 = str("%.2f" % options_3)
        options.append(options_3)
        options_4 = float(selling_price / (1+0.5*(discount/100)))
        options_4 = str("%.2f" % options_4)
        options.append(options_4)
        random.shuffle(options)
        template_obj["options"] = options
        list_of_json_object.append(template_obj)
        duplicity-=1

# %%
percentage_sell(list_of_json_object)
#print(list_of_json_object)

# %%
import json
with open('data.json','w',encoding = 'utf-8') as f:
    json.dump(list_of_json_object,f,ensure_ascii=False,indent=4)
